# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC_Ee60/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for column in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , column))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std)

            sys_shift = 0.0
            print(f'df.at[i, column_to_modify] : {df.at[i, column_to_modify]}' )
            for col in find_corr_err(df):   
                # sys_shift += sysErrDict[df.at[i, col]]**2
                sys_shift += sysErrDict[df.at[i, col]]* sysErrDict[df.at[i, col]]/100.0
                print(f'row: {i} and error: {df.at[i, col]} and column: {col}, sys_shift is:{sys_shift}')
                df.at[i, column_to_modify] += df.at[i, column_to_modify] * sysErrDict[df.at[i, col]]/100.0    # all errors are in percent

            
            # sys_shift  = sys_shift**0.5
            print(f'df.at[i, column_to_modify] shifted: {df.at[i, column_to_modify]}' )
            # sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift 
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 23 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 30 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 31 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 32 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 36 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 37 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 38 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 39 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 43 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 44 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 45 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 46 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 47 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 48 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 49 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# row: 50 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 52 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 53 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 54 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 55 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 56 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 57 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 58 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 59 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 60 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# row: 61 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.7762567885907399
# total sys shift: 0.7762567885907399
# row: 62 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 63 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 64 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 65 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 66 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 67 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 68 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 69 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 70 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 71 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# row: 72 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.7762567885907399
# total sys shift: 0.7762567885907399
# row: 73 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 74 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 75 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 76 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 77 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 78 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 79 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 80 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 81 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# row: 82 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.7762567885907399
# total sys shift: 0.7762567885907399
# row: 83 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 84 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 85 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 86 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 87 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 88 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 89 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 90 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# row: 91 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.7762567885907399
# total sys shift: 0.7762567885907399
# row: 92 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 93 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 94 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 95 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 96 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 97 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 98 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# row: 99 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 100 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.6122965964916063
# total sys shift: 1.6122965964916063
# row: 101 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 102 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 103 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 104 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# row: 105 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.684420504598211
# total sys shift: 4.684420504598211
# row: 106 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.9205951026175
# total sys shift: 6.9205951026175
# row: 107 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.1492950391285675
# total sys shift: 2.1492950391285675
# row: 108 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:7.940448383040324
# total sys shift: 7.940448383040324
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D6_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D6_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.9727641664506966
# total sys shift: 0.9727641664506966
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.9727641664506966
# total sys shift: 0.9727641664506966
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-10.53148145558992
# total sys shift: 10.53148145558992
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:24.975741392060222
# total sys shift: 24.975741392060222
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.9727641664506966
# total sys shift: 0.9727641664506966
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-10.53148145558992
# total sys shift: 10.53148145558992
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:24.975741392060222
# total sys shift: 24.975741392060222
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.9727641664506966
# total sys shift: 0.9727641664506966
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-10.53148145558992
# total sys shift: 10.53148145558992
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:24.975741392060222
# total sys shift: 24.975741392060222
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.9727641664506966
# total sys shift: 0.9727641664506966
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-10.53148145558992
# total sys shift: 10.53148145558992
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:24.975741392060222
# total sys shift: 24.975741392060222
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.18872295365627967
# total sys shift: 0.18872295365627967
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.9727641664506966
# total sys shift: 0.9727641664506966
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-10.53148145558992
# total sys shift: 10.53148145558992
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:24.975741392060222
# total sys shift: 24.975741392060222
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:24.975741392060222
# total sys shift: 24.975741392060222
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D1_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D1_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.891041465761921
# total sys shift: 3.891041465761921
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.891041465761921
# total sys shift: 3.891041465761921
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:4.668941644117292
# total sys shift: 4.668941644117292
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8415499497413124
# total sys shift: 2.8415499497413124
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.891041465761921
# total sys shift: 3.891041465761921
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:4.668941644117292
# total sys shift: 4.668941644117292
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8415499497413124
# total sys shift: 2.8415499497413124
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.891041465761921
# total sys shift: 3.891041465761921
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:4.668941644117292
# total sys shift: 4.668941644117292
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8415499497413124
# total sys shift: 2.8415499497413124
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.891041465761921
# total sys shift: 3.891041465761921
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:4.668941644117292
# total sys shift: 4.668941644117292
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8415499497413124
# total sys shift: 2.8415499497413124
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.4469425171672223
# total sys shift: 2.4469425171672223
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.891041465761921
# total sys shift: 3.891041465761921
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:4.668941644117292
# total sys shift: 4.668941644117292
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8415499497413124
# total sys shift: 2.8415499497413124
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8415499497413124
# total sys shift: 2.8415499497413124
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D2_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D2_datacc-thexp.dat
# row: 0 and error: 0.05 and column: eelen, sysErrDict[df.at[i, col]] is:-0.027323694427915424
# row: 0 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.007953582705384953
# row: 0 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.09310395714240277
# row: 0 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 0 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5143190085917005
# row: 0 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 0 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.6207917692208069
# row: 1 and error: 0.06 and column: eelen, sysErrDict[df.at[i, col]] is:-0.012680759740326087
# row: 1 and error: 0.5 and column: ethee, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 1 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.09310395714240277
# row: 1 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 1 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 1 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.47868645239292
# row: 2 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.09310395714240277
# row: 2 and error: 0.6 and column: ethee, sysErrDict[df.at[i, col]] is:0.3565073075061786
# row: 2 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 2 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 2 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 2 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.5053735204140346
# row: 3 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 3 and error: 0.68 and column: ethee, sysErrDict[df.at[i, col]] is:-0.9933931374469369
# row: 3 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 3 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 3 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 3 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.0611222439341463
# row: 4 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 4 and error: 0.74 and column: ethee, sysErrDict[df.at[i, col]] is:-1.2337628982438242
# row: 4 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 4 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 4 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 4 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.2889225656059289
# row: 5 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 5 and error: 0.77 and column: ethee, sysErrDict[df.at[i, col]] is:0.18455267405375764
# row: 5 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 5 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 5 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 5 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.384438668964722
# row: 6 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 6 and error: 0.79 and column: ethee, sysErrDict[df.at[i, col]] is:0.2187684590637905
# row: 6 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 6 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 6 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 6 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:3.3649154252033564
# total sys shift: 3.3888418166311047
# row: 7 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 7 and error: 0.8 and column: ethee, sysErrDict[df.at[i, col]] is:-0.4680946314518288
# row: 7 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 7 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 7 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 7 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 7 and error: 2.0 and column: enois, sysErrDict[df.at[i, col]] is:-1.0183017751603987
# total sys shift: 1.1781858030286099
# row: 8 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 8 and error: 0.78 and column: ethee, sysErrDict[df.at[i, col]] is:-0.2959836844332608
# row: 8 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 8 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 8 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 8 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 8 and error: 2.17 and column: enois, sysErrDict[df.at[i, col]] is:-3.0502828727368887
# total sys shift: 3.086082086129924
# row: 9 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 9 and error: 0.32 and column: ethee, sysErrDict[df.at[i, col]] is:-0.522078024609025
# row: 9 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.012680759740326087
# row: 9 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 9 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5143190085917005
# row: 9 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 9 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.8174010023478752
# row: 10 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 10 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1416779468724847
# row: 10 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.012680759740326087
# row: 10 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 10 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 10 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.38875124808918887
# row: 11 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.09310395714240277
# row: 11 and error: 0.39 and column: ethee, sysErrDict[df.at[i, col]] is:0.10687311303527386
# row: 11 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 11 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 11 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 11 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3642073629738683
# row: 12 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.09310395714240277
# row: 12 and error: 0.4 and column: ethee, sysErrDict[df.at[i, col]] is:0.652162730840994
# row: 12 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.173738887047964
# row: 12 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 12 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 12 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.758650092433367
# row: 13 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.09310395714240277
# row: 13 and error: 0.41 and column: ethee, sysErrDict[df.at[i, col]] is:-0.02196821347238533
# row: 13 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.173738887047964
# row: 13 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 13 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 13 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3882220210837374
# row: 14 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.09310395714240277
# row: 14 and error: 0.42 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0894371025162855
# row: 14 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 14 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 14 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 14 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.36919362147371704
# row: 15 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 15 and error: 0.44 and column: ethee, sysErrDict[df.at[i, col]] is:0.16835670640010938
# row: 15 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 15 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 15 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 15 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:3.3649154252033564
# total sys shift: 3.389712420015383
# row: 16 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 16 and error: 0.46 and column: ethee, sysErrDict[df.at[i, col]] is:-0.26429286231274507
# row: 16 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 16 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 16 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 16 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 16 and error: 1.88 and column: enois, sysErrDict[df.at[i, col]] is:0.18281000062033556
# total sys shift: 0.4923623710657017
# row: 17 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 17 and error: 0.47 and column: ethee, sysErrDict[df.at[i, col]] is:-0.5595276564237394
# row: 17 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 17 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 17 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 17 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 17 and error: 2.15 and column: enois, sysErrDict[df.at[i, col]] is:1.5793675174796722
# total sys shift: 1.7145097406379097
# row: 18 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 18 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:-0.3156248806036774
# row: 18 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:0.008944845375580055
# row: 18 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 18 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5143190085917005
# row: 18 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 18 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.6904925142480421
# row: 19 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 19 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.007953582705384953
# row: 19 and error: 0.03 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0063479883948843125
# row: 19 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 19 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 19 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.36193597089515794
# row: 20 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 20 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.19515013225455458
# row: 20 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 20 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 20 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 20 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.41249760155460063
# row: 21 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 21 and error: 0.3 and column: ethee, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 21 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 21 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 21 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 21 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3762968175917567
# row: 22 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.13969217247352722
# row: 22 and error: 0.31 and column: ethee, sysErrDict[df.at[i, col]] is:-0.26133958723828565
# row: 22 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.173738887047964
# row: 22 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 22 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 22 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.47893389034797934
# row: 23 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 23 and error: 0.33 and column: ethee, sysErrDict[df.at[i, col]] is:-0.44357759891087706
# row: 23 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.007069463838912374
# row: 23 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 23 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 23 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.5562084660390049
# row: 24 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 24 and error: 0.34 and column: ethee, sysErrDict[df.at[i, col]] is:0.11455438680478107
# row: 24 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.007069463838912374
# row: 24 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 24 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 24 and error: 1.66 and column: enois, sysErrDict[df.at[i, col]] is:-0.4027267120875206
# total sys shift: 0.5365801744408454
# row: 25 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 25 and error: 0.36 and column: ethee, sysErrDict[df.at[i, col]] is:0.07934138931215406
# row: 25 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.007069463838912374
# row: 25 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 25 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 25 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 25 and error: 1.93 and column: enois, sysErrDict[df.at[i, col]] is:0.6765035637064631
# total sys shift: 0.7593147563451216
# row: 26 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09086473711986065
# row: 26 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1416779468724847
# row: 26 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.173738887047964
# row: 26 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 26 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 26 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 26 and error: 2.22 and column: enois, sysErrDict[df.at[i, col]] is:0.6456692827026883
# total sys shift: 0.766017788385666
# row: 27 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 27 and error: 0.16 and column: ethee, sysErrDict[df.at[i, col]] is:0.10842410484360057
# row: 27 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.022555098422735544
# row: 27 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 27 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5143190085917005
# row: 27 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 27 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.6239754447842474
# row: 28 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 28 and error: 0.22 and column: ethee, sysErrDict[df.at[i, col]] is:0.011476097898653654
# row: 28 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:0.008944845375580055
# row: 28 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 28 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 28 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.33581022200154476
# row: 29 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 29 and error: 0.23 and column: ethee, sysErrDict[df.at[i, col]] is:-0.14107017098374186
# row: 29 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03430169931680234
# row: 29 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.04948539061697731
# row: 29 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.3300475475721932
# row: 29 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.36556010974442593
# row: 30 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03430169931680234
# ...
# row: 132 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 132 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.8527343648685849
# row: 133 and error: 0.47 and column: eelen, sysErrDict[df.at[i, col]] is:-0.374331479018867
# row: 133 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.05128299618239394
# row: 133 and error: 1.8 and column: ehadr, sysErrDict[df.at[i, col]] is:1.5219151632897039
# row: 133 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 133 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 133 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 133 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.7408196757039767
# row: 134 and error: 0.67 and column: eelen, sysErrDict[df.at[i, col]] is:0.38772733171637225
# row: 134 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:0.04268944723284172
# row: 134 and error: 2.8 and column: ehadr, sysErrDict[df.at[i, col]] is:-4.977959747327559
# row: 134 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 134 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 134 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 134 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 5.050119948660971
# row: 135 and error: 1.0 and column: eelen, sysErrDict[df.at[i, col]] is:-0.9949576861751956
# row: 135 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:-0.04664951398348748
# row: 135 and error: 4.43 and column: ehadr, sysErrDict[df.at[i, col]] is:-4.752603193789318
# row: 135 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 135 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 135 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 135 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 4.914349139940659
# row: 136 and error: 1.73 and column: eelen, sysErrDict[df.at[i, col]] is:-1.0950086014593141
# row: 136 and error: 0.1 and column: ethee, sysErrDict[df.at[i, col]] is:0.006513208489676125
# row: 136 and error: 8.02 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.03220742488504715
# row: 136 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 136 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 136 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 136 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.331013506527081
# row: 137 and error: 0.15 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19524638548491405
# row: 137 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 137 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03302379769357517
# row: 137 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 137 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.9949576861751956
# row: 137 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 137 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.2651584472797095
# row: 138 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.05518691488742386
# row: 138 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 138 and error: 0.28 and column: ehadr, sysErrDict[df.at[i, col]] is:0.036766250203253185
# row: 138 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 138 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 138 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 138 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.7588952615458701
# row: 139 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.287196759001465
# row: 139 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 139 and error: 0.64 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.29523571034687435
# row: 139 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 139 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 139 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 139 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.8609127530202718
# row: 140 and error: 0.34 and column: eelen, sysErrDict[df.at[i, col]] is:0.3925636372056267
# row: 140 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 140 and error: 1.13 and column: ehadr, sysErrDict[df.at[i, col]] is:1.1283718431705474
# row: 140 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 140 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 140 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 140 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.4138082935759657
# row: 141 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.1631301893989969
# row: 141 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.020055325870338935
# row: 141 and error: 1.81 and column: ehadr, sysErrDict[df.at[i, col]] is:1.4718291020605834
# row: 141 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 141 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 141 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 141 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.6627591399979307
# row: 142 and error: 0.68 and column: eelen, sysErrDict[df.at[i, col]] is:-1.1242584662128492
# row: 142 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.05128299618239394
# row: 142 and error: 2.82 and column: ehadr, sysErrDict[df.at[i, col]] is:-1.6934923193664944
# row: 142 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 142 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 142 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 142 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 2.1693263142015073
# row: 143 and error: 1.01 and column: eelen, sysErrDict[df.at[i, col]] is:-0.016562056892209874
# row: 143 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:0.04268944723284172
# row: 143 and error: 4.46 and column: ehadr, sysErrDict[df.at[i, col]] is:-8.689801664598798
# row: 143 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 143 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 143 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 143 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 8.722741715646674
# row: 144 and error: 1.74 and column: eelen, sysErrDict[df.at[i, col]] is:-2.5455412739494774
# row: 144 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:-0.017772667418953714
# row: 144 and error: 8.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-5.528775630979382
# row: 144 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 144 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 144 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 144 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 6.1334272311639975
# row: 145 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.05518691488742386
# row: 145 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 145 and error: 0.24 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.2907187917829007
# row: 145 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 145 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.9949576861751956
# row: 145 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 145 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.2841250663135102
# row: 146 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.287196759001465
# row: 146 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 146 and error: 0.58 and column: ehadr, sysErrDict[df.at[i, col]] is:0.4724788360713856
# row: 146 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 146 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 146 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 146 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.9366124567740338
# row: 147 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:-0.38913423283263227
# row: 147 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 147 and error: 1.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.17649801525226705
# row: 147 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 147 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 147 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 147 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.8683902727565558
# row: 148 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.1631301893989969
# row: 148 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 148 and error: 1.78 and column: ehadr, sysErrDict[df.at[i, col]] is:0.8243377950239285
# row: 148 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 148 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 148 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 148 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.1303401807713638
# row: 149 and error: 0.69 and column: eelen, sysErrDict[df.at[i, col]] is:-0.23066778821773445
# row: 149 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.020055325870338935
# row: 149 and error: 2.81 and column: ehadr, sysErrDict[df.at[i, col]] is:0.4167083582575267
# row: 149 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 149 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 149 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 149 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.893716441408452
# row: 150 and error: 1.02 and column: eelen, sysErrDict[df.at[i, col]] is:1.0346113481549832
# row: 150 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.05128299618239394
# row: 150 and error: 4.47 and column: ehadr, sysErrDict[df.at[i, col]] is:5.154807351162605
# row: 150 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 150 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 150 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 150 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 5.31192646713164
# row: 151 and error: 1.76 and column: eelen, sysErrDict[df.at[i, col]] is:3.2037189559184123
# row: 151 and error: 0.05 and column: ethee, sysErrDict[df.at[i, col]] is:0.05722309193715665
# row: 151 and error: 8.13 and column: ehadr, sysErrDict[df.at[i, col]] is:2.363438152420893
# row: 151 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 151 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 151 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 151 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 4.052703160640509
# row: 152 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:-0.38913423283263227
# row: 152 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 152 and error: 1.06 and column: ehadr, sysErrDict[df.at[i, col]] is:1.5865595205254286
# row: 152 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 152 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.9949576861751956
# row: 152 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 152 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 2.0566989905662654
# row: 153 and error: 0.49 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1553232144059601
# row: 153 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 153 and error: 1.73 and column: ehadr, sysErrDict[df.at[i, col]] is:-1.0950086014593141
# row: 153 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 153 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.9949576861751956
# row: 153 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 153 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.6687224456902223
# row: 154 and error: 0.7 and column: eelen, sysErrDict[df.at[i, col]] is:0.5906126230226822
# row: 154 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.007161569862673958
# row: 154 and error: 2.76 and column: ehadr, sysErrDict[df.at[i, col]] is:-4.03038250395088
# row: 154 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 154 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 154 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 154 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 4.142985766798514
# row: 155 and error: 1.03 and column: eelen, sysErrDict[df.at[i, col]] is:1.2016063011501639
# row: 155 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.020055325870338935
# row: 155 and error: 4.44 and column: ehadr, sysErrDict[df.at[i, col]] is:-6.891682098216103
# row: 155 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 155 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 155 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 155 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 7.0364064293584505
# row: 156 and error: 1.78 and column: eelen, sysErrDict[df.at[i, col]] is:0.8243377950239285
# row: 156 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.05128299618239394
# row: 156 and error: 8.14 and column: ehadr, sysErrDict[df.at[i, col]] is:0.017655490607557278
# row: 156 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.7487583580401102
# row: 156 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 156 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.10408793614129734
# row: 156 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.1197981244563797
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D7_datanc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D7_datanc-thexp.dat
