# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC_Ee60/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for column in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , column))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std)

            sys_shift = 0.0
            print(f'df.at[i, column_to_modify] : {df.at[i, column_to_modify]}' )
            for col in find_corr_err(df):   
                # sys_shift += sysErrDict[df.at[i, col]]**2
                sys_shift += sysErrDict[df.at[i, col]]* sysErrDict[df.at[i, col]]/100.0
                print(f'row: {i} and error: {df.at[i, col]} and column: {col}, sys_shift is:{sys_shift}')
                df.at[i, column_to_modify] += df.at[i, column_to_modify] * sysErrDict[df.at[i, col]]/100.0    # all errors are in percent

            
            # sys_shift  = sys_shift**0.5
            print(f'df.at[i, column_to_modify] shifted: {df.at[i, column_to_modify]}' )
            # sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift 
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# df.at[i, column_to_modify] : 2.774284135096376
# row: 0 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.696741743068458
# df.at[i, column_to_modify] : 3.6130253233125416
# row: 1 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 3.51203976726121
# df.at[i, column_to_modify] : 3.5427690038491098
# row: 2 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 3.443747141060971
# df.at[i, column_to_modify] : 3.0337027875684526
# row: 3 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.948909536627107
# df.at[i, column_to_modify] : 2.5654946743738956
# row: 4 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.493788034354875
# df.at[i, column_to_modify] : 2.072065454989023
# row: 5 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.0141503662691425
# df.at[i, column_to_modify] : 1.8808969462583445
# row: 6 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.8283250966320583
# df.at[i, column_to_modify] : 1.3342099965215912
# row: 7 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.2969182738429226
# df.at[i, column_to_modify] : 1.0238541791465283
# row: 8 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.9952370302631663
# df.at[i, column_to_modify] : 3.1363803909733
# row: 9 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 3.048717258438003
# df.at[i, column_to_modify] : 3.4263731050192656
# row: 10 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 3.3306045558709685
# df.at[i, column_to_modify] : 3.2975341027384513
# row: 11 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 3.20536665713141
# df.at[i, column_to_modify] : 2.800930066976764
# row: 12 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.7226429101031404
# df.at[i, column_to_modify] : 2.0994917468986034
# row: 13 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.040810081946598
# df.at[i, column_to_modify] : 1.7209713596344838
# row: 14 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.6728694964729587
# df.at[i, column_to_modify] : 1.3019087649338
# row: 15 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.2655198750728225
# df.at[i, column_to_modify] : 1.0248931542369648
# row: 16 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.9962469655689785
# df.at[i, column_to_modify] : 0.725946723308355
# row: 17 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.705656211353204
# df.at[i, column_to_modify] : 2.741188768736945
# row: 18 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.664571405922901
# df.at[i, column_to_modify] : 2.992323241591951
# row: 19 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.9086865661200956
# df.at[i, column_to_modify] : 2.7859026173579733
# row: 20 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.708035483932842
# df.at[i, column_to_modify] : 2.152940820419755
# row: 21 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.0927652316983436
# df.at[i, column_to_modify] : 1.7868820513680719
# row: 22 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.7369379570404664
# df.at[i, column_to_modify] : 1.3563602796226253
# row: 23 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.318449447345909
# df.at[i, column_to_modify] : 0.9858524441747344
# row: 24 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.9582974595425555
# df.at[i, column_to_modify] : 0.8038763541225038
# row: 25 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.7814076766699057
# df.at[i, column_to_modify] : 0.5786045852687504
# row: 26 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.5624323471722723
# df.at[i, column_to_modify] : 2.3231094481934496
# row: 27 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.2581775757595115
# df.at[i, column_to_modify] : 2.57483472106405
# row: 28 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.502867022866869
# df.at[i, column_to_modify] : 2.201700379501814
# row: 29 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.1401619408842376
# df.at[i, column_to_modify] : 1.91097504992495
# row: 30 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.857562504828266
# df.at[i, column_to_modify] : 1.4325659943670936
# row: 31 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.3925251807619587
# df.at[i, column_to_modify] : 0.9848440803386277
# row: 32 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.9573172798938206
# df.at[i, column_to_modify] : 0.8437044665634299
# row: 33 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.8201225768520165
# df.at[i, column_to_modify] : 0.5754731341902546
# row: 34 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.559388421449984
# df.at[i, column_to_modify] : 0.4237692548349447
# row: 35 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.41192472843186656
# df.at[i, column_to_modify] : 0.2773765529051547
# row: 36 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.281053784947702
# df.at[i, column_to_modify] : 0.2040938721503712
# row: 37 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.19067334001456174
# df.at[i, column_to_modify] : 2.088863028009691
# row: 38 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 2.030478440158193
# df.at[i, column_to_modify] : 2.026633725323749
# row: 39 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.9699884722878358
# df.at[i, column_to_modify] : 1.8564576125883732
# row: 40 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.8045688524727699
# df.at[i, column_to_modify] : 1.4047299776680997
# row: 41 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.3654671922728596
# df.at[i, column_to_modify] : 0.9971076923768092
# row: 42 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.969238118890008
# df.at[i, column_to_modify] : 0.831226330207855
# row: 43 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.8079932095820667
# df.at[i, column_to_modify] : 0.5563948393946178
# row: 44 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.5408433729053539
# df.at[i, column_to_modify] : 0.39720666533496896
# row: 45 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.386104574323503
# df.at[i, column_to_modify] : 0.22240710898580357
# row: 46 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.2253556009873339
# df.at[i, column_to_modify] : 0.17584355808391966
# row: 47 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.16428067235258523
# df.at[i, column_to_modify] : 0.042313961917035445
# row: 48 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.04292370376059123
# df.at[i, column_to_modify] : 0.012337962946495735
# row: 49 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: 0.011920895971692788
# df.at[i, column_to_modify] : 1.5529888491259562
# row: 50 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.5095821667928482
# df.at[i, column_to_modify] : 1.550162019764325
# row: 51 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.5068343484841162
# df.at[i, column_to_modify] : 1.3262255161578556
# row: 52 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.2891569630163917
# df.at[i, column_to_modify] : 0.997964835512696
# row: 53 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.9700713045198031
# df.at[i, column_to_modify] : 0.8178572279360362
# row: 54 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.7949977792627015
# df.at[i, column_to_modify] : 0.5387821031123153
# row: 55 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.5237229199058664
# df.at[i, column_to_modify] : 0.37539260127877316
# row: 56 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.36490022240362696
# df.at[i, column_to_modify] : 0.2609683180224776
# row: 57 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.2644280230735028
# df.at[i, column_to_modify] : 0.13951344693994605
# row: 58 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.1303395081131321
# df.at[i, column_to_modify] : 0.06377351084089793
# row: 59 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.06469248359382511
# df.at[i, column_to_modify] : 0.029944015259605605
# row: 60 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: 0.028931801175973264
# df.at[i, column_to_modify] : 0.017862713592829697
# row: 61 and error: 8.67 and column: ccsys, sys_shift is:0.0956472599931831
# df.at[i, column_to_modify] shifted: 0.017310275392824055
# df.at[i, column_to_modify] : 1.2913239184621117
# row: 62 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.2552308794493872
# df.at[i, column_to_modify] : 1.2014931641136741
# row: 63 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 1.1679109319363887
# df.at[i, column_to_modify] : 0.9670184775961101
# row: 64 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.9399899101399535
# df.at[i, column_to_modify] : 0.8020285825155743
# row: 65 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.7796115510456317
# df.at[i, column_to_modify] : 0.5509648279909142
# row: 66 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.535565132572124
# df.at[i, column_to_modify] : 0.3221517581078925
# row: 67 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.31314748287751226
# df.at[i, column_to_modify] : 0.22305009518783547
# row: 68 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.22600711137585622
# df.at[i, column_to_modify] : 0.1325785056696141
# row: 69 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.12386058544442612
# df.at[i, column_to_modify] : 0.024292430511140387
# row: 70 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.024642483087010156
# df.at[i, column_to_modify] : 0.011571861585304545
# row: 71 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: 0.011180691557873707
# df.at[i, column_to_modify] : -0.0025913934956347693
# row: 72 and error: 8.67 and column: ccsys, sys_shift is:0.0956472599931831
# df.at[i, column_to_modify] shifted: -0.0025112497509122735
# df.at[i, column_to_modify] : 0.9884136252524621
# row: 73 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.9607870545470794
# df.at[i, column_to_modify] : 0.8824385103749102
# row: 74 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.8577739880765675
# df.at[i, column_to_modify] : 0.7879970756438877
# row: 75 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.7659722306096538
# df.at[i, column_to_modify] : 0.56273572770759
# row: 76 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.5470070307605118
# df.at[i, column_to_modify] : 0.3860817602147426
# row: 77 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.37529061491471005
# df.at[i, column_to_modify] : 0.2142991968233516
# row: 78 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.21714020074021992
# df.at[i, column_to_modify] : 0.09799526422748717
# row: 79 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.09155142258312285
# df.at[i, column_to_modify] : 0.068462281227854
# row: 80 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.06944881890191426
# df.at[i, column_to_modify] : 0.020173942025577728
# row: 81 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: 0.019491991122746764
# df.at[i, column_to_modify] : 0.0010891353759504958
# row: 82 and error: 8.67 and column: ccsys, sys_shift is:0.0956472599931831
# df.at[i, column_to_modify] shifted: 0.001055451804665219
# df.at[i, column_to_modify] : 0.7751064368715753
# row: 83 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.7534418905365726
# df.at[i, column_to_modify] : 0.7299475061037598
# row: 84 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.7095451706104156
# df.at[i, column_to_modify] : 0.5166912725357558
# row: 85 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.5022495372046414
# df.at[i, column_to_modify] : 0.289206653898742
# row: 86 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.2811232079928238
# df.at[i, column_to_modify] : 0.16698730926238106
# row: 87 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.16920109077306394
# df.at[i, column_to_modify] : 0.0566965508802327
# row: 88 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.05296837484505459
# df.at[i, column_to_modify] : 0.010556187594114062
# row: 89 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.010708301671665484
# df.at[i, column_to_modify] : -0.003363184929585643
# row: 90 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: -0.0032494973321785248
# df.at[i, column_to_modify] : 0.00140298278408845
# row: 91 and error: 8.67 and column: ccsys, sys_shift is:0.0956472599931831
# df.at[i, column_to_modify] shifted: 0.001359592888155066
# df.at[i, column_to_modify] : 0.6518329352018167
# row: 92 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.6336139343580651
# df.at[i, column_to_modify] : 0.5009852520500759
# row: 93 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.4869825065045759
# df.at[i, column_to_modify] : 0.28449219615681115
# row: 94 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.27654052129979134
# df.at[i, column_to_modify] : 0.26497314967397206
# row: 95 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.26848594751571675
# df.at[i, column_to_modify] : 0.07826345708201357
# row: 96 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.07311711324639442
# df.at[i, column_to_modify] : 0.05044299099583658
# row: 97 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.05116987169740205
# df.at[i, column_to_modify] : 0.0038338359431357646
# row: 98 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: 0.0037042386696127007
# df.at[i, column_to_modify] : 0.4429121836158039
# row: 99 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.43053260441502944
# df.at[i, column_to_modify] : 0.34530306400360417
# row: 100 and error: 2.0 and column: ccsys, sys_shift is:0.07812256810223084
# df.at[i, column_to_modify] shifted: 0.33565170017295654
# df.at[i, column_to_modify] : 0.2372729512775617
# row: 101 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.24041852248799475
# df.at[i, column_to_modify] : 0.1504787732923875
# row: 102 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.14058379118709555
# df.at[i, column_to_modify] : 0.02396972618632067
# row: 103 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.02431512861077411
# df.at[i, column_to_modify] : -0.005745969351792307
# row: 104 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: -0.005551735176729955
# df.at[i, column_to_modify] : 0.07198541383181901
# row: 105 and error: 3.33 and column: ccsys, sys_shift is:0.017575293175825447
# df.at[i, column_to_modify] shifted: 0.07293973771956631
# df.at[i, column_to_modify] : 0.01932818685183116
# row: 106 and error: 4.67 and column: ccsys, sys_shift is:0.43239388348648594
# df.at[i, column_to_modify] shifted: 0.018057229767040224
# df.at[i, column_to_modify] : 0.07627522013869062
# row: 107 and error: 6.0 and column: ccsys, sys_shift is:0.02076465010081206
# df.at[i, column_to_modify] shifted: 0.07737434182897755
# df.at[i, column_to_modify] : 0.011594367790915276
# row: 108 and error: 7.33 and column: ccsys, sys_shift is:0.11426801429787849
# df.at[i, column_to_modify] shifted: 0.011202436973787705
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D6_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D6_datacc-thexp.dat
# df.at[i, column_to_modify] : 5.322155349073805
# row: 0 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 5.279618727597051
# df.at[i, column_to_modify] : 6.723031731204989
# row: 1 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 6.669298790850995
# df.at[i, column_to_modify] : 6.300690865339059
# row: 2 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 6.250333428398101
# df.at[i, column_to_modify] : 5.7783855096332575
# row: 3 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 5.73220252904574
# df.at[i, column_to_modify] : 4.465491820817174
# row: 4 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 4.429801969087706
# df.at[i, column_to_modify] : 3.3982034622374755
# row: 5 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.37104377130524
# df.at[i, column_to_modify] : 2.972084004162394
# row: 6 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 2.948330016540787
# df.at[i, column_to_modify] : 2.013586559884499
# row: 7 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.9974932360916502
# df.at[i, column_to_modify] : 4.696606326486696
# row: 8 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 4.659069322691822
# df.at[i, column_to_modify] : 5.876458363787133
# row: 9 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 5.829491548906802
# df.at[i, column_to_modify] : 5.8072767353346295
# row: 10 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 5.760862845453592
# df.at[i, column_to_modify] : 5.036785470209811
# row: 11 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 4.9965296296802375
# df.at[i, column_to_modify] : 3.8752139665389325
# row: 12 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.8442418323518344
# df.at[i, column_to_modify] : 3.261992503516098
# row: 13 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.235921460624383
# df.at[i, column_to_modify] : 2.1283952887129884
# row: 14 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 2.1113843713663827
# df.at[i, column_to_modify] : 1.4037692127848467
# row: 15 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.3925497733418886
# df.at[i, column_to_modify] : 4.19402441635546
# row: 16 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 4.160504231888499
# df.at[i, column_to_modify] : 4.544474022960427
# row: 17 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 4.508152916444953
# df.at[i, column_to_modify] : 4.007878101009617
# row: 18 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.975845666304891
# df.at[i, column_to_modify] : 3.372776369731726
# row: 19 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.3458199014674195
# df.at[i, column_to_modify] : 2.181693981892456
# row: 20 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 2.164257081802341
# df.at[i, column_to_modify] : 1.4046786666894973
# row: 21 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.393451958556703
# df.at[i, column_to_modify] : 1.0325922141282986
# row: 22 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.0243393576685822
# df.at[i, column_to_modify] : 0.4930119791966789
# row: 23 and error: 3.33 and column: ccsys, sys_shift is:0.0012293076371583756
# df.at[i, column_to_modify] shifted: 0.4947405523424625
# df.at[i, column_to_modify] : 3.048370348535652
# row: 24 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.0240066524140823
# df.at[i, column_to_modify] : 3.3786808146041087
# row: 25 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.3516771558464598
# df.at[i, column_to_modify] : 3.1533888598507276
# row: 26 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 3.1281858171917367
# df.at[i, column_to_modify] : 2.1854566458507394
# row: 27 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 2.167989673167466
# df.at[i, column_to_modify] : 1.380943199690866
# row: 28 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.3699061941332644
# df.at[i, column_to_modify] : 1.0112832245366707
# row: 29 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.0032006773529638
# df.at[i, column_to_modify] : 0.4716376960047872
# row: 30 and error: 3.33 and column: ccsys, sys_shift is:0.0012293076371583756
# df.at[i, column_to_modify] shifted: 0.4732913277424613
# df.at[i, column_to_modify] : 0.1058936288814468
# row: 31 and error: 6.0 and column: ccsys, sys_shift is:1.2969813154010625
# df.at[i, column_to_modify] shifted: 0.09383392369099612
# df.at[i, column_to_modify] : 0.004273072449647874
# row: 32 and error: 8.67 and column: ccsys, sys_shift is:0.2256058788572357
# df.at[i, column_to_modify] shifted: 0.0040701101091063915
# df.at[i, column_to_modify] : 2.189893765833611
# row: 33 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 2.172391330056764
# df.at[i, column_to_modify] : 2.0090107088174234
# row: 34 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.9929539569079582
# df.at[i, column_to_modify] : 1.3454488466243917
# row: 35 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.3346955249809045
# df.at[i, column_to_modify] : 0.9693823919134085
# row: 36 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 0.9616347315828571
# df.at[i, column_to_modify] : 0.4181214760253406
# row: 37 and error: 3.33 and column: ccsys, sys_shift is:0.0012293076371583756
# df.at[i, column_to_modify] shifted: 0.41958747195572443
# df.at[i, column_to_modify] : 0.08361567982878684
# row: 38 and error: 6.0 and column: ccsys, sys_shift is:1.2969813154010625
# df.at[i, column_to_modify] shifted: 0.07409310081543359
# df.at[i, column_to_modify] : 0.004068209203417729
# row: 39 and error: 8.67 and column: ccsys, sys_shift is:0.2256058788572357
# df.at[i, column_to_modify] shifted: 0.0038749774547245605
# df.at[i, column_to_modify] : 1.5968089161216863
# row: 40 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.5840466324263045
# df.at[i, column_to_modify] : 1.2820954804293898
# row: 41 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.2718485021713102
# df.at[i, column_to_modify] : 0.9307621453458186
# row: 42 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 0.923323152219029
# df.at[i, column_to_modify] : 0.39276604583911656
# row: 43 and error: 3.33 and column: ccsys, sys_shift is:0.0012293076371583756
# df.at[i, column_to_modify] shifted: 0.3941431418693578
# df.at[i, column_to_modify] : 0.07609534320477791
# row: 44 and error: 6.0 and column: ccsys, sys_shift is:1.2969813154010625
# df.at[i, column_to_modify] shifted: 0.06742921838585059
# df.at[i, column_to_modify] : 0.0032056665714307285
# row: 45 and error: 8.67 and column: ccsys, sys_shift is:0.2256058788572357
# df.at[i, column_to_modify] shifted: 0.003053403861635863
# df.at[i, column_to_modify] : 1.1696885074223793
# row: 46 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 1.1603399270028705
# df.at[i, column_to_modify] : 0.8797449185321154
# row: 47 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 0.872713673831186
# df.at[i, column_to_modify] : 0.3630787719799702
# row: 48 and error: 3.33 and column: ccsys, sys_shift is:0.0012293076371583756
# df.at[i, column_to_modify] shifted: 0.36435178002344876
# df.at[i, column_to_modify] : 0.0613126985683158
# row: 49 and error: 6.0 and column: ccsys, sys_shift is:1.2969813154010625
# df.at[i, column_to_modify] shifted: 0.05433009652723677
# df.at[i, column_to_modify] : 0.0024421354516266955
# row: 50 and error: 8.67 and column: ccsys, sys_shift is:0.2256058788572357
# df.at[i, column_to_modify] shifted: 0.002326138933191271
# df.at[i, column_to_modify] : 0.8664379548308838
# row: 51 and error: 2.0 and column: ccsys, sys_shift is:0.006387793835977147
# df.at[i, column_to_modify] shifted: 0.859513064274251
# df.at[i, column_to_modify] : 0.36421194945560226
# row: 52 and error: 3.33 and column: ccsys, sys_shift is:0.0012293076371583756
# df.at[i, column_to_modify] shifted: 0.3654889305874366
# df.at[i, column_to_modify] : 0.051454009139934524
# row: 53 and error: 6.0 and column: ccsys, sys_shift is:1.2969813154010625
# df.at[i, column_to_modify] shifted: 0.045594164807004275
# df.at[i, column_to_modify] : 0.002151853977429442
# row: 54 and error: 8.67 and column: ccsys, sys_shift is:0.2256058788572357
# df.at[i, column_to_modify] shifted: 0.0020496452447414278
# df.at[i, column_to_modify] : 0.002490736744392
# row: 55 and error: 8.67 and column: ccsys, sys_shift is:0.2256058788572357
# df.at[i, column_to_modify] shifted: 0.002372431762374639
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D1_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D1_datacc-thexp.dat
# df.at[i, column_to_modify] : 5.373620600329519
# row: 0 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 5.4898011708344265
# df.at[i, column_to_modify] : 6.608580409325716
# row: 1 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 6.751461475796232
# df.at[i, column_to_modify] : 6.300821029694953
# row: 2 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 6.437048172682008
# df.at[i, column_to_modify] : 5.696349852817404
# row: 3 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 5.819508003516634
# df.at[i, column_to_modify] : 4.607184371777651
# row: 4 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 4.706794178376501
# df.at[i, column_to_modify] : 3.5021963494426034
# row: 5 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.5779157200795058
# df.at[i, column_to_modify] : 2.9941221031640732
# row: 6 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.0588566350522424
# df.at[i, column_to_modify] : 1.9931908476590312
# row: 7 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 2.03628470690767
# df.at[i, column_to_modify] : 4.658286853107284
# row: 8 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 4.7590015228657565
# df.at[i, column_to_modify] : 5.916585264804563
# row: 9 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 6.044505023684407
# df.at[i, column_to_modify] : 5.867270159690782
# row: 10 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 5.994123699447104
# df.at[i, column_to_modify] : 4.9955358270272825
# row: 11 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 5.103542001174773
# df.at[i, column_to_modify] : 3.8677481195119983
# row: 12 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.951370916228728
# df.at[i, column_to_modify] : 3.2475529778255616
# row: 13 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.3177668216696072
# df.at[i, column_to_modify] : 2.0986098125716945
# row: 14 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 2.143982886598697
# df.at[i, column_to_modify] : 1.4078635540807494
# row: 15 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.4383023221054472
# df.at[i, column_to_modify] : 4.2465498323751945
# row: 16 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 4.338362526068645
# df.at[i, column_to_modify] : 4.61733861906103
# row: 17 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 4.717167965953133
# df.at[i, column_to_modify] : 3.9763228148763887
# row: 18 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 4.062293054962875
# df.at[i, column_to_modify] : 3.360037476531642
# row: 19 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.4326832957987063
# df.at[i, column_to_modify] : 2.175033934169802
# row: 20 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 2.2220593388520538
# df.at[i, column_to_modify] : 1.396938973660023
# row: 21 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.4271415463742947
# df.at[i, column_to_modify] : 1.0466175005905975
# row: 22 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.0692459344460838
# df.at[i, column_to_modify] : 0.5015769085834781
# row: 23 and error: 3.33 and column: ccsys, sys_shift is:0.017505438946328843
# df.at[i, column_to_modify] shifted: 0.4949406387402222
# df.at[i, column_to_modify] : 3.0539730154345937
# row: 24 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.120001556269431
# df.at[i, column_to_modify] : 3.351550777004414
# row: 25 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.424013109258511
# df.at[i, column_to_modify] : 3.1671516084972415
# row: 26 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 3.2356271314487834
# df.at[i, column_to_modify] : 2.179926141410019
# row: 27 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 2.2270573182467395
# df.at[i, column_to_modify] : 1.3883802496936462
# row: 28 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.418397778187798
# df.at[i, column_to_modify] : 1.000020423124481
# row: 29 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.021641403077557
# df.at[i, column_to_modify] : 0.4629076807053487
# row: 30 and error: 3.33 and column: ccsys, sys_shift is:0.017505438946328843
# df.at[i, column_to_modify] shifted: 0.45678303615113236
# df.at[i, column_to_modify] : 0.10566737413818914
# row: 31 and error: 6.0 and column: ccsys, sys_shift is:0.0210954937497191
# df.at[i, column_to_modify] shifted: 0.10413263078004328
# df.at[i, column_to_modify] : 0.004563142610789953
# row: 32 and error: 8.67 and column: ccsys, sys_shift is:0.004031701732441964
# df.at[i, column_to_modify] shifted: 0.004592116596362088
# df.at[i, column_to_modify] : 2.2125127571104692
# row: 33 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 2.2603484741230764
# df.at[i, column_to_modify] : 2.003497167742759
# row: 34 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 2.04681385518047
# df.at[i, column_to_modify] : 1.3495141573924487
# row: 35 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.3786913800457727
# df.at[i, column_to_modify] : 0.9709455322717057
# row: 36 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 0.9919378974307941
# df.at[i, column_to_modify] : 0.4223086908086949
# row: 37 and error: 3.33 and column: ccsys, sys_shift is:0.017505438946328843
# df.at[i, column_to_modify] shifted: 0.4167212038622295
# df.at[i, column_to_modify] : 0.09037231299874497
# row: 38 and error: 6.0 and column: ccsys, sys_shift is:0.0210954937497191
# df.at[i, column_to_modify] shifted: 0.08905971951124413
# df.at[i, column_to_modify] : 0.003671517232007275
# row: 39 and error: 8.67 and column: ccsys, sys_shift is:0.004031701732441964
# df.at[i, column_to_modify] shifted: 0.0036948297813579087
# df.at[i, column_to_modify] : 1.5915971116102559
# row: 40 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.6260082980698103
# df.at[i, column_to_modify] : 1.2817124703553022
# row: 41 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.309423784030853
# df.at[i, column_to_modify] : 0.9364191727042512
# row: 42 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 0.956665059380702
# df.at[i, column_to_modify] : 0.3916191182651821
# row: 43 and error: 3.33 and column: ccsys, sys_shift is:0.017505438946328843
# df.at[i, column_to_modify] shifted: 0.3864376792872089
# df.at[i, column_to_modify] : 0.07775749296359831
# row: 44 and error: 6.0 and column: ccsys, sys_shift is:0.0210954937497191
# df.at[i, column_to_modify] shifted: 0.0766281207534411
# df.at[i, column_to_modify] : 0.0030293325287823664
# row: 45 and error: 8.67 and column: ccsys, sys_shift is:0.004031701732441964
# df.at[i, column_to_modify] shifted: 0.00304856748251241
# df.at[i, column_to_modify] : 1.1521632101284622
# row: 46 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 1.1770735990493475
# df.at[i, column_to_modify] : 0.8824322863281419
# row: 47 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 0.9015109474549184
# df.at[i, column_to_modify] : 0.3619300272405722
# row: 48 and error: 3.33 and column: ccsys, sys_shift is:0.017505438946328843
# df.at[i, column_to_modify] shifted: 0.357141399048081
# df.at[i, column_to_modify] : 0.0700557795317965
# row: 49 and error: 6.0 and column: ccsys, sys_shift is:0.0210954937497191
# df.at[i, column_to_modify] shifted: 0.06903826922444707
# df.at[i, column_to_modify] : 0.0023264404316159708
# row: 50 and error: 8.67 and column: ccsys, sys_shift is:0.004031701732441964
# df.at[i, column_to_modify] shifted: 0.0023412123239825782
# df.at[i, column_to_modify] : 0.8248406830810345
# row: 51 and error: 2.0 and column: ccsys, sys_shift is:0.04674476804520065
# df.at[i, column_to_modify] shifted: 0.8426741827386276
# df.at[i, column_to_modify] : 0.33822023757126896
# row: 52 and error: 3.33 and column: ccsys, sys_shift is:0.017505438946328843
# df.at[i, column_to_modify] shifted: 0.3337453091513943
# df.at[i, column_to_modify] : 0.06581710099796727
# row: 53 and error: 6.0 and column: ccsys, sys_shift is:0.0210954937497191
# df.at[i, column_to_modify] shifted: 0.06486115447773914
# df.at[i, column_to_modify] : 0.0023336379992299696
# row: 54 and error: 8.67 and column: ccsys, sys_shift is:0.004031701732441964
# df.at[i, column_to_modify] shifted: 0.002348455593043582
# df.at[i, column_to_modify] : 0.001645712142997377
# row: 55 and error: 8.67 and column: ccsys, sys_shift is:0.004031701732441964
# df.at[i, column_to_modify] shifted: 0.0016561617046162362
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D2_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D2_datacc-thexp.dat
# df.at[i, column_to_modify] : 1.531886304712879
# row: 0 and error: 0.05 and column: eelen, sys_shift is:7.652088156336355e-05
# row: 0 and error: 0.27 and column: ethee, sys_shift is:0.0005990261069124233
# row: 0 and error: 0.07 and column: ehadr, sys_shift is:0.0006320464813127589
# row: 0 and error: 0.3 and column: radco, sys_shift is:0.0006568223780580448
# row: 0 and error: 1.0 and column: egamp, sys_shift is:0.0007343847079722101
# row: 0 and error: 0.5 and column: effic, sys_shift is:0.0012043212487463408
# row: 0 and error: 0.0 and column: enois, sys_shift is:0.0012043212487463408
# df.at[i, column_to_modify] shifted: 1.54129975573769
# df.at[i, column_to_modify] : 1.2822329871239477
# row: 1 and error: 0.06 and column: eelen, sys_shift is:3.656256640555633e-07
# row: 1 and error: 0.5 and column: ethee, sys_shift is:0.0004703021664381861
# row: 1 and error: 0.07 and column: ehadr, sys_shift is:0.0005033225408385218
# row: 1 and error: 0.3 and column: radco, sys_shift is:0.0005280984375838077
# row: 1 and error: 0.0 and column: egamp, sys_shift is:0.0005280984375838077
# row: 1 and error: 0.5 and column: effic, sys_shift is:0.0009980349783579381
# row: 1 and error: 0.0 and column: enois, sys_shift is:0.0009980349783579381
# df.at[i, column_to_modify] shifted: 1.2877767566601672
# df.at[i, column_to_modify] : 1.1836106923763696
# row: 2 and error: 0.07 and column: eelen, sys_shift is:3.302037440033565e-05
# row: 2 and error: 0.6 and column: ethee, sys_shift is:0.004203817708790309
# row: 2 and error: 0.1 and column: ehadr, sys_shift is:0.004374563677148511
# row: 2 and error: 0.3 and column: radco, sys_shift is:0.004399339573893797
# row: 2 and error: 0.0 and column: egamp, sys_shift is:0.004399339573893797
# row: 2 and error: 0.5 and column: effic, sys_shift is:0.004869276114667927
# row: 2 and error: 0.0 and column: enois, sys_shift is:0.004869276114667927
# df.at[i, column_to_modify] shifted: 1.1921850695059648
# df.at[i, column_to_modify] : 1.0012921810266873
# row: 3 and error: 0.08 and column: eelen, sys_shift is:4.422992661933775e-06
# row: 3 and error: 0.68 and column: ethee, sys_shift is:0.0006095433217532233
# row: 3 and error: 0.1 and column: ehadr, sys_shift is:0.0007802892901114249
# row: 3 and error: 0.3 and column: radco, sys_shift is:0.0008050651868567108
# row: 3 and error: 0.0 and column: egamp, sys_shift is:0.0008050651868567108
# row: 3 and error: 0.5 and column: effic, sys_shift is:0.0012750017276308414
# row: 3 and error: 0.0 and column: enois, sys_shift is:0.0012750017276308414
# df.at[i, column_to_modify] shifted: 1.0049054401116835
# df.at[i, column_to_modify] : 0.8355976497340745
# row: 4 and error: 0.08 and column: eelen, sys_shift is:4.422992661933775e-06
# row: 4 and error: 0.74 and column: ethee, sys_shift is:0.007613999969769713
# row: 4 and error: 0.1 and column: ehadr, sys_shift is:0.007784745938127915
# row: 4 and error: 0.3 and column: radco, sys_shift is:0.007809521834873201
# row: 4 and error: 0.0 and column: egamp, sys_shift is:0.007809521834873201
# row: 4 and error: 0.5 and column: effic, sys_shift is:0.008279458375647331
# row: 4 and error: 0.0 and column: enois, sys_shift is:0.008279458375647331
# df.at[i, column_to_modify] shifted: 0.8292576139487217
# df.at[i, column_to_modify] : 0.748253046620108
# row: 5 and error: 0.09 and column: eelen, sys_shift is:5.602328970535482e-07
# row: 5 and error: 0.77 and column: ethee, sys_shift is:0.0029188701237416515
# row: 5 and error: 0.09 and column: ehadr, sys_shift is:0.002919430356638705
# row: 5 and error: 0.3 and column: radco, sys_shift is:0.002944206253383991
# row: 5 and error: 0.0 and column: egamp, sys_shift is:0.002944206253383991
# row: 5 and error: 0.5 and column: effic, sys_shift is:0.0034141427941581214
# row: 5 and error: 0.0 and column: enois, sys_shift is:0.0034141427941581214
# df.at[i, column_to_modify] shifted: 0.7544142309846149
# df.at[i, column_to_modify] : 0.6338396907402406
# row: 6 and error: 0.09 and column: eelen, sys_shift is:5.602328970535482e-07
# row: 6 and error: 0.79 and column: ethee, sys_shift is:0.01593729486880697
# row: 6 and error: 0.09 and column: ehadr, sys_shift is:0.01593785510170402
# row: 6 and error: 0.3 and column: radco, sys_shift is:0.015962630998449308
# row: 6 and error: 0.0 and column: egamp, sys_shift is:0.015962630998449308
# row: 6 and error: 0.5 and column: effic, sys_shift is:0.01643256753922344
# row: 6 and error: 1.71 and column: enois, sys_shift is:0.018467345685918114
# df.at[i, column_to_modify] shifted: 0.6465526369002557
# df.at[i, column_to_modify] : 0.5396210789656547
# row: 7 and error: 0.09 and column: eelen, sys_shift is:5.602328970535482e-07
# row: 7 and error: 0.8 and column: ethee, sys_shift is:0.005985297667235148
# row: 7 and error: 0.08 and column: ehadr, sys_shift is:0.005989720659897082
# row: 7 and error: 0.3 and column: radco, sys_shift is:0.006014496556642368
# row: 7 and error: 0.0 and column: egamp, sys_shift is:0.006014496556642368
# row: 7 and error: 0.5 and column: effic, sys_shift is:0.006484433097416498
# row: 7 and error: 2.0 and column: enois, sys_shift is:0.0071916867701110965
# df.at[i, column_to_modify] shifted: 0.5466217260977797
# df.at[i, column_to_modify] : 0.49657984734127436
# row: 8 and error: 0.09 and column: eelen, sys_shift is:5.602328970535482e-07
# row: 8 and error: 0.78 and column: ethee, sys_shift is:0.010744836566297144
# row: 8 and error: 0.08 and column: ehadr, sys_shift is:0.010749259558959078
# row: 8 and error: 0.3 and column: radco, sys_shift is:0.010774035455704363
# row: 8 and error: 0.0 and column: egamp, sys_shift is:0.010774035455704363
# row: 8 and error: 0.5 and column: effic, sys_shift is:0.011243971996478494
# row: 8 and error: 2.17 and column: enois, sys_shift is:0.018183162610059554
# df.at[i, column_to_modify] shifted: 0.488572202709993
# df.at[i, column_to_modify] : 1.751115306239446
# row: 9 and error: 0.08 and column: eelen, sys_shift is:4.422992661933775e-06
# row: 9 and error: 0.32 and column: ethee, sys_shift is:0.00034649413397529964
# row: 9 and error: 0.06 and column: ehadr, sys_shift is:0.0003468597596393552
# row: 9 and error: 0.3 and column: radco, sys_shift is:0.00037163565638464107
# row: 9 and error: 1.0 and column: egamp, sys_shift is:0.00044919798629880633
# row: 9 and error: 0.5 and column: effic, sys_shift is:0.0009191345270729369
# row: 9 and error: 0.0 and column: enois, sys_shift is:0.0009191345270729369
# df.at[i, column_to_modify] shifted: 1.7538181314153236
# df.at[i, column_to_modify] : 1.6660315563345844
# row: 10 and error: 0.08 and column: eelen, sys_shift is:4.422992661933775e-06
# row: 10 and error: 0.37 and column: ethee, sys_shift is:0.002267893099274606
# row: 10 and error: 0.06 and column: ehadr, sys_shift is:0.0022682587249386616
# row: 10 and error: 0.3 and column: radco, sys_shift is:0.0022930346216839476
# row: 10 and error: 0.0 and column: egamp, sys_shift is:0.0022930346216839476
# row: 10 and error: 0.5 and column: effic, sys_shift is:0.002762971162458078
# row: 10 and error: 0.0 and column: enois, sys_shift is:0.002762971162458078
# df.at[i, column_to_modify] shifted: 1.662277678212091
# df.at[i, column_to_modify] : 1.48735407558154
# row: 11 and error: 0.07 and column: eelen, sys_shift is:3.302037440033565e-05
# row: 11 and error: 0.39 and column: ethee, sys_shift is:0.00045866202194960547
# row: 11 and error: 0.09 and column: ehadr, sys_shift is:0.00045922225484665904
# row: 11 and error: 0.3 and column: radco, sys_shift is:0.0004839981515919449
# row: 11 and error: 0.0 and column: egamp, sys_shift is:0.0004839981515919449
# row: 11 and error: 0.5 and column: effic, sys_shift is:0.0009539346923660755
# row: 11 and error: 0.0 and column: enois, sys_shift is:0.0009539346923660755
# df.at[i, column_to_modify] shifted: 1.493650120127489
# df.at[i, column_to_modify] : 1.2873721891040153
# row: 12 and error: 0.07 and column: eelen, sys_shift is:3.302037440033565e-05
# row: 12 and error: 0.4 and column: ethee, sys_shift is:0.0033136992451221372
# row: 12 and error: 0.11 and column: ehadr, sys_shift is:0.003354137839382987
# row: 12 and error: 0.3 and column: radco, sys_shift is:0.003378913736128273
# row: 12 and error: 0.0 and column: egamp, sys_shift is:0.003378913736128273
# ...
# row: 132 and error: 0.3 and column: radco, sys_shift is:0.001443355211692271
# row: 132 and error: 0.0 and column: egamp, sys_shift is:0.001443355211692271
# row: 132 and error: 0.5 and column: effic, sys_shift is:0.005084749186692937
# row: 132 and error: 0.0 and column: enois, sys_shift is:0.005084749186692937
# df.at[i, column_to_modify] shifted: 0.14576322160571656
# df.at[i, column_to_modify] : 0.06870363241382105
# row: 133 and error: 0.47 and column: eelen, sys_shift is:0.00012854772708655715
# row: 133 and error: 0.03 and column: ethee, sys_shift is:0.00012917848406936397
# row: 133 and error: 1.8 and column: ehadr, sys_shift is:0.011966255812780428
# row: 133 and error: 0.3 and column: radco, sys_shift is:0.01303355800001287
# row: 133 and error: 0.0 and column: egamp, sys_shift is:0.01303355800001287
# row: 133 and error: 0.5 and column: effic, sys_shift is:0.016674951975013536
# row: 133 and error: 0.0 and column: enois, sys_shift is:0.016674951975013536
# df.at[i, column_to_modify] shifted: 0.06851724746075764
# df.at[i, column_to_modify] : 0.02465466670710493
# row: 134 and error: 0.67 and column: eelen, sys_shift is:0.004493528911220982
# row: 134 and error: 0.04 and column: ethee, sys_shift is:0.004493875733197269
# row: 134 and error: 2.8 and column: ehadr, sys_shift is:0.005448209787061064
# row: 134 and error: 0.3 and column: radco, sys_shift is:0.006515511974293507
# row: 134 and error: 0.0 and column: egamp, sys_shift is:0.006515511974293507
# row: 134 and error: 0.5 and column: effic, sys_shift is:0.010156905949294172
# row: 134 and error: 0.0 and column: enois, sys_shift is:0.010156905949294172
# df.at[i, column_to_modify] shifted: 0.025127193941273034
# df.at[i, column_to_modify] : 0.007073439731863122
# row: 135 and error: 1.0 and column: eelen, sys_shift is:0.007767710443942143
# row: 135 and error: 0.06 and column: ethee, sys_shift is:0.007844882722526153
# row: 135 and error: 4.43 and column: ehadr, sys_shift is:0.017058723554550296
# row: 135 and error: 0.3 and column: radco, sys_shift is:0.01812602574178274
# row: 135 and error: 0.0 and column: egamp, sys_shift is:0.01812602574178274
# row: 135 and error: 0.5 and column: effic, sys_shift is:0.021767419716783407
# row: 135 and error: 0.0 and column: enois, sys_shift is:0.021767419716783407
# df.at[i, column_to_modify] shifted: 0.007150651304465699
# df.at[i, column_to_modify] : 0.0014454473323250443
# row: 136 and error: 1.73 and column: eelen, sys_shift is:0.07834928833240207
# row: 136 and error: 0.1 and column: ethee, sys_shift is:0.07840721252346323
# row: 136 and error: 8.02 and column: ehadr, sys_shift is:0.15233737175239637
# row: 136 and error: 0.3 and column: radco, sys_shift is:0.1534046739396288
# row: 136 and error: 0.0 and column: egamp, sys_shift is:0.1534046739396288
# row: 136 and error: 0.5 and column: effic, sys_shift is:0.15704606791462947
# row: 136 and error: 0.0 and column: enois, sys_shift is:0.15704606791462947
# df.at[i, column_to_modify] shifted: 0.0014555331127265845
# df.at[i, column_to_modify] : 0.8525705776655538
# row: 137 and error: 0.15 and column: eelen, sys_shift is:0.00014478774141619163
# row: 137 and error: 0.0 and column: ethee, sys_shift is:0.00014478774141619163
# row: 137 and error: 0.08 and column: ehadr, sys_shift is:0.0002508709436580068
# row: 137 and error: 0.3 and column: radco, sys_shift is:0.0013181731308904495
# row: 137 and error: 1.0 and column: egamp, sys_shift is:0.009085883574832592
# row: 137 and error: 0.5 and column: effic, sys_shift is:0.012727277549833257
# row: 137 and error: 0.0 and column: enois, sys_shift is:0.012727277549833257
# df.at[i, column_to_modify] shifted: 0.852784430343964
# df.at[i, column_to_modify] : 0.45633479867385257
# row: 138 and error: 0.19 and column: eelen, sys_shift is:1.6576383394220087e-05
# row: 138 and error: 0.01 and column: ethee, sys_shift is:1.7326780880971027e-05
# row: 138 and error: 0.28 and column: ehadr, sys_shift is:0.0012815348401055695
# row: 138 and error: 0.3 and column: radco, sys_shift is:0.0023488370273380124
# row: 138 and error: 0.0 and column: egamp, sys_shift is:0.0023488370273380124
# row: 138 and error: 0.5 and column: effic, sys_shift is:0.005990231002338678
# row: 138 and error: 0.0 and column: enois, sys_shift is:0.005990231002338678
# df.at[i, column_to_modify] shifted: 0.45909775754898163
# df.at[i, column_to_modify] : 0.281321654161665
# row: 139 and error: 0.25 and column: eelen, sys_shift is:5.727729423570527e-06
# row: 139 and error: 0.01 and column: ethee, sys_shift is:6.478126910321466e-06
# row: 139 and error: 0.64 and column: ehadr, sys_shift is:0.00041607156682353874
# row: 139 and error: 0.3 and column: radco, sys_shift is:0.0014833737540559814
# row: 139 and error: 0.0 and column: egamp, sys_shift is:0.0014833737540559814
# row: 139 and error: 0.5 and column: effic, sys_shift is:0.005124767729056647
# row: 139 and error: 0.0 and column: enois, sys_shift is:0.005124767729056647
# df.at[i, column_to_modify] shifted: 0.2845619707219873
# df.at[i, column_to_modify] : 0.15916812218844234
# row: 140 and error: 0.34 and column: eelen, sys_shift is:0.00017545166572966307
# row: 140 and error: 0.01 and column: ethee, sys_shift is:0.00017620206321641401
# row: 140 and error: 1.13 and column: ehadr, sys_shift is:0.012857744475815733
# row: 140 and error: 0.3 and column: radco, sys_shift is:0.013925046663048175
# row: 140 and error: 0.0 and column: egamp, sys_shift is:0.013925046663048175
# row: 140 and error: 0.5 and column: effic, sys_shift is:0.017566440638048842
# row: 140 and error: 0.0 and column: enois, sys_shift is:0.017566440638048842
# df.at[i, column_to_modify] shifted: 0.1622316290885511
# df.at[i, column_to_modify] : 0.07098414852491339
# row: 141 and error: 0.48 and column: eelen, sys_shift is:0.00045247061944112855
# row: 141 and error: 0.02 and column: ethee, sys_shift is:0.0004524719674744953
# row: 141 and error: 1.81 and column: ehadr, sys_shift is:0.25658280256901667
# row: 141 and error: 0.3 and column: radco, sys_shift is:0.2576501047562491
# row: 141 and error: 0.0 and column: egamp, sys_shift is:0.2576501047562491
# row: 141 and error: 0.5 and column: effic, sys_shift is:0.2612914987312498
# row: 141 and error: 0.0 and column: enois, sys_shift is:0.2612914987312498
# df.at[i, column_to_modify] shifted: 0.07543213195339532
# df.at[i, column_to_modify] : 0.028581530954529342
# row: 142 and error: 0.68 and column: eelen, sys_shift is:0.0021490333410713234
# row: 142 and error: 0.03 and column: ethee, sys_shift is:0.0021496640980541303
# row: 142 and error: 2.82 and column: ehadr, sys_shift is:0.008847194088990882
# row: 142 and error: 0.3 and column: radco, sys_shift is:0.009914496276223324
# row: 142 and error: 0.0 and column: egamp, sys_shift is:0.009914496276223324
# row: 142 and error: 0.5 and column: effic, sys_shift is:0.01355589025122399
# row: 142 and error: 0.0 and column: enois, sys_shift is:0.01355589025122399
# df.at[i, column_to_modify] shifted: 0.028481478289530977
# df.at[i, column_to_modify] : 0.00741306748075923
# row: 143 and error: 1.01 and column: eelen, sys_shift is:0.015101467476964201
# row: 143 and error: 0.04 and column: ethee, sys_shift is:0.015101814298940489
# row: 143 and error: 4.46 and column: ehadr, sys_shift is:0.045029322966087026
# row: 143 and error: 0.3 and column: radco, sys_shift is:0.04609662515331947
# row: 143 and error: 0.0 and column: egamp, sys_shift is:0.04609662515331947
# row: 143 and error: 0.5 and column: effic, sys_shift is:0.049738019128320134
# row: 143 and error: 0.0 and column: enois, sys_shift is:0.049738019128320134
# df.at[i, column_to_modify] shifted: 0.007261943061522447
# df.at[i, column_to_modify] : 0.0013289970435636559
# row: 144 and error: 1.74 and column: eelen, sys_shift is:0.005844253619324572
# row: 144 and error: 0.07 and column: ethee, sys_shift is:0.005915543061114452
# row: 144 and error: 8.09 and column: ehadr, sys_shift is:0.5690077290446504
# row: 144 and error: 0.3 and column: radco, sys_shift is:0.5700750312318827
# row: 144 and error: 0.0 and column: egamp, sys_shift is:0.5700750312318827
# row: 144 and error: 0.5 and column: effic, sys_shift is:0.5737164252068834
# row: 144 and error: 0.0 and column: enois, sys_shift is:0.5737164252068834
# df.at[i, column_to_modify] shifted: 0.00143222568774092
# df.at[i, column_to_modify] : 0.5664192756460211
# row: 145 and error: 0.19 and column: eelen, sys_shift is:1.6576383394220087e-05
# row: 145 and error: 0.0 and column: ethee, sys_shift is:1.6576383394220087e-05
# row: 145 and error: 0.24 and column: ehadr, sys_shift is:2.805114241841437e-05
# row: 145 and error: 0.3 and column: radco, sys_shift is:0.001095353329650857
# row: 145 and error: 1.0 and column: egamp, sys_shift is:0.008863063773593
# row: 145 and error: 0.5 and column: effic, sys_shift is:0.012504457748593666
# row: 145 and error: 0.0 and column: enois, sys_shift is:0.012504457748593666
# df.at[i, column_to_modify] shifted: 0.5670830044491797
# df.at[i, column_to_modify] : 0.3508077974077179
# row: 146 and error: 0.25 and column: eelen, sys_shift is:5.727729423570527e-06
# row: 146 and error: 0.01 and column: ethee, sys_shift is:6.478126910321466e-06
# row: 146 and error: 0.58 and column: ehadr, sys_shift is:0.032478539021669195
# row: 146 and error: 0.3 and column: radco, sys_shift is:0.03354584120890164
# row: 146 and error: 0.0 and column: egamp, sys_shift is:0.03354584120890164
# row: 146 and error: 0.5 and column: effic, sys_shift is:0.0371872351839023
# row: 146 and error: 0.0 and column: enois, sys_shift is:0.0371872351839023
# df.at[i, column_to_modify] shifted: 0.3477503056806297
# df.at[i, column_to_modify] : 0.1458731951371925
# row: 147 and error: 0.35 and column: eelen, sys_shift is:0.0036351147434314944
# row: 147 and error: 0.01 and column: ethee, sys_shift is:0.0036358651409182452
# row: 147 and error: 1.08 and column: ehadr, sys_shift is:0.06220990890400119
# row: 147 and error: 0.3 and column: radco, sys_shift is:0.06327721109123363
# row: 147 and error: 0.0 and column: egamp, sys_shift is:0.06327721109123363
# row: 147 and error: 0.5 and column: effic, sys_shift is:0.0669186050662343
# row: 147 and error: 0.0 and column: enois, sys_shift is:0.0669186050662343
# df.at[i, column_to_modify] shifted: 0.15169226855082815
# df.at[i, column_to_modify] : 0.06590282952431449
# row: 148 and error: 0.48 and column: eelen, sys_shift is:0.00045247061944112855
# row: 148 and error: 0.01 and column: ethee, sys_shift is:0.00045322101692787947
# row: 148 and error: 1.78 and column: ehadr, sys_shift is:0.022359278997449397
# row: 148 and error: 0.3 and column: radco, sys_shift is:0.02342658118468184
# row: 148 and error: 0.0 and column: egamp, sys_shift is:0.02342658118468184
# row: 148 and error: 0.5 and column: effic, sys_shift is:0.027067975159682508
# row: 148 and error: 0.0 and column: enois, sys_shift is:0.027067975159682508
# df.at[i, column_to_modify] shifted: 0.06566632274154391
# df.at[i, column_to_modify] : 0.029306643129103332
# row: 149 and error: 0.69 and column: eelen, sys_shift is:0.0006495256021659286
# row: 149 and error: 0.02 and column: ethee, sys_shift is:0.0006495269501992954
# row: 149 and error: 2.81 and column: ehadr, sys_shift is:0.08419655745614615
# row: 149 and error: 0.3 and column: radco, sys_shift is:0.0852638596433786
# row: 149 and error: 0.0 and column: egamp, sys_shift is:0.0852638596433786
# row: 149 and error: 0.5 and column: effic, sys_shift is:0.08890525361837927
# row: 149 and error: 0.0 and column: enois, sys_shift is:0.08890525361837927
# df.at[i, column_to_modify] shifted: 0.028651720318685316
# df.at[i, column_to_modify] : 0.006159897063011664
# row: 150 and error: 1.02 and column: eelen, sys_shift is:5.114049482135545e-07
# row: 150 and error: 0.03 and column: ethee, sys_shift is:1.142161931020356e-06
# row: 150 and error: 4.47 and column: ehadr, sys_shift is:0.1094433397020161
# row: 150 and error: 0.3 and column: radco, sys_shift is:0.11051064188924854
# row: 150 and error: 0.0 and column: egamp, sys_shift is:0.11051064188924854
# row: 150 and error: 0.5 and column: effic, sys_shift is:0.11415203586424921
# row: 150 and error: 0.0 and column: enois, sys_shift is:0.11415203586424921
# df.at[i, column_to_modify] shifted: 0.00601253979534475
# df.at[i, column_to_modify] : 0.0017465257946622573
# row: 151 and error: 1.76 and column: eelen, sys_shift is:0.005227543609976914
# row: 151 and error: 0.05 and column: ethee, sys_shift is:0.005227675361399925
# row: 151 and error: 8.13 and column: ehadr, sys_shift is:0.01978065207131502
# row: 151 and error: 0.3 and column: radco, sys_shift is:0.020847954258547463
# row: 151 and error: 0.0 and column: egamp, sys_shift is:0.020847954258547463
# row: 151 and error: 0.5 and column: effic, sys_shift is:0.02448934823354813
# row: 151 and error: 0.0 and column: enois, sys_shift is:0.02448934823354813
# df.at[i, column_to_modify] shifted: 0.001771107575929488
# df.at[i, column_to_modify] : 0.22243122043096808
# row: 152 and error: 0.35 and column: eelen, sys_shift is:0.0036351147434314944
# row: 152 and error: 0.0 and column: ethee, sys_shift is:0.0036351147434314944
# row: 152 and error: 1.06 and column: ehadr, sys_shift is:0.007108431599453705
# row: 152 and error: 0.3 and column: radco, sys_shift is:0.008175733786686148
# row: 152 and error: 1.0 and column: egamp, sys_shift is:0.015943444230628292
# row: 152 and error: 0.5 and column: effic, sys_shift is:0.01958483820562896
# row: 152 and error: 0.0 and column: enois, sys_shift is:0.01958483820562896
# df.at[i, column_to_modify] shifted: 0.2225481464900169
# df.at[i, column_to_modify] : 0.10443692935247295
# row: 153 and error: 0.49 and column: eelen, sys_shift is:0.007394690383637981
# row: 153 and error: 0.01 and column: ethee, sys_shift is:0.007395440781124732
# row: 153 and error: 1.73 and column: ehadr, sys_shift is:0.0857447291135268
# row: 153 and error: 0.3 and column: radco, sys_shift is:0.08681203130075925
# row: 153 and error: 1.0 and column: egamp, sys_shift is:0.09457974174470139
# row: 153 and error: 0.5 and column: effic, sys_shift is:0.09822113571970206
# row: 153 and error: 0.0 and column: enois, sys_shift is:0.09822113571970206
# df.at[i, column_to_modify] shifted: 0.10067479776173988
# df.at[i, column_to_modify] : 0.042916903344416044
# row: 154 and error: 0.7 and column: eelen, sys_shift is:0.0011545470853278473
# row: 154 and error: 0.01 and column: ethee, sys_shift is:0.0011552974828145982
# row: 154 and error: 2.76 and column: ehadr, sys_shift is:0.07457955941514464
# row: 154 and error: 0.3 and column: radco, sys_shift is:0.07564686160237709
# row: 154 and error: 0.0 and column: egamp, sys_shift is:0.07564686160237709
# row: 154 and error: 0.5 and column: effic, sys_shift is:0.07928825557737776
# row: 154 and error: 0.0 and column: enois, sys_shift is:0.07928825557737776
# df.at[i, column_to_modify] shifted: 0.04463799607465023
# df.at[i, column_to_modify] : 0.0018786207709452912
# row: 155 and error: 1.03 and column: eelen, sys_shift is:1.06921485481559e-06
# row: 155 and error: 0.02 and column: ethee, sys_shift is:1.0705628881823442e-06
# row: 155 and error: 4.44 and column: ehadr, sys_shift is:0.006403778381757518
# row: 155 and error: 0.3 and column: radco, sys_shift is:0.007471080568989961
# row: 155 and error: 0.0 and column: egamp, sys_shift is:0.007471080568989961
# row: 155 and error: 0.5 and column: effic, sys_shift is:0.011112474543990628
# row: 155 and error: 0.0 and column: enois, sys_shift is:0.011112474543990628
# df.at[i, column_to_modify] shifted: 0.0018811606684082168
# df.at[i, column_to_modify] : -0.0009239080058705605
# row: 156 and error: 1.78 and column: eelen, sys_shift is:0.021906057980521518
# row: 156 and error: 0.03 and column: ethee, sys_shift is:0.021906688737504326
# row: 156 and error: 8.14 and column: ehadr, sys_shift is:0.8565447494144699
# row: 156 and error: 0.3 and column: radco, sys_shift is:0.8576120516017023
# row: 156 and error: 0.0 and column: egamp, sys_shift is:0.8576120516017023
# row: 156 and error: 0.5 and column: effic, sys_shift is:0.8612534455767029
# row: 156 and error: 0.0 and column: enois, sys_shift is:0.8612534455767029
# df.at[i, column_to_modify] shifted: -0.00100273021838433
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D7_datanc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D7_datanc-thexp.dat
