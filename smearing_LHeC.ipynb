# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC_Ee60/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for column in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , column))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std)

            sys_shift = 0.0
            for col in find_corr_err(df):
                print(f'row: {i} and error: {df.at[i, col]} and column: {col}, sysErrDict[df.at[i, col]] is:{sysErrDict[df.at[i, col]]}')
                sys_shift += sysErrDict[df.at[i, col]]**2
            
            sys_shift  = sys_shift**0.5
            sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift *0.0
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 23 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 30 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 31 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 32 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 36 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 37 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 38 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 39 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 43 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 44 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 45 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 46 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 47 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 48 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 49 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# row: 50 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 52 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 53 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 54 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 55 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 56 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 57 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 58 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 59 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 60 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# row: 61 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6509329941719852
# row: 62 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 63 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 64 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 65 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 66 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 67 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 68 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 69 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 70 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 71 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# row: 72 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6509329941719852
# row: 73 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 74 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 75 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 76 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 77 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 78 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 79 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 80 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 81 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# row: 82 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6509329941719852
# row: 83 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 84 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 85 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 86 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 87 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 88 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 89 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 90 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# row: 91 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6509329941719852
# row: 92 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 93 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 94 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 95 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 96 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 97 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 98 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# row: 99 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 100 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.7300576360826887
# row: 101 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 102 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 103 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 104 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# row: 105 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:3.2283371004345627
# row: 106 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.527342836248508
# row: 107 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:1.2272745536565062
# row: 108 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.71570861097507
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D6_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D6_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.3711408092224633
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.3711408092224633
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.810097996559241
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.245099054078754
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.3711408092224633
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.810097996559241
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.245099054078754
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.3711408092224633
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.810097996559241
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.245099054078754
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.3711408092224633
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.810097996559241
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.245099054078754
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8804488220025224
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.3711408092224633
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.810097996559241
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.245099054078754
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.245099054078754
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D1_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D1_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:0.6968743042536882
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:0.6968743042536882
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.3633812289013063
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.36162237853233
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:0.6968743042536882
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.3633812289013063
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.36162237853233
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:0.6968743042536882
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.3633812289013063
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.36162237853233
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:0.6968743042536882
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.3633812289013063
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.36162237853233
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:2.6944251575078653
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:0.6968743042536882
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.3633812289013063
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.36162237853233
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.36162237853233
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D2_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D2_datacc-thexp.dat
# row: 0 and error: 0.05 and column: eelen, sysErrDict[df.at[i, col]] is:0.010321330076645385
# row: 0 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.034591281150414856
# row: 0 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05060044456865163
# row: 0 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 0 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.040259896343165916
# row: 0 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 0 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.06 and column: eelen, sysErrDict[df.at[i, col]] is:-0.045273440280121306
# row: 1 and error: 0.5 and column: ethee, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 1 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05060044456865163
# row: 1 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 1 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 1 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.05060044456865163
# row: 2 and error: 0.6 and column: ethee, sysErrDict[df.at[i, col]] is:0.050826510070253815
# row: 2 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 2 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 2 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 2 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 3 and error: 0.68 and column: ethee, sysErrDict[df.at[i, col]] is:1.1036770457132155
# row: 3 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 3 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 3 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 3 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 4 and error: 0.74 and column: ethee, sysErrDict[df.at[i, col]] is:0.03926916998513602
# row: 4 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 4 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 4 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 4 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 5 and error: 0.77 and column: ethee, sysErrDict[df.at[i, col]] is:0.8438153684786522
# row: 5 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 5 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 5 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 5 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 6 and error: 0.79 and column: ethee, sysErrDict[df.at[i, col]] is:1.0259053897822967
# row: 6 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 6 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 6 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 6 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-2.8454759138405983
# row: 7 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 7 and error: 0.8 and column: ethee, sysErrDict[df.at[i, col]] is:-0.5057725180200338
# row: 7 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 7 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 7 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 7 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 7 and error: 2.0 and column: enois, sysErrDict[df.at[i, col]] is:2.45303797610106
# row: 8 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 8 and error: 0.78 and column: ethee, sysErrDict[df.at[i, col]] is:0.37895418258687363
# row: 8 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 8 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 8 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 8 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 8 and error: 2.17 and column: enois, sysErrDict[df.at[i, col]] is:2.676417178168641
# row: 9 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 9 and error: 0.32 and column: ethee, sysErrDict[df.at[i, col]] is:0.592132468009755
# row: 9 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.045273440280121306
# row: 9 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 9 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.040259896343165916
# row: 9 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 9 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 10 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:0.002694937505277758
# row: 10 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.045273440280121306
# row: 10 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 10 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 10 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.05060044456865163
# row: 11 and error: 0.39 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1376097271242384
# row: 11 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 11 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 11 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 11 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.05060044456865163
# row: 12 and error: 0.4 and column: ethee, sysErrDict[df.at[i, col]] is:0.4833049718806979
# row: 12 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 12 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 12 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 12 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.05060044456865163
# row: 13 and error: 0.41 and column: ethee, sysErrDict[df.at[i, col]] is:-0.818562774797605
# row: 13 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 13 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 13 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 13 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.05060044456865163
# row: 14 and error: 0.42 and column: ethee, sysErrDict[df.at[i, col]] is:-0.2188731596127039
# row: 14 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 14 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 14 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 14 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 15 and error: 0.44 and column: ethee, sysErrDict[df.at[i, col]] is:0.8219153114240894
# row: 15 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 15 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 15 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 15 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-2.8454759138405983
# row: 16 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 16 and error: 0.46 and column: ethee, sysErrDict[df.at[i, col]] is:0.9874455280025087
# row: 16 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 16 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 16 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 16 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 16 and error: 1.88 and column: enois, sysErrDict[df.at[i, col]] is:2.975412172711209
# row: 17 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 17 and error: 0.47 and column: ethee, sysErrDict[df.at[i, col]] is:-0.7191266380733987
# row: 17 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 17 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 17 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 17 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 17 and error: 2.15 and column: enois, sysErrDict[df.at[i, col]] is:2.6951730372300324
# row: 18 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 18 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:-0.09411815309995798
# row: 18 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03843123420522399
# row: 18 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 18 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.040259896343165916
# row: 18 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 18 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 19 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.034591281150414856
# row: 19 and error: 0.03 and column: ehadr, sysErrDict[df.at[i, col]] is:0.004530886663869072
# row: 19 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 19 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 19 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 20 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.030897175763769942
# row: 20 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 20 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 20 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 20 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 21 and error: 0.3 and column: ethee, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 21 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 21 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 21 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 21 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.09698108238798574
# row: 22 and error: 0.31 and column: ethee, sysErrDict[df.at[i, col]] is:0.08277090016192036
# row: 22 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 22 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 22 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 22 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 23 and error: 0.33 and column: ethee, sysErrDict[df.at[i, col]] is:-0.08621405971321308
# row: 23 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.14493790968098133
# row: 23 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 23 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 23 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 24 and error: 0.34 and column: ethee, sysErrDict[df.at[i, col]] is:-0.33469738092869006
# row: 24 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.14493790968098133
# row: 24 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 24 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 24 and error: 1.66 and column: enois, sysErrDict[df.at[i, col]] is:-1.9358094688380492
# row: 25 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 25 and error: 0.36 and column: ethee, sysErrDict[df.at[i, col]] is:0.7884159750835629
# row: 25 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.14493790968098133
# row: 25 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 25 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 25 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 25 and error: 1.93 and column: enois, sysErrDict[df.at[i, col]] is:0.5087697269076223
# row: 26 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 26 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:0.002694937505277758
# row: 26 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 26 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 26 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 26 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 26 and error: 2.22 and column: enois, sysErrDict[df.at[i, col]] is:1.9762785354901942
# row: 27 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 27 and error: 0.16 and column: ethee, sysErrDict[df.at[i, col]] is:0.058480473118478156
# row: 27 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.006203267155911255
# row: 27 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 27 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.040259896343165916
# row: 27 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 27 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 28 and error: 0.22 and column: ethee, sysErrDict[df.at[i, col]] is:-0.18419201836968305
# row: 28 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03843123420522399
# row: 28 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 28 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 28 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 29 and error: 0.23 and column: ethee, sysErrDict[df.at[i, col]] is:0.1337022589852652
# row: 29 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 29 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 29 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 29 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 30 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 30 and error: 0.24 and column: ethee, sysErrDict[df.at[i, col]] is:-0.21424451845179107
# row: 30 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 30 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 30 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 30 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 30 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 31 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 31 and error: 0.26 and column: ethee, sysErrDict[df.at[i, col]] is:-0.22053345556991916
# row: 31 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08171460367987982
# row: 31 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 31 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 31 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 31 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 32 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 32 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.034591281150414856
# row: 32 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08171460367987982
# row: 32 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 32 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 32 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 32 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 33 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 33 and error: 0.28 and column: ethee, sysErrDict[df.at[i, col]] is:-0.3231267394764237
# row: 33 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08171460367987982
# row: 33 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 33 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 33 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 33 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-2.8454759138405983
# row: 34 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 34 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.030897175763769942
# row: 34 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08171460367987982
# row: 34 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 34 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 34 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 34 and error: 2.0 and column: enois, sysErrDict[df.at[i, col]] is:2.45303797610106
# row: 35 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 35 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.030897175763769942
# row: 35 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.14493790968098133
# row: 35 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 35 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 35 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 35 and error: 2.17 and column: enois, sysErrDict[df.at[i, col]] is:2.676417178168641
# row: 36 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 36 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.14493790968098133
# row: 36 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.006203267155911255
# row: 36 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 36 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.040259896343165916
# row: 36 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 36 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 37 and error: 0.15 and column: ethee, sysErrDict[df.at[i, col]] is:0.04999509051037025
# row: 37 and error: 0.02 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.002270497508960998
# row: 37 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 37 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 37 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 38 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 38 and error: 0.17 and column: ethee, sysErrDict[df.at[i, col]] is:-0.04266712774122926
# row: 38 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013033671484507887
# row: 38 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 38 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 38 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 38 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 39 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 39 and error: 0.18 and column: ethee, sysErrDict[df.at[i, col]] is:0.12166399230304788
# row: 39 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08171460367987982
# row: 39 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 39 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 39 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 39 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 40 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.0025375305914640996
# row: 40 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:-0.09411815309995798
# row: 40 and error: 0.14 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.13482245712479085
# row: 40 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 40 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 40 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 40 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 41 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 41 and error: 0.2 and column: ethee, sysErrDict[df.at[i, col]] is:-0.38057763532352196
# row: 41 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04999509051037025
# row: 41 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 41 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 41 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 41 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 42 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 42 and error: 0.2 and column: ethee, sysErrDict[df.at[i, col]] is:-0.38057763532352196
# row: 42 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04999509051037025
# row: 42 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 42 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 42 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 42 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-2.8454759138405983
# row: 43 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.06467542363122099
# row: 43 and error: 0.21 and column: ethee, sysErrDict[df.at[i, col]] is:-0.05736819906611698
# row: 43 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04999509051037025
# row: 43 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 43 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 43 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.35496266544801636
# row: 43 and error: 1.88 and column: enois, sysErrDict[df.at[i, col]] is:2.975412172711209
# row: 44 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.14493790968098133
# row: 44 and error: 0.21 and column: ethee, sysErrDict[df.at[i, col]] is:-0.05736819906611698
# row: 44 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08171460367987982
# row: 44 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.43514964125734323
# row: 44 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# ...
# row: 131 and error: 0.66 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.40922673835123413
# row: 131 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 131 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 131 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 131 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 132 and error: 0.34 and column: eelen, sysErrDict[df.at[i, col]] is:0.10686820544806794
# row: 132 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.008298981065915992
# row: 132 and error: 1.14 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.7231296422985946
# row: 132 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 132 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 132 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 132 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 133 and error: 0.47 and column: eelen, sysErrDict[df.at[i, col]] is:-0.06873617063533187
# row: 133 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.01826512074636571
# row: 133 and error: 1.8 and column: ehadr, sysErrDict[df.at[i, col]] is:0.1713606170572809
# row: 133 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 133 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 133 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 133 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 134 and error: 0.67 and column: eelen, sysErrDict[df.at[i, col]] is:1.1205903673099356
# row: 134 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:-0.02185874092394782
# row: 134 and error: 2.8 and column: ehadr, sysErrDict[df.at[i, col]] is:2.649541787423237
# row: 134 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 134 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 134 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 134 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 135 and error: 1.0 and column: eelen, sysErrDict[df.at[i, col]] is:-0.4816239291088411
# row: 135 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:0.10063457448324152
# row: 135 and error: 4.43 and column: ehadr, sysErrDict[df.at[i, col]] is:-6.039471525528908
# row: 135 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 135 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 135 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 135 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 136 and error: 1.73 and column: eelen, sysErrDict[df.at[i, col]] is:1.6487716113060809
# row: 136 and error: 0.1 and column: ethee, sysErrDict[df.at[i, col]] is:0.12523238666472633
# row: 136 and error: 8.02 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.18654991876115404
# row: 136 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 136 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 136 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 136 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 137 and error: 0.15 and column: eelen, sysErrDict[df.at[i, col]] is:0.04217989283810409
# row: 137 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 137 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.09879428668256168
# row: 137 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 137 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.4816239291088411
# row: 137 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 137 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 138 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.2964844357890704
# row: 138 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 138 and error: 0.28 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.48016806963880626
# row: 138 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 138 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 138 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 138 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 139 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.028494155904159702
# row: 139 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 139 and error: 0.64 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.05154517303638718
# row: 139 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 139 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 139 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 139 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 140 and error: 0.34 and column: eelen, sysErrDict[df.at[i, col]] is:0.10686820544806794
# row: 140 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 140 and error: 1.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-2.235985577043729
# row: 140 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 140 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 140 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 140 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 141 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.2599004324820297
# row: 141 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.008298981065915992
# row: 141 and error: 1.81 and column: ehadr, sysErrDict[df.at[i, col]] is:1.322160551276515
# row: 141 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 141 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 141 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 141 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 142 and error: 0.68 and column: eelen, sysErrDict[df.at[i, col]] is:0.2578123807513215
# row: 142 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.01826512074636571
# row: 142 and error: 2.82 and column: ehadr, sysErrDict[df.at[i, col]] is:0.666877524809753
# row: 142 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 142 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 142 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 142 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 143 and error: 1.01 and column: eelen, sysErrDict[df.at[i, col]] is:-0.4367578747872161
# row: 143 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:-0.02185874092394782
# row: 143 and error: 4.46 and column: ehadr, sysErrDict[df.at[i, col]] is:2.123480314001047
# row: 143 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 143 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 143 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 143 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 144 and error: 1.74 and column: eelen, sysErrDict[df.at[i, col]] is:0.4338137709255488
# row: 144 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:-0.05039798140901126
# row: 144 and error: 8.09 and column: ehadr, sysErrDict[df.at[i, col]] is:3.4858075120210463
# row: 144 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 144 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 144 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 144 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 145 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.2964844357890704
# row: 145 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 145 and error: 0.24 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.14729998947694034
# row: 145 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 145 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.4816239291088411
# row: 145 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 145 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 146 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.028494155904159702
# row: 146 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 146 and error: 0.58 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.533704612559882
# row: 146 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 146 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 146 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 146 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 147 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:0.18013788224227137
# row: 147 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 147 and error: 1.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-1.6979291010071405
# row: 147 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 147 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 147 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 147 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 148 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.2599004324820297
# row: 148 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 148 and error: 1.78 and column: ehadr, sysErrDict[df.at[i, col]] is:2.016580706860678
# row: 148 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 148 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 148 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 148 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 149 and error: 0.69 and column: eelen, sysErrDict[df.at[i, col]] is:-0.931543845541427
# row: 149 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.008298981065915992
# row: 149 and error: 2.81 and column: ehadr, sysErrDict[df.at[i, col]] is:2.7091404030238073
# row: 149 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 149 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 149 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 149 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 150 and error: 1.02 and column: eelen, sysErrDict[df.at[i, col]] is:-0.6931101657983044
# row: 150 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.01826512074636571
# row: 150 and error: 4.47 and column: ehadr, sysErrDict[df.at[i, col]] is:1.9767684634241076
# row: 150 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 150 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 150 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 150 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 151 and error: 1.76 and column: eelen, sysErrDict[df.at[i, col]] is:-1.2946214179286386
# row: 151 and error: 0.05 and column: ethee, sysErrDict[df.at[i, col]] is:-0.051517470201741605
# row: 151 and error: 8.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-2.4485515297439426
# row: 151 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 151 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 151 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 151 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 152 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:0.18013788224227137
# row: 152 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 152 and error: 1.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.8791588198239871
# row: 152 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 152 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.4816239291088411
# row: 152 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 152 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 153 and error: 0.49 and column: eelen, sysErrDict[df.at[i, col]] is:0.585778832117669
# row: 153 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 153 and error: 1.73 and column: ehadr, sysErrDict[df.at[i, col]] is:1.6487716113060809
# row: 153 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 153 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.4816239291088411
# row: 153 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 153 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 154 and error: 0.7 and column: eelen, sysErrDict[df.at[i, col]] is:0.8608744052560644
# row: 154 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0043157832563253135
# row: 154 and error: 2.76 and column: ehadr, sysErrDict[df.at[i, col]] is:0.6874714586144246
# row: 154 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 154 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 154 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 154 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 155 and error: 1.03 and column: eelen, sysErrDict[df.at[i, col]] is:0.11303715791960331
# row: 155 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.008298981065915992
# row: 155 and error: 4.44 and column: ehadr, sysErrDict[df.at[i, col]] is:-3.8571256267208103
# row: 155 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 155 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 155 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 155 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 156 and error: 1.78 and column: eelen, sysErrDict[df.at[i, col]] is:2.016580706860678
# row: 156 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.01826512074636571
# row: 156 and error: 8.14 and column: ehadr, sysErrDict[df.at[i, col]] is:9.665160033815017
# row: 156 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.24940452942507046
# row: 156 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 156 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.07337623962823653
# row: 156 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D7_datanc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D7_datanc-thexp.dat
