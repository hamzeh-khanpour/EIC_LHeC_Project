# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC_Ee60/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for elem in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , elem))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std) *0.0

            sys_shift = 0.0
            for col in find_corr_err(df):
                print(f'row: {i} and error: {df.at[i, col]} and column: {col}')
                sys_shift += sysErrDict[df.at[i, col]]**2
            
            sys_shift  = sys_shift**0.5
            sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# row: 0 and error: 2.0 and column: ccsys
# row: 1 and error: 2.0 and column: ccsys
# row: 2 and error: 2.0 and column: ccsys
# row: 3 and error: 2.0 and column: ccsys
# row: 4 and error: 2.0 and column: ccsys
# row: 5 and error: 2.0 and column: ccsys
# row: 6 and error: 2.0 and column: ccsys
# row: 7 and error: 2.0 and column: ccsys
# row: 8 and error: 2.0 and column: ccsys
# row: 9 and error: 2.0 and column: ccsys
# row: 10 and error: 2.0 and column: ccsys
# row: 11 and error: 2.0 and column: ccsys
# row: 12 and error: 2.0 and column: ccsys
# row: 13 and error: 2.0 and column: ccsys
# row: 14 and error: 2.0 and column: ccsys
# row: 15 and error: 2.0 and column: ccsys
# row: 16 and error: 2.0 and column: ccsys
# row: 17 and error: 2.0 and column: ccsys
# row: 18 and error: 2.0 and column: ccsys
# row: 19 and error: 2.0 and column: ccsys
# row: 20 and error: 2.0 and column: ccsys
# row: 21 and error: 2.0 and column: ccsys
# row: 22 and error: 2.0 and column: ccsys
# row: 23 and error: 2.0 and column: ccsys
# row: 24 and error: 2.0 and column: ccsys
# row: 25 and error: 2.0 and column: ccsys
# row: 26 and error: 2.0 and column: ccsys
# row: 27 and error: 2.0 and column: ccsys
# row: 28 and error: 2.0 and column: ccsys
# row: 29 and error: 2.0 and column: ccsys
# row: 30 and error: 2.0 and column: ccsys
# row: 31 and error: 2.0 and column: ccsys
# row: 32 and error: 2.0 and column: ccsys
# row: 33 and error: 2.0 and column: ccsys
# row: 34 and error: 2.0 and column: ccsys
# row: 35 and error: 2.0 and column: ccsys
# row: 36 and error: 3.33 and column: ccsys
# row: 37 and error: 4.67 and column: ccsys
# row: 38 and error: 2.0 and column: ccsys
# row: 39 and error: 2.0 and column: ccsys
# row: 40 and error: 2.0 and column: ccsys
# row: 41 and error: 2.0 and column: ccsys
# row: 42 and error: 2.0 and column: ccsys
# row: 43 and error: 2.0 and column: ccsys
# row: 44 and error: 2.0 and column: ccsys
# row: 45 and error: 2.0 and column: ccsys
# row: 46 and error: 3.33 and column: ccsys
# row: 47 and error: 4.67 and column: ccsys
# row: 48 and error: 6.0 and column: ccsys
# row: 49 and error: 7.33 and column: ccsys
# row: 50 and error: 2.0 and column: ccsys
# row: 51 and error: 2.0 and column: ccsys
# row: 52 and error: 2.0 and column: ccsys
# row: 53 and error: 2.0 and column: ccsys
# row: 54 and error: 2.0 and column: ccsys
# row: 55 and error: 2.0 and column: ccsys
# row: 56 and error: 2.0 and column: ccsys
# row: 57 and error: 3.33 and column: ccsys
# row: 58 and error: 4.67 and column: ccsys
# row: 59 and error: 6.0 and column: ccsys
# row: 60 and error: 7.33 and column: ccsys
# row: 61 and error: 8.67 and column: ccsys
# row: 62 and error: 2.0 and column: ccsys
# row: 63 and error: 2.0 and column: ccsys
# row: 64 and error: 2.0 and column: ccsys
# row: 65 and error: 2.0 and column: ccsys
# row: 66 and error: 2.0 and column: ccsys
# row: 67 and error: 2.0 and column: ccsys
# row: 68 and error: 3.33 and column: ccsys
# row: 69 and error: 4.67 and column: ccsys
# row: 70 and error: 6.0 and column: ccsys
# row: 71 and error: 7.33 and column: ccsys
# row: 72 and error: 8.67 and column: ccsys
# row: 73 and error: 2.0 and column: ccsys
# row: 74 and error: 2.0 and column: ccsys
# row: 75 and error: 2.0 and column: ccsys
# row: 76 and error: 2.0 and column: ccsys
# row: 77 and error: 2.0 and column: ccsys
# row: 78 and error: 3.33 and column: ccsys
# row: 79 and error: 4.67 and column: ccsys
# row: 80 and error: 6.0 and column: ccsys
# row: 81 and error: 7.33 and column: ccsys
# row: 82 and error: 8.67 and column: ccsys
# row: 83 and error: 2.0 and column: ccsys
# row: 84 and error: 2.0 and column: ccsys
# row: 85 and error: 2.0 and column: ccsys
# row: 86 and error: 2.0 and column: ccsys
# row: 87 and error: 3.33 and column: ccsys
# row: 88 and error: 4.67 and column: ccsys
# row: 89 and error: 6.0 and column: ccsys
# row: 90 and error: 7.33 and column: ccsys
# row: 91 and error: 8.67 and column: ccsys
# row: 92 and error: 2.0 and column: ccsys
# row: 93 and error: 2.0 and column: ccsys
# row: 94 and error: 2.0 and column: ccsys
# row: 95 and error: 3.33 and column: ccsys
# row: 96 and error: 4.67 and column: ccsys
# row: 97 and error: 6.0 and column: ccsys
# row: 98 and error: 7.33 and column: ccsys
# row: 99 and error: 2.0 and column: ccsys
# row: 100 and error: 2.0 and column: ccsys
# row: 101 and error: 3.33 and column: ccsys
# row: 102 and error: 4.67 and column: ccsys
# row: 103 and error: 6.0 and column: ccsys
# row: 104 and error: 7.33 and column: ccsys
# row: 105 and error: 3.33 and column: ccsys
# row: 106 and error: 4.67 and column: ccsys
# row: 107 and error: 6.0 and column: ccsys
# row: 108 and error: 7.33 and column: ccsys
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D6_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D6_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys
# row: 1 and error: 2.0 and column: ccsys
# row: 2 and error: 2.0 and column: ccsys
# row: 3 and error: 2.0 and column: ccsys
# row: 4 and error: 2.0 and column: ccsys
# row: 5 and error: 2.0 and column: ccsys
# row: 6 and error: 2.0 and column: ccsys
# row: 7 and error: 2.0 and column: ccsys
# row: 8 and error: 2.0 and column: ccsys
# row: 9 and error: 2.0 and column: ccsys
# row: 10 and error: 2.0 and column: ccsys
# row: 11 and error: 2.0 and column: ccsys
# row: 12 and error: 2.0 and column: ccsys
# row: 13 and error: 2.0 and column: ccsys
# row: 14 and error: 2.0 and column: ccsys
# row: 15 and error: 2.0 and column: ccsys
# row: 16 and error: 2.0 and column: ccsys
# row: 17 and error: 2.0 and column: ccsys
# row: 18 and error: 2.0 and column: ccsys
# row: 19 and error: 2.0 and column: ccsys
# row: 20 and error: 2.0 and column: ccsys
# row: 21 and error: 2.0 and column: ccsys
# row: 22 and error: 2.0 and column: ccsys
# row: 23 and error: 3.33 and column: ccsys
# row: 24 and error: 2.0 and column: ccsys
# row: 25 and error: 2.0 and column: ccsys
# row: 26 and error: 2.0 and column: ccsys
# row: 27 and error: 2.0 and column: ccsys
# row: 28 and error: 2.0 and column: ccsys
# row: 29 and error: 2.0 and column: ccsys
# row: 30 and error: 3.33 and column: ccsys
# row: 31 and error: 6.0 and column: ccsys
# row: 32 and error: 8.67 and column: ccsys
# row: 33 and error: 2.0 and column: ccsys
# row: 34 and error: 2.0 and column: ccsys
# row: 35 and error: 2.0 and column: ccsys
# row: 36 and error: 2.0 and column: ccsys
# row: 37 and error: 3.33 and column: ccsys
# row: 38 and error: 6.0 and column: ccsys
# row: 39 and error: 8.67 and column: ccsys
# row: 40 and error: 2.0 and column: ccsys
# row: 41 and error: 2.0 and column: ccsys
# row: 42 and error: 2.0 and column: ccsys
# row: 43 and error: 3.33 and column: ccsys
# row: 44 and error: 6.0 and column: ccsys
# row: 45 and error: 8.67 and column: ccsys
# row: 46 and error: 2.0 and column: ccsys
# row: 47 and error: 2.0 and column: ccsys
# row: 48 and error: 3.33 and column: ccsys
# row: 49 and error: 6.0 and column: ccsys
# row: 50 and error: 8.67 and column: ccsys
# row: 51 and error: 2.0 and column: ccsys
# row: 52 and error: 3.33 and column: ccsys
# row: 53 and error: 6.0 and column: ccsys
# row: 54 and error: 8.67 and column: ccsys
# row: 55 and error: 8.67 and column: ccsys
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D1_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D1_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys
# row: 1 and error: 2.0 and column: ccsys
# row: 2 and error: 2.0 and column: ccsys
# row: 3 and error: 2.0 and column: ccsys
# row: 4 and error: 2.0 and column: ccsys
# row: 5 and error: 2.0 and column: ccsys
# row: 6 and error: 2.0 and column: ccsys
# row: 7 and error: 2.0 and column: ccsys
# row: 8 and error: 2.0 and column: ccsys
# row: 9 and error: 2.0 and column: ccsys
# row: 10 and error: 2.0 and column: ccsys
# row: 11 and error: 2.0 and column: ccsys
# row: 12 and error: 2.0 and column: ccsys
# row: 13 and error: 2.0 and column: ccsys
# row: 14 and error: 2.0 and column: ccsys
# row: 15 and error: 2.0 and column: ccsys
# row: 16 and error: 2.0 and column: ccsys
# row: 17 and error: 2.0 and column: ccsys
# row: 18 and error: 2.0 and column: ccsys
# row: 19 and error: 2.0 and column: ccsys
# row: 20 and error: 2.0 and column: ccsys
# row: 21 and error: 2.0 and column: ccsys
# row: 22 and error: 2.0 and column: ccsys
# row: 23 and error: 3.33 and column: ccsys
# row: 24 and error: 2.0 and column: ccsys
# row: 25 and error: 2.0 and column: ccsys
# row: 26 and error: 2.0 and column: ccsys
# row: 27 and error: 2.0 and column: ccsys
# row: 28 and error: 2.0 and column: ccsys
# row: 29 and error: 2.0 and column: ccsys
# row: 30 and error: 3.33 and column: ccsys
# row: 31 and error: 6.0 and column: ccsys
# row: 32 and error: 8.67 and column: ccsys
# row: 33 and error: 2.0 and column: ccsys
# row: 34 and error: 2.0 and column: ccsys
# row: 35 and error: 2.0 and column: ccsys
# row: 36 and error: 2.0 and column: ccsys
# row: 37 and error: 3.33 and column: ccsys
# row: 38 and error: 6.0 and column: ccsys
# row: 39 and error: 8.67 and column: ccsys
# row: 40 and error: 2.0 and column: ccsys
# row: 41 and error: 2.0 and column: ccsys
# row: 42 and error: 2.0 and column: ccsys
# row: 43 and error: 3.33 and column: ccsys
# row: 44 and error: 6.0 and column: ccsys
# row: 45 and error: 8.67 and column: ccsys
# row: 46 and error: 2.0 and column: ccsys
# row: 47 and error: 2.0 and column: ccsys
# row: 48 and error: 3.33 and column: ccsys
# row: 49 and error: 6.0 and column: ccsys
# row: 50 and error: 8.67 and column: ccsys
# row: 51 and error: 2.0 and column: ccsys
# row: 52 and error: 3.33 and column: ccsys
# row: 53 and error: 6.0 and column: ccsys
# row: 54 and error: 8.67 and column: ccsys
# row: 55 and error: 8.67 and column: ccsys
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D2_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D2_datacc-thexp.dat
# row: 0 and error: 0.05 and column: eelen
# row: 0 and error: 0.27 and column: ethee
# row: 0 and error: 0.07 and column: ehadr
# row: 0 and error: 0.3 and column: radco
# row: 0 and error: 1.0 and column: egamp
# row: 0 and error: 0.5 and column: effic
# row: 0 and error: 0.0 and column: enois
# row: 1 and error: 0.06 and column: eelen
# row: 1 and error: 0.5 and column: ethee
# row: 1 and error: 0.07 and column: ehadr
# row: 1 and error: 0.3 and column: radco
# row: 1 and error: 0.0 and column: egamp
# row: 1 and error: 0.5 and column: effic
# row: 1 and error: 0.0 and column: enois
# row: 2 and error: 0.07 and column: eelen
# row: 2 and error: 0.6 and column: ethee
# row: 2 and error: 0.1 and column: ehadr
# row: 2 and error: 0.3 and column: radco
# row: 2 and error: 0.0 and column: egamp
# row: 2 and error: 0.5 and column: effic
# row: 2 and error: 0.0 and column: enois
# row: 3 and error: 0.08 and column: eelen
# row: 3 and error: 0.68 and column: ethee
# row: 3 and error: 0.1 and column: ehadr
# row: 3 and error: 0.3 and column: radco
# row: 3 and error: 0.0 and column: egamp
# row: 3 and error: 0.5 and column: effic
# row: 3 and error: 0.0 and column: enois
# row: 4 and error: 0.08 and column: eelen
# row: 4 and error: 0.74 and column: ethee
# row: 4 and error: 0.1 and column: ehadr
# row: 4 and error: 0.3 and column: radco
# row: 4 and error: 0.0 and column: egamp
# row: 4 and error: 0.5 and column: effic
# row: 4 and error: 0.0 and column: enois
# row: 5 and error: 0.09 and column: eelen
# row: 5 and error: 0.77 and column: ethee
# row: 5 and error: 0.09 and column: ehadr
# row: 5 and error: 0.3 and column: radco
# row: 5 and error: 0.0 and column: egamp
# row: 5 and error: 0.5 and column: effic
# row: 5 and error: 0.0 and column: enois
# row: 6 and error: 0.09 and column: eelen
# row: 6 and error: 0.79 and column: ethee
# row: 6 and error: 0.09 and column: ehadr
# row: 6 and error: 0.3 and column: radco
# row: 6 and error: 0.0 and column: egamp
# row: 6 and error: 0.5 and column: effic
# row: 6 and error: 1.71 and column: enois
# row: 7 and error: 0.09 and column: eelen
# row: 7 and error: 0.8 and column: ethee
# row: 7 and error: 0.08 and column: ehadr
# row: 7 and error: 0.3 and column: radco
# row: 7 and error: 0.0 and column: egamp
# row: 7 and error: 0.5 and column: effic
# row: 7 and error: 2.0 and column: enois
# row: 8 and error: 0.09 and column: eelen
# row: 8 and error: 0.78 and column: ethee
# row: 8 and error: 0.08 and column: ehadr
# row: 8 and error: 0.3 and column: radco
# row: 8 and error: 0.0 and column: egamp
# row: 8 and error: 0.5 and column: effic
# row: 8 and error: 2.17 and column: enois
# row: 9 and error: 0.08 and column: eelen
# row: 9 and error: 0.32 and column: ethee
# row: 9 and error: 0.06 and column: ehadr
# row: 9 and error: 0.3 and column: radco
# row: 9 and error: 1.0 and column: egamp
# row: 9 and error: 0.5 and column: effic
# row: 9 and error: 0.0 and column: enois
# row: 10 and error: 0.08 and column: eelen
# row: 10 and error: 0.37 and column: ethee
# row: 10 and error: 0.06 and column: ehadr
# row: 10 and error: 0.3 and column: radco
# row: 10 and error: 0.0 and column: egamp
# row: 10 and error: 0.5 and column: effic
# row: 10 and error: 0.0 and column: enois
# row: 11 and error: 0.07 and column: eelen
# row: 11 and error: 0.39 and column: ethee
# row: 11 and error: 0.09 and column: ehadr
# row: 11 and error: 0.3 and column: radco
# row: 11 and error: 0.0 and column: egamp
# row: 11 and error: 0.5 and column: effic
# row: 11 and error: 0.0 and column: enois
# row: 12 and error: 0.07 and column: eelen
# row: 12 and error: 0.4 and column: ethee
# row: 12 and error: 0.11 and column: ehadr
# row: 12 and error: 0.3 and column: radco
# row: 12 and error: 0.0 and column: egamp
# row: 12 and error: 0.5 and column: effic
# row: 12 and error: 0.0 and column: enois
# row: 13 and error: 0.07 and column: eelen
# row: 13 and error: 0.41 and column: ethee
# row: 13 and error: 0.11 and column: ehadr
# row: 13 and error: 0.3 and column: radco
# row: 13 and error: 0.0 and column: egamp
# row: 13 and error: 0.5 and column: effic
# row: 13 and error: 0.0 and column: enois
# row: 14 and error: 0.07 and column: eelen
# row: 14 and error: 0.42 and column: ethee
# row: 14 and error: 0.1 and column: ehadr
# row: 14 and error: 0.3 and column: radco
# row: 14 and error: 0.0 and column: egamp
# row: 14 and error: 0.5 and column: effic
# row: 14 and error: 0.0 and column: enois
# row: 15 and error: 0.08 and column: eelen
# row: 15 and error: 0.44 and column: ethee
# row: 15 and error: 0.1 and column: ehadr
# row: 15 and error: 0.3 and column: radco
# row: 15 and error: 0.0 and column: egamp
# row: 15 and error: 0.5 and column: effic
# row: 15 and error: 1.71 and column: enois
# row: 16 and error: 0.08 and column: eelen
# row: 16 and error: 0.46 and column: ethee
# row: 16 and error: 0.1 and column: ehadr
# row: 16 and error: 0.3 and column: radco
# row: 16 and error: 0.0 and column: egamp
# row: 16 and error: 0.5 and column: effic
# row: 16 and error: 1.88 and column: enois
# row: 17 and error: 0.08 and column: eelen
# row: 17 and error: 0.47 and column: ethee
# row: 17 and error: 0.09 and column: ehadr
# row: 17 and error: 0.3 and column: radco
# row: 17 and error: 0.0 and column: egamp
# row: 17 and error: 0.5 and column: effic
# row: 17 and error: 2.15 and column: enois
# row: 18 and error: 0.09 and column: eelen
# row: 18 and error: 0.19 and column: ethee
# row: 18 and error: 0.04 and column: ehadr
# row: 18 and error: 0.3 and column: radco
# row: 18 and error: 1.0 and column: egamp
# row: 18 and error: 0.5 and column: effic
# row: 18 and error: 0.0 and column: enois
# row: 19 and error: 0.08 and column: eelen
# row: 19 and error: 0.27 and column: ethee
# row: 19 and error: 0.03 and column: ehadr
# row: 19 and error: 0.3 and column: radco
# row: 19 and error: 0.0 and column: egamp
# row: 19 and error: 0.5 and column: effic
# row: 19 and error: 0.0 and column: enois
# row: 20 and error: 0.08 and column: eelen
# row: 20 and error: 0.29 and column: ethee
# row: 20 and error: 0.09 and column: ehadr
# row: 20 and error: 0.3 and column: radco
# row: 20 and error: 0.0 and column: egamp
# row: 20 and error: 0.5 and column: effic
# row: 20 and error: 0.0 and column: enois
# row: 21 and error: 0.08 and column: eelen
# row: 21 and error: 0.3 and column: ethee
# row: 21 and error: 0.1 and column: ehadr
# row: 21 and error: 0.3 and column: radco
# row: 21 and error: 0.0 and column: egamp
# row: 21 and error: 0.5 and column: effic
# row: 21 and error: 0.0 and column: enois
# row: 22 and error: 0.08 and column: eelen
# row: 22 and error: 0.31 and column: ethee
# row: 22 and error: 0.11 and column: ehadr
# row: 22 and error: 0.3 and column: radco
# row: 22 and error: 0.0 and column: egamp
# row: 22 and error: 0.5 and column: effic
# row: 22 and error: 0.0 and column: enois
# row: 23 and error: 0.09 and column: eelen
# row: 23 and error: 0.33 and column: ethee
# row: 23 and error: 0.12 and column: ehadr
# row: 23 and error: 0.3 and column: radco
# row: 23 and error: 0.0 and column: egamp
# row: 23 and error: 0.5 and column: effic
# row: 23 and error: 0.0 and column: enois
# row: 24 and error: 0.09 and column: eelen
# row: 24 and error: 0.34 and column: ethee
# row: 24 and error: 0.12 and column: ehadr
# row: 24 and error: 0.3 and column: radco
# row: 24 and error: 0.0 and column: egamp
# row: 24 and error: 0.5 and column: effic
# row: 24 and error: 1.66 and column: enois
# row: 25 and error: 0.09 and column: eelen
# row: 25 and error: 0.36 and column: ethee
# row: 25 and error: 0.12 and column: ehadr
# row: 25 and error: 0.3 and column: radco
# row: 25 and error: 0.0 and column: egamp
# row: 25 and error: 0.5 and column: effic
# row: 25 and error: 1.93 and column: enois
# row: 26 and error: 0.1 and column: eelen
# row: 26 and error: 0.37 and column: ethee
# row: 26 and error: 0.11 and column: ehadr
# row: 26 and error: 0.3 and column: radco
# row: 26 and error: 0.0 and column: egamp
# row: 26 and error: 0.5 and column: effic
# row: 26 and error: 2.22 and column: enois
# row: 27 and error: 0.09 and column: eelen
# row: 27 and error: 0.16 and column: ethee
# row: 27 and error: 0.01 and column: ehadr
# row: 27 and error: 0.3 and column: radco
# row: 27 and error: 1.0 and column: egamp
# row: 27 and error: 0.5 and column: effic
# row: 27 and error: 0.0 and column: enois
# row: 28 and error: 0.09 and column: eelen
# row: 28 and error: 0.22 and column: ethee
# row: 28 and error: 0.04 and column: ehadr
# row: 28 and error: 0.3 and column: radco
# row: 28 and error: 0.0 and column: egamp
# row: 28 and error: 0.5 and column: effic
# row: 28 and error: 0.0 and column: enois
# row: 29 and error: 0.09 and column: eelen
# row: 29 and error: 0.23 and column: ethee
# row: 29 and error: 0.09 and column: ehadr
# row: 29 and error: 0.3 and column: radco
# row: 29 and error: 0.0 and column: egamp
# row: 29 and error: 0.5 and column: effic
# row: 29 and error: 0.0 and column: enois
# row: 30 and error: 0.09 and column: eelen
# row: 30 and error: 0.24 and column: ethee
# row: 30 and error: 0.11 and column: ehadr
# row: 30 and error: 0.3 and column: radco
# row: 30 and error: 0.0 and column: egamp
# row: 30 and error: 0.5 and column: effic
# row: 30 and error: 0.0 and column: enois
# row: 31 and error: 0.09 and column: eelen
# row: 31 and error: 0.26 and column: ethee
# row: 31 and error: 0.13 and column: ehadr
# row: 31 and error: 0.3 and column: radco
# row: 31 and error: 0.0 and column: egamp
# row: 31 and error: 0.5 and column: effic
# row: 31 and error: 0.0 and column: enois
# row: 32 and error: 0.1 and column: eelen
# row: 32 and error: 0.27 and column: ethee
# row: 32 and error: 0.13 and column: ehadr
# row: 32 and error: 0.3 and column: radco
# row: 32 and error: 0.0 and column: egamp
# row: 32 and error: 0.5 and column: effic
# row: 32 and error: 0.0 and column: enois
# row: 33 and error: 0.1 and column: eelen
# row: 33 and error: 0.28 and column: ethee
# row: 33 and error: 0.13 and column: ehadr
# row: 33 and error: 0.3 and column: radco
# row: 33 and error: 0.0 and column: egamp
# row: 33 and error: 0.5 and column: effic
# row: 33 and error: 1.71 and column: enois
# row: 34 and error: 0.1 and column: eelen
# row: 34 and error: 0.29 and column: ethee
# row: 34 and error: 0.13 and column: ehadr
# row: 34 and error: 0.3 and column: radco
# row: 34 and error: 0.0 and column: egamp
# row: 34 and error: 0.5 and column: effic
# row: 34 and error: 2.0 and column: enois
# row: 35 and error: 0.11 and column: eelen
# row: 35 and error: 0.29 and column: ethee
# row: 35 and error: 0.12 and column: ehadr
# row: 35 and error: 0.3 and column: radco
# row: 35 and error: 0.0 and column: egamp
# row: 35 and error: 0.5 and column: effic
# row: 35 and error: 2.17 and column: enois
# row: 36 and error: 0.1 and column: eelen
# row: 36 and error: 0.12 and column: ethee
# row: 36 and error: 0.01 and column: ehadr
# row: 36 and error: 0.3 and column: radco
# row: 36 and error: 1.0 and column: egamp
# row: 36 and error: 0.5 and column: effic
# row: 36 and error: 0.0 and column: enois
# row: 37 and error: 0.1 and column: eelen
# row: 37 and error: 0.15 and column: ethee
# row: 37 and error: 0.02 and column: ehadr
# row: 37 and error: 0.3 and column: radco
# row: 37 and error: 0.0 and column: egamp
# row: 37 and error: 0.5 and column: effic
# row: 37 and error: 0.0 and column: enois
# row: 38 and error: 0.1 and column: eelen
# row: 38 and error: 0.17 and column: ethee
# row: 38 and error: 0.09 and column: ehadr
# row: 38 and error: 0.3 and column: radco
# row: 38 and error: 0.0 and column: egamp
# row: 38 and error: 0.5 and column: effic
# row: 38 and error: 0.0 and column: enois
# row: 39 and error: 0.1 and column: eelen
# row: 39 and error: 0.18 and column: ethee
# row: 39 and error: 0.13 and column: ehadr
# row: 39 and error: 0.3 and column: radco
# row: 39 and error: 0.0 and column: egamp
# row: 39 and error: 0.5 and column: effic
# row: 39 and error: 0.0 and column: enois
# row: 40 and error: 0.1 and column: eelen
# row: 40 and error: 0.19 and column: ethee
# row: 40 and error: 0.14 and column: ehadr
# row: 40 and error: 0.3 and column: radco
# row: 40 and error: 0.0 and column: egamp
# row: 40 and error: 0.5 and column: effic
# row: 40 and error: 0.0 and column: enois
# row: 41 and error: 0.11 and column: eelen
# row: 41 and error: 0.2 and column: ethee
# row: 41 and error: 0.15 and column: ehadr
# row: 41 and error: 0.3 and column: radco
# row: 41 and error: 0.0 and column: egamp
# row: 41 and error: 0.5 and column: effic
# row: 41 and error: 0.0 and column: enois
# row: 42 and error: 0.11 and column: eelen
# row: 42 and error: 0.2 and column: ethee
# row: 42 and error: 0.15 and column: ehadr
# row: 42 and error: 0.3 and column: radco
# row: 42 and error: 0.0 and column: egamp
# row: 42 and error: 0.5 and column: effic
# row: 42 and error: 1.71 and column: enois
# row: 43 and error: 0.11 and column: eelen
# row: 43 and error: 0.21 and column: ethee
# row: 43 and error: 0.15 and column: ehadr
# row: 43 and error: 0.3 and column: radco
# row: 43 and error: 0.0 and column: egamp
# row: 43 and error: 0.5 and column: effic
# row: 43 and error: 1.88 and column: enois
# row: 44 and error: 0.12 and column: eelen
# row: 44 and error: 0.21 and column: ethee
# row: 44 and error: 0.13 and column: ehadr
# row: 44 and error: 0.3 and column: radco
# row: 44 and error: 0.0 and column: egamp
# row: 44 and error: 0.5 and column: effic
# row: 44 and error: 2.15 and column: enois
# row: 45 and error: 0.11 and column: eelen
# row: 45 and error: 0.07 and column: ethee
# row: 45 and error: 0.0 and column: ehadr
# row: 45 and error: 0.3 and column: radco
# row: 45 and error: 1.0 and column: egamp
# row: 45 and error: 0.5 and column: effic
# row: 45 and error: 0.0 and column: enois
# row: 46 and error: 0.11 and column: eelen
# row: 46 and error: 0.11 and column: ethee
# row: 46 and error: 0.03 and column: ehadr
# row: 46 and error: 0.3 and column: radco
# row: 46 and error: 0.0 and column: egamp
# row: 46 and error: 0.5 and column: effic
# row: 46 and error: 0.0 and column: enois
# row: 47 and error: 0.11 and column: eelen
# row: 47 and error: 0.13 and column: ethee
# row: 47 and error: 0.11 and column: ehadr
# row: 47 and error: 0.3 and column: radco
# row: 47 and error: 0.0 and column: egamp
# row: 47 and error: 0.5 and column: effic
# row: 47 and error: 0.0 and column: enois
# row: 48 and error: 0.11 and column: eelen
# row: 48 and error: 0.13 and column: ethee
# row: 48 and error: 0.14 and column: ehadr
# row: 48 and error: 0.3 and column: radco
# row: 48 and error: 0.0 and column: egamp
# row: 48 and error: 0.5 and column: effic
# row: 48 and error: 0.0 and column: enois
# row: 49 and error: 0.12 and column: eelen
# row: 49 and error: 0.14 and column: ethee
# row: 49 and error: 0.16 and column: ehadr
# row: 49 and error: 0.3 and column: radco
# row: 49 and error: 0.0 and column: egamp
# row: 49 and error: 0.5 and column: effic
# row: 49 and error: 0.0 and column: enois
# row: 50 and error: 0.12 and column: eelen
# row: 50 and error: 0.15 and column: ethee
# row: 50 and error: 0.17 and column: ehadr
# row: 50 and error: 0.3 and column: radco
# row: 50 and error: 0.0 and column: egamp
# row: 50 and error: 0.5 and column: effic
# row: 50 and error: 0.0 and column: enois
# row: 51 and error: 0.12 and column: eelen
# row: 51 and error: 0.15 and column: ethee
# row: 51 and error: 0.17 and column: ehadr
# row: 51 and error: 0.3 and column: radco
# row: 51 and error: 0.0 and column: egamp
# row: 51 and error: 0.5 and column: effic
# row: 51 and error: 1.66 and column: enois
# row: 52 and error: 0.12 and column: eelen
# row: 52 and error: 0.15 and column: ethee
# row: 52 and error: 0.15 and column: ehadr
# row: 52 and error: 0.3 and column: radco
# row: 52 and error: 0.0 and column: egamp
# row: 52 and error: 0.5 and column: effic
# row: 52 and error: 1.93 and column: enois
# row: 53 and error: 0.12 and column: eelen
# row: 53 and error: 0.15 and column: ethee
# row: 53 and error: 0.14 and column: ehadr
# row: 53 and error: 0.3 and column: radco
# row: 53 and error: 0.0 and column: egamp
# row: 53 and error: 0.5 and column: effic
# row: 53 and error: 2.22 and column: enois
# row: 54 and error: 0.11 and column: eelen
# row: 54 and error: 0.06 and column: ethee
# row: 54 and error: 0.01 and column: ehadr
# row: 54 and error: 0.3 and column: radco
# row: 54 and error: 1.0 and column: egamp
# row: 54 and error: 0.5 and column: effic
# row: 54 and error: 0.0 and column: enois
# row: 55 and error: 0.12 and column: eelen
# row: 55 and error: 0.09 and column: ethee
# row: 55 and error: 0.07 and column: ehadr
# row: 55 and error: 0.3 and column: radco
# row: 55 and error: 0.0 and column: egamp
# row: 55 and error: 0.5 and column: effic
# row: 55 and error: 0.0 and column: enois
# row: 56 and error: 0.12 and column: eelen
# row: 56 and error: 0.1 and column: ethee
# row: 56 and error: 0.12 and column: ehadr
# row: 56 and error: 0.3 and column: radco
# row: 56 and error: 0.0 and column: egamp
# row: 56 and error: 0.5 and column: effic
# row: 56 and error: 0.0 and column: enois
# row: 57 and error: 0.12 and column: eelen
# row: 57 and error: 0.1 and column: ethee
# row: 57 and error: 0.16 and column: ehadr
# row: 57 and error: 0.3 and column: radco
# row: 57 and error: 0.0 and column: egamp
# row: 57 and error: 0.5 and column: effic
# row: 57 and error: 0.0 and column: enois
# row: 58 and error: 0.12 and column: eelen
# row: 58 and error: 0.11 and column: ethee
# row: 58 and error: 0.18 and column: ehadr
# row: 58 and error: 0.3 and column: radco
# row: 58 and error: 0.0 and column: egamp
# row: 58 and error: 0.5 and column: effic
# row: 58 and error: 0.0 and column: enois
# row: 59 and error: 0.13 and column: eelen
# row: 59 and error: 0.11 and column: ethee
# row: 59 and error: 0.18 and column: ehadr
# row: 59 and error: 0.3 and column: radco
# row: 59 and error: 0.0 and column: egamp
# row: 59 and error: 0.5 and column: effic
# row: 59 and error: 0.0 and column: enois
# row: 60 and error: 0.13 and column: eelen
# row: 60 and error: 0.11 and column: ethee
# row: 60 and error: 0.17 and column: ehadr
# row: 60 and error: 0.3 and column: radco
# row: 60 and error: 0.0 and column: egamp
# row: 60 and error: 0.5 and column: effic
# row: 60 and error: 1.71 and column: enois
# row: 61 and error: 0.13 and column: eelen
# row: 61 and error: 0.11 and column: ethee
# row: 61 and error: 0.15 and column: ehadr
# row: 61 and error: 0.3 and column: radco
# row: 61 and error: 0.0 and column: egamp
# row: 61 and error: 0.5 and column: effic
# row: 61 and error: 2.0 and column: enois
# row: 62 and error: 0.13 and column: eelen
# row: 62 and error: 0.11 and column: ethee
# row: 62 and error: 0.16 and column: ehadr
# row: 62 and error: 0.3 and column: radco
# row: 62 and error: 0.0 and column: egamp
# row: 62 and error: 0.5 and column: effic
# row: 62 and error: 2.17 and column: enois
# row: 63 and error: 0.12 and column: eelen
# row: 63 and error: 0.05 and column: ethee
# row: 63 and error: 0.02 and column: ehadr
# row: 63 and error: 0.3 and column: radco
# row: 63 and error: 1.0 and column: egamp
# row: 63 and error: 0.5 and column: effic
# row: 63 and error: 0.0 and column: enois
# row: 64 and error: 0.12 and column: eelen
# row: 64 and error: 0.06 and column: ethee
# row: 64 and error: 0.07 and column: ehadr
# row: 64 and error: 0.3 and column: radco
# row: 64 and error: 0.0 and column: egamp
# row: 64 and error: 0.5 and column: effic
# row: 64 and error: 0.0 and column: enois
# row: 65 and error: 0.13 and column: eelen
# row: 65 and error: 0.07 and column: ethee
# row: 65 and error: 0.13 and column: ehadr
# row: 65 and error: 0.3 and column: radco
# row: 65 and error: 0.0 and column: egamp
# row: 65 and error: 0.5 and column: effic
# row: 65 and error: 0.0 and column: enois
# row: 66 and error: 0.13 and column: eelen
# row: 66 and error: 0.08 and column: ethee
# row: 66 and error: 0.18 and column: ehadr
# row: 66 and error: 0.3 and column: radco
# row: 66 and error: 0.0 and column: egamp
# row: 66 and error: 0.5 and column: effic
# row: 66 and error: 0.0 and column: enois
# row: 67 and error: 0.13 and column: eelen
# row: 67 and error: 0.08 and column: ethee
# row: 67 and error: 0.18 and column: ehadr
# row: 67 and error: 0.3 and column: radco
# row: 67 and error: 0.0 and column: egamp
# row: 67 and error: 0.5 and column: effic
# row: 67 and error: 0.0 and column: enois
# row: 68 and error: 0.13 and column: eelen
# row: 68 and error: 0.08 and column: ethee
# row: 68 and error: 0.18 and column: ehadr
# row: 68 and error: 0.3 and column: radco
# row: 68 and error: 0.0 and column: egamp
# row: 68 and error: 0.5 and column: effic
# row: 68 and error: 0.0 and column: enois
# row: 69 and error: 0.13 and column: eelen
# row: 69 and error: 0.08 and column: ethee
# row: 69 and error: 0.16 and column: ehadr
# row: 69 and error: 0.3 and column: radco
# row: 69 and error: 0.0 and column: egamp
# row: 69 and error: 0.5 and column: effic
# row: 69 and error: 1.71 and column: enois
# row: 70 and error: 0.14 and column: eelen
# row: 70 and error: 0.08 and column: ethee
# row: 70 and error: 0.18 and column: ehadr
# row: 70 and error: 0.3 and column: radco
# row: 70 and error: 0.0 and column: egamp
# row: 70 and error: 0.5 and column: effic
# row: 70 and error: 1.88 and column: enois
# row: 71 and error: 0.16 and column: eelen
# row: 71 and error: 0.09 and column: ethee
# row: 71 and error: 0.28 and column: ehadr
# row: 71 and error: 0.3 and column: radco
# row: 71 and error: 0.0 and column: egamp
# row: 71 and error: 0.5 and column: effic
# row: 71 and error: 2.15 and column: enois
# row: 72 and error: 0.13 and column: eelen
# row: 72 and error: 0.03 and column: ethee
# row: 72 and error: 0.03 and column: ehadr
# row: 72 and error: 0.3 and column: radco
# row: 72 and error: 1.0 and column: egamp
# row: 72 and error: 0.5 and column: effic
# row: 72 and error: 0.0 and column: enois
# row: 73 and error: 0.13 and column: eelen
# row: 73 and error: 0.04 and column: ethee
# row: 73 and error: 0.07 and column: ehadr
# row: 73 and error: 0.3 and column: radco
# row: 73 and error: 0.0 and column: egamp
# row: 73 and error: 0.5 and column: effic
# row: 73 and error: 0.0 and column: enois
# row: 74 and error: 0.13 and column: eelen
# row: 74 and error: 0.05 and column: ethee
# row: 74 and error: 0.16 and column: ehadr
# row: 74 and error: 0.3 and column: radco
# row: 74 and error: 0.0 and column: egamp
# row: 74 and error: 0.5 and column: effic
# row: 74 and error: 0.0 and column: enois
# row: 75 and error: 0.13 and column: eelen
# row: 75 and error: 0.05 and column: ethee
# row: 75 and error: 0.18 and column: ehadr
# row: 75 and error: 0.3 and column: radco
# row: 75 and error: 0.0 and column: egamp
# row: 75 and error: 0.5 and column: effic
# row: 75 and error: 0.0 and column: enois
# row: 76 and error: 0.13 and column: eelen
# row: 76 and error: 0.05 and column: ethee
# row: 76 and error: 0.19 and column: ehadr
# row: 76 and error: 0.3 and column: radco
# row: 76 and error: 0.0 and column: egamp
# row: 76 and error: 0.5 and column: effic
# row: 76 and error: 0.0 and column: enois
# row: 77 and error: 0.13 and column: eelen
# row: 77 and error: 0.05 and column: ethee
# row: 77 and error: 0.18 and column: ehadr
# row: 77 and error: 0.3 and column: radco
# row: 77 and error: 0.0 and column: egamp
# row: 77 and error: 0.5 and column: effic
# row: 77 and error: 0.0 and column: enois
# row: 78 and error: 0.14 and column: eelen
# row: 78 and error: 0.06 and column: ethee
# row: 78 and error: 0.19 and column: ehadr
# row: 78 and error: 0.3 and column: radco
# row: 78 and error: 0.0 and column: egamp
# row: 78 and error: 0.5 and column: effic
# row: 78 and error: 1.66 and column: enois
# row: 79 and error: 0.17 and column: eelen
# row: 79 and error: 0.07 and column: ethee
# row: 79 and error: 0.31 and column: ehadr
# row: 79 and error: 0.3 and column: radco
# row: 79 and error: 0.0 and column: egamp
# row: 79 and error: 0.5 and column: effic
# row: 79 and error: 1.93 and column: enois
# row: 80 and error: 0.23 and column: eelen
# row: 80 and error: 0.09 and column: ethee
# row: 80 and error: 0.59 and column: ehadr
# row: 80 and error: 0.3 and column: radco
# row: 80 and error: 0.0 and column: egamp
# row: 80 and error: 0.5 and column: effic
# row: 80 and error: 2.06 and column: enois
# row: 81 and error: 0.31 and column: eelen
# row: 81 and error: 0.13 and column: ethee
# row: 81 and error: 1.02 and column: ehadr
# row: 81 and error: 0.3 and column: radco
# row: 81 and error: 0.0 and column: egamp
# row: 81 and error: 0.5 and column: effic
# row: 81 and error: 2.15 and column: enois
# row: 82 and error: 0.44 and column: eelen
# row: 82 and error: 0.17 and column: ethee
# row: 82 and error: 1.65 and column: ehadr
# row: 82 and error: 0.3 and column: radco
# row: 82 and error: 0.0 and column: egamp
# row: 82 and error: 0.5 and column: effic
# row: 82 and error: 2.22 and column: enois
# row: 83 and error: 0.13 and column: eelen
# row: 83 and error: 0.02 and column: ethee
# row: 83 and error: 0.05 and column: ehadr
# row: 83 and error: 0.3 and column: radco
# row: 83 and error: 1.0 and column: egamp
# row: 83 and error: 0.5 and column: effic
# row: 83 and error: 0.0 and column: enois
# row: 84 and error: 0.14 and column: eelen
# row: 84 and error: 0.03 and column: ethee
# row: 84 and error: 0.11 and column: ehadr
# row: 84 and error: 0.3 and column: radco
# row: 84 and error: 0.0 and column: egamp
# row: 84 and error: 0.5 and column: effic
# row: 84 and error: 0.0 and column: enois
# row: 85 and error: 0.14 and column: eelen
# row: 85 and error: 0.04 and column: ethee
# row: 85 and error: 0.16 and column: ehadr
# row: 85 and error: 0.3 and column: radco
# row: 85 and error: 0.0 and column: egamp
# row: 85 and error: 0.5 and column: effic
# row: 85 and error: 0.0 and column: enois
# row: 86 and error: 0.14 and column: eelen
# row: 86 and error: 0.04 and column: ethee
# row: 86 and error: 0.18 and column: ehadr
# row: 86 and error: 0.3 and column: radco
# row: 86 and error: 0.0 and column: egamp
# row: 86 and error: 0.5 and column: effic
# row: 86 and error: 0.0 and column: enois
# row: 87 and error: 0.14 and column: eelen
# row: 87 and error: 0.04 and column: ethee
# row: 87 and error: 0.18 and column: ehadr
# row: 87 and error: 0.3 and column: radco
# row: 87 and error: 0.0 and column: egamp
# row: 87 and error: 0.5 and column: effic
# row: 87 and error: 0.0 and column: enois
# row: 88 and error: 0.14 and column: eelen
# row: 88 and error: 0.04 and column: ethee
# row: 88 and error: 0.2 and column: ehadr
# row: 88 and error: 0.3 and column: radco
# row: 88 and error: 0.0 and column: egamp
# row: 88 and error: 0.5 and column: effic
# row: 88 and error: 0.0 and column: enois
# row: 89 and error: 0.17 and column: eelen
# row: 89 and error: 0.05 and column: ethee
# row: 89 and error: 0.33 and column: ehadr
# row: 89 and error: 0.3 and column: radco
# row: 89 and error: 0.0 and column: egamp
# row: 89 and error: 0.5 and column: effic
# row: 89 and error: 1.71 and column: enois
# row: 90 and error: 0.23 and column: eelen
# row: 90 and error: 0.06 and column: ethee
# row: 90 and error: 0.62 and column: ehadr
# row: 90 and error: 0.3 and column: radco
# row: 90 and error: 0.0 and column: egamp
# row: 90 and error: 0.5 and column: effic
# row: 90 and error: 1.84 and column: enois
# row: 91 and error: 0.32 and column: eelen
# row: 91 and error: 0.09 and column: ethee
# row: 91 and error: 1.05 and column: ehadr
# row: 91 and error: 0.3 and column: radco
# row: 91 and error: 0.0 and column: egamp
# row: 91 and error: 0.5 and column: effic
# row: 91 and error: 1.93 and column: enois
# row: 92 and error: 0.45 and column: eelen
# row: 92 and error: 0.13 and column: ethee
# row: 92 and error: 1.68 and column: ehadr
# row: 92 and error: 0.3 and column: radco
# row: 92 and error: 0.0 and column: egamp
# row: 92 and error: 0.5 and column: effic
# row: 92 and error: 2.0 and column: enois
# row: 93 and error: 0.64 and column: eelen
# row: 93 and error: 0.18 and column: ethee
# row: 93 and error: 2.63 and column: ehadr
# row: 93 and error: 0.3 and column: radco
# row: 93 and error: 0.0 and column: egamp
# row: 93 and error: 0.5 and column: effic
# row: 93 and error: 2.06 and column: enois
# row: 94 and error: 0.95 and column: eelen
# row: 94 and error: 0.27 and column: ethee
# row: 94 and error: 4.19 and column: ehadr
# row: 94 and error: 0.3 and column: radco
# row: 94 and error: 0.0 and column: egamp
# row: 94 and error: 0.5 and column: effic
# row: 94 and error: 2.11 and column: enois
# row: 95 and error: 0.14 and column: eelen
# row: 95 and error: 0.02 and column: ethee
# row: 95 and error: 0.06 and column: ehadr
# row: 95 and error: 0.3 and column: radco
# row: 95 and error: 1.0 and column: egamp
# row: 95 and error: 0.5 and column: effic
# row: 95 and error: 0.0 and column: enois
# row: 96 and error: 0.14 and column: eelen
# row: 96 and error: 0.02 and column: ethee
# row: 96 and error: 0.1 and column: ehadr
# row: 96 and error: 0.3 and column: radco
# row: 96 and error: 0.0 and column: egamp
# row: 96 and error: 0.5 and column: effic
# row: 96 and error: 0.0 and column: enois
# row: 97 and error: 0.14 and column: eelen
# row: 97 and error: 0.02 and column: ethee
# row: 97 and error: 0.15 and column: ehadr
# row: 97 and error: 0.3 and column: radco
# row: 97 and error: 0.0 and column: egamp
# row: 97 and error: 0.5 and column: effic
# row: 97 and error: 0.0 and column: enois
# row: 98 and error: 0.14 and column: eelen
# row: 98 and error: 0.03 and column: ethee
# row: 98 and error: 0.18 and column: ehadr
# row: 98 and error: 0.3 and column: radco
# row: 98 and error: 0.0 and column: egamp
# row: 98 and error: 0.5 and column: effic
# row: 98 and error: 0.0 and column: enois
# row: 99 and error: 0.15 and column: eelen
# row: 99 and error: 0.03 and column: ethee
# row: 99 and error: 0.21 and column: ehadr
# row: 99 and error: 0.3 and column: radco
# row: 99 and error: 0.0 and column: egamp
# row: 99 and error: 0.5 and column: effic
# row: 99 and error: 0.0 and column: enois
# row: 100 and error: 0.17 and column: eelen
# row: 100 and error: 0.03 and column: ethee
# row: 100 and error: 0.34 and column: ehadr
# row: 100 and error: 0.3 and column: radco
# row: 100 and error: 0.0 and column: egamp
# row: 100 and error: 0.5 and column: effic
# row: 100 and error: 0.0 and column: enois
# row: 101 and error: 0.23 and column: eelen
# row: 101 and error: 0.04 and column: ethee
# row: 101 and error: 0.64 and column: ehadr
# row: 101 and error: 0.3 and column: radco
# row: 101 and error: 0.0 and column: egamp
# row: 101 and error: 0.5 and column: effic
# row: 101 and error: 1.55 and column: enois
# row: 102 and error: 0.33 and column: eelen
# row: 102 and error: 0.06 and column: ethee
# row: 102 and error: 1.08 and column: ehadr
# row: 102 and error: 0.3 and column: radco
# row: 102 and error: 0.0 and column: egamp
# row: 102 and error: 0.5 and column: effic
# row: 102 and error: 1.64 and column: enois
# row: 103 and error: 0.45 and column: eelen
# row: 103 and error: 0.09 and column: ethee
# row: 103 and error: 1.72 and column: ehadr
# row: 103 and error: 0.3 and column: radco
# row: 103 and error: 0.0 and column: egamp
# row: 103 and error: 0.5 and column: effic
# row: 103 and error: 1.71 and column: enois
# row: 104 and error: 0.65 and column: eelen
# row: 104 and error: 0.12 and column: ethee
# row: 104 and error: 2.68 and column: ehadr
# row: 104 and error: 0.3 and column: radco
# row: 104 and error: 0.0 and column: egamp
# row: 104 and error: 0.5 and column: effic
# row: 104 and error: 1.77 and column: enois
# row: 105 and error: 0.97 and column: eelen
# row: 105 and error: 0.18 and column: ethee
# row: 105 and error: 4.26 and column: ehadr
# row: 105 and error: 0.3 and column: radco
# row: 105 and error: 0.0 and column: egamp
# row: 105 and error: 0.5 and column: effic
# row: 105 and error: 1.82 and column: enois
# row: 106 and error: 1.68 and column: eelen
# row: 106 and error: 0.32 and column: ethee
# row: 106 and error: 7.77 and column: ehadr
# row: 106 and error: 0.3 and column: radco
# row: 106 and error: 0.0 and column: egamp
# row: 106 and error: 0.5 and column: effic
# row: 106 and error: 1.86 and column: enois
# row: 107 and error: 0.14 and column: eelen
# row: 107 and error: 0.01 and column: ethee
# row: 107 and error: 0.06 and column: ehadr
# row: 107 and error: 0.3 and column: radco
# row: 107 and error: 1.0 and column: egamp
# row: 107 and error: 0.5 and column: effic
# row: 107 and error: 0.0 and column: enois
# row: 108 and error: 0.14 and column: eelen
# row: 108 and error: 0.02 and column: ethee
# row: 108 and error: 0.09 and column: ehadr
# row: 108 and error: 0.3 and column: radco
# row: 108 and error: 0.0 and column: egamp
# row: 108 and error: 0.5 and column: effic
# row: 108 and error: 0.0 and column: enois
# row: 109 and error: 0.14 and column: eelen
# row: 109 and error: 0.02 and column: ethee
# row: 109 and error: 0.16 and column: ehadr
# row: 109 and error: 0.3 and column: radco
# row: 109 and error: 0.0 and column: egamp
# row: 109 and error: 0.5 and column: effic
# row: 109 and error: 0.0 and column: enois
# row: 110 and error: 0.15 and column: eelen
# row: 110 and error: 0.02 and column: ethee
# row: 110 and error: 0.21 and column: ehadr
# row: 110 and error: 0.3 and column: radco
# row: 110 and error: 0.0 and column: egamp
# row: 110 and error: 0.5 and column: effic
# row: 110 and error: 0.0 and column: enois
# row: 111 and error: 0.18 and column: eelen
# row: 111 and error: 0.02 and column: ethee
# row: 111 and error: 0.35 and column: ehadr
# row: 111 and error: 0.3 and column: radco
# row: 111 and error: 0.0 and column: egamp
# row: 111 and error: 0.5 and column: effic
# row: 111 and error: 0.0 and column: enois
# row: 112 and error: 0.24 and column: eelen
# row: 112 and error: 0.03 and column: ethee
# row: 112 and error: 0.66 and column: ehadr
# row: 112 and error: 0.3 and column: radco
# row: 112 and error: 0.0 and column: egamp
# row: 112 and error: 0.5 and column: effic
# row: 112 and error: 0.0 and column: enois
# row: 113 and error: 0.33 and column: eelen
# row: 113 and error: 0.04 and column: ethee
# row: 113 and error: 1.11 and column: ehadr
# row: 113 and error: 0.3 and column: radco
# row: 113 and error: 0.0 and column: egamp
# row: 113 and error: 0.5 and column: effic
# row: 113 and error: 0.0 and column: enois
# row: 114 and error: 0.46 and column: eelen
# row: 114 and error: 0.06 and column: ethee
# row: 114 and error: 1.76 and column: ehadr
# row: 114 and error: 0.3 and column: radco
# row: 114 and error: 0.0 and column: egamp
# row: 114 and error: 0.5 and column: effic
# row: 114 and error: 0.0 and column: enois
# row: 115 and error: 0.66 and column: eelen
# row: 115 and error: 0.08 and column: ethee
# row: 115 and error: 2.73 and column: ehadr
# row: 115 and error: 0.3 and column: radco
# row: 115 and error: 0.0 and column: egamp
# row: 115 and error: 0.5 and column: effic
# row: 115 and error: 1.55 and column: enois
# row: 116 and error: 0.98 and column: eelen
# row: 116 and error: 0.13 and column: ethee
# row: 116 and error: 4.32 and column: ehadr
# row: 116 and error: 0.3 and column: radco
# row: 116 and error: 0.0 and column: egamp
# row: 116 and error: 0.5 and column: effic
# row: 116 and error: 1.6 and column: enois
# row: 117 and error: 1.69 and column: eelen
# row: 117 and error: 0.22 and column: ethee
# row: 117 and error: 7.86 and column: ehadr
# row: 117 and error: 0.3 and column: radco
# row: 117 and error: 0.0 and column: egamp
# row: 117 and error: 0.5 and column: effic
# row: 117 and error: 1.64 and column: enois
# row: 118 and error: 0.15 and column: eelen
# row: 118 and error: 0.01 and column: ethee
# row: 118 and error: 0.07 and column: ehadr
# row: 118 and error: 0.3 and column: radco
# row: 118 and error: 1.0 and column: egamp
# row: 118 and error: 0.5 and column: effic
# row: 118 and error: 0.0 and column: enois
# row: 119 and error: 0.14 and column: eelen
# row: 119 and error: 0.01 and column: ethee
# row: 119 and error: 0.11 and column: ehadr
# row: 119 and error: 0.3 and column: radco
# row: 119 and error: 0.0 and column: egamp
# row: 119 and error: 0.5 and column: effic
# row: 119 and error: 0.0 and column: enois
# row: 120 and error: 0.15 and column: eelen
# row: 120 and error: 0.01 and column: ethee
# row: 120 and error: 0.19 and column: ehadr
# row: 120 and error: 0.3 and column: radco
# row: 120 and error: 0.0 and column: egamp
# row: 120 and error: 0.5 and column: effic
# row: 120 and error: 0.0 and column: enois
# row: 121 and error: 0.18 and column: eelen
# row: 121 and error: 0.02 and column: ethee
# row: 121 and error: 0.35 and column: ehadr
# row: 121 and error: 0.3 and column: radco
# row: 121 and error: 0.0 and column: egamp
# row: 121 and error: 0.5 and column: effic
# row: 121 and error: 0.0 and column: enois
# row: 122 and error: 0.24 and column: eelen
# row: 122 and error: 0.02 and column: ethee
# row: 122 and error: 0.67 and column: ehadr
# row: 122 and error: 0.3 and column: radco
# row: 122 and error: 0.0 and column: egamp
# row: 122 and error: 0.5 and column: effic
# row: 122 and error: 0.0 and column: enois
# row: 123 and error: 0.34 and column: eelen
# row: 123 and error: 0.03 and column: ethee
# row: 123 and error: 1.13 and column: ehadr
# row: 123 and error: 0.3 and column: radco
# row: 123 and error: 0.0 and column: egamp
# row: 123 and error: 0.5 and column: effic
# row: 123 and error: 0.0 and column: enois
# row: 124 and error: 0.47 and column: eelen
# row: 124 and error: 0.04 and column: ethee
# row: 124 and error: 1.78 and column: ehadr
# row: 124 and error: 0.3 and column: radco
# row: 124 and error: 0.0 and column: egamp
# row: 124 and error: 0.5 and column: effic
# row: 124 and error: 0.0 and column: enois
# row: 125 and error: 0.67 and column: eelen
# row: 125 and error: 0.06 and column: ethee
# row: 125 and error: 2.77 and column: ehadr
# row: 125 and error: 0.3 and column: radco
# row: 125 and error: 0.0 and column: egamp
# row: 125 and error: 0.5 and column: effic
# row: 125 and error: 0.0 and column: enois
# row: 126 and error: 0.99 and column: eelen
# row: 126 and error: 0.09 and column: ethee
# row: 126 and error: 4.38 and column: ehadr
# row: 126 and error: 0.3 and column: radco
# row: 126 and error: 0.0 and column: egamp
# row: 126 and error: 0.5 and column: effic
# row: 126 and error: 0.0 and column: enois
# row: 127 and error: 1.71 and column: eelen
# row: 127 and error: 0.15 and column: ethee
# row: 127 and error: 7.94 and column: ehadr
# row: 127 and error: 0.3 and column: radco
# row: 127 and error: 0.0 and column: egamp
# row: 127 and error: 0.5 and column: effic
# row: 127 and error: 0.0 and column: enois
# row: 128 and error: 0.15 and column: eelen
# row: 128 and error: 0.01 and column: ethee
# row: 128 and error: 0.06 and column: ehadr
# row: 128 and error: 0.3 and column: radco
# row: 128 and error: 1.0 and column: egamp
# row: 128 and error: 0.5 and column: effic
# row: 128 and error: 0.0 and column: enois
# row: 129 and error: 0.15 and column: eelen
# row: 129 and error: 0.01 and column: ethee
# row: 129 and error: 0.14 and column: ehadr
# row: 129 and error: 0.3 and column: radco
# row: 129 and error: 0.0 and column: egamp
# row: 129 and error: 0.5 and column: effic
# row: 129 and error: 0.0 and column: enois
# row: 130 and error: 0.18 and column: eelen
# row: 130 and error: 0.01 and column: ethee
# row: 130 and error: 0.33 and column: ehadr
# row: 130 and error: 0.3 and column: radco
# row: 130 and error: 0.0 and column: egamp
# row: 130 and error: 0.5 and column: effic
# row: 130 and error: 0.0 and column: enois
# row: 131 and error: 0.25 and column: eelen
# row: 131 and error: 0.01 and column: ethee
# row: 131 and error: 0.66 and column: ehadr
# row: 131 and error: 0.3 and column: radco
# row: 131 and error: 0.0 and column: egamp
# row: 131 and error: 0.5 and column: effic
# row: 131 and error: 0.0 and column: enois
# row: 132 and error: 0.34 and column: eelen
# ...
# row: 103 and error: 0.5 and column: effic
# row: 103 and error: 1.71 and column: enois
# row: 104 and error: 0.65 and column: eelen
# row: 104 and error: 0.12 and column: ethee
# row: 104 and error: 2.68 and column: ehadr
# row: 104 and error: 0.3 and column: radco
# row: 104 and error: 0.0 and column: egamp
# row: 104 and error: 0.5 and column: effic
# row: 104 and error: 1.77 and column: enois
# row: 105 and error: 0.97 and column: eelen
# row: 105 and error: 0.18 and column: ethee
# row: 105 and error: 4.26 and column: ehadr
# row: 105 and error: 0.3 and column: radco
# row: 105 and error: 0.0 and column: egamp
# row: 105 and error: 0.5 and column: effic
# row: 105 and error: 1.82 and column: enois
# row: 106 and error: 1.68 and column: eelen
# row: 106 and error: 0.32 and column: ethee
# row: 106 and error: 7.77 and column: ehadr
# row: 106 and error: 0.3 and column: radco
# row: 106 and error: 0.0 and column: egamp
# row: 106 and error: 0.5 and column: effic
# row: 106 and error: 1.86 and column: enois
# row: 107 and error: 0.14 and column: eelen
# row: 107 and error: 0.01 and column: ethee
# row: 107 and error: 0.06 and column: ehadr
# row: 107 and error: 0.3 and column: radco
# row: 107 and error: 1.0 and column: egamp
# row: 107 and error: 0.5 and column: effic
# row: 107 and error: 0.0 and column: enois
# row: 108 and error: 0.14 and column: eelen
# row: 108 and error: 0.02 and column: ethee
# row: 108 and error: 0.09 and column: ehadr
# row: 108 and error: 0.3 and column: radco
# row: 108 and error: 0.0 and column: egamp
# row: 108 and error: 0.5 and column: effic
# row: 108 and error: 0.0 and column: enois
# row: 109 and error: 0.14 and column: eelen
# row: 109 and error: 0.02 and column: ethee
# row: 109 and error: 0.16 and column: ehadr
# row: 109 and error: 0.3 and column: radco
# row: 109 and error: 0.0 and column: egamp
# row: 109 and error: 0.5 and column: effic
# row: 109 and error: 0.0 and column: enois
# row: 110 and error: 0.15 and column: eelen
# row: 110 and error: 0.02 and column: ethee
# row: 110 and error: 0.21 and column: ehadr
# row: 110 and error: 0.3 and column: radco
# row: 110 and error: 0.0 and column: egamp
# row: 110 and error: 0.5 and column: effic
# row: 110 and error: 0.0 and column: enois
# row: 111 and error: 0.18 and column: eelen
# row: 111 and error: 0.02 and column: ethee
# row: 111 and error: 0.35 and column: ehadr
# row: 111 and error: 0.3 and column: radco
# row: 111 and error: 0.0 and column: egamp
# row: 111 and error: 0.5 and column: effic
# row: 111 and error: 0.0 and column: enois
# row: 112 and error: 0.24 and column: eelen
# row: 112 and error: 0.03 and column: ethee
# row: 112 and error: 0.66 and column: ehadr
# row: 112 and error: 0.3 and column: radco
# row: 112 and error: 0.0 and column: egamp
# row: 112 and error: 0.5 and column: effic
# row: 112 and error: 0.0 and column: enois
# row: 113 and error: 0.33 and column: eelen
# row: 113 and error: 0.04 and column: ethee
# row: 113 and error: 1.11 and column: ehadr
# row: 113 and error: 0.3 and column: radco
# row: 113 and error: 0.0 and column: egamp
# row: 113 and error: 0.5 and column: effic
# row: 113 and error: 0.0 and column: enois
# row: 114 and error: 0.46 and column: eelen
# row: 114 and error: 0.06 and column: ethee
# row: 114 and error: 1.76 and column: ehadr
# row: 114 and error: 0.3 and column: radco
# row: 114 and error: 0.0 and column: egamp
# row: 114 and error: 0.5 and column: effic
# row: 114 and error: 0.0 and column: enois
# row: 115 and error: 0.66 and column: eelen
# row: 115 and error: 0.08 and column: ethee
# row: 115 and error: 2.73 and column: ehadr
# row: 115 and error: 0.3 and column: radco
# row: 115 and error: 0.0 and column: egamp
# row: 115 and error: 0.5 and column: effic
# row: 115 and error: 1.55 and column: enois
# row: 116 and error: 0.98 and column: eelen
# row: 116 and error: 0.13 and column: ethee
# row: 116 and error: 4.32 and column: ehadr
# row: 116 and error: 0.3 and column: radco
# row: 116 and error: 0.0 and column: egamp
# row: 116 and error: 0.5 and column: effic
# row: 116 and error: 1.6 and column: enois
# row: 117 and error: 1.69 and column: eelen
# row: 117 and error: 0.22 and column: ethee
# row: 117 and error: 7.86 and column: ehadr
# row: 117 and error: 0.3 and column: radco
# row: 117 and error: 0.0 and column: egamp
# row: 117 and error: 0.5 and column: effic
# row: 117 and error: 1.64 and column: enois
# row: 118 and error: 0.15 and column: eelen
# row: 118 and error: 0.01 and column: ethee
# row: 118 and error: 0.07 and column: ehadr
# row: 118 and error: 0.3 and column: radco
# row: 118 and error: 1.0 and column: egamp
# row: 118 and error: 0.5 and column: effic
# row: 118 and error: 0.0 and column: enois
# row: 119 and error: 0.14 and column: eelen
# row: 119 and error: 0.01 and column: ethee
# row: 119 and error: 0.11 and column: ehadr
# row: 119 and error: 0.3 and column: radco
# row: 119 and error: 0.0 and column: egamp
# row: 119 and error: 0.5 and column: effic
# row: 119 and error: 0.0 and column: enois
# row: 120 and error: 0.15 and column: eelen
# row: 120 and error: 0.01 and column: ethee
# row: 120 and error: 0.19 and column: ehadr
# row: 120 and error: 0.3 and column: radco
# row: 120 and error: 0.0 and column: egamp
# row: 120 and error: 0.5 and column: effic
# row: 120 and error: 0.0 and column: enois
# row: 121 and error: 0.18 and column: eelen
# row: 121 and error: 0.02 and column: ethee
# row: 121 and error: 0.35 and column: ehadr
# row: 121 and error: 0.3 and column: radco
# row: 121 and error: 0.0 and column: egamp
# row: 121 and error: 0.5 and column: effic
# row: 121 and error: 0.0 and column: enois
# row: 122 and error: 0.24 and column: eelen
# row: 122 and error: 0.02 and column: ethee
# row: 122 and error: 0.67 and column: ehadr
# row: 122 and error: 0.3 and column: radco
# row: 122 and error: 0.0 and column: egamp
# row: 122 and error: 0.5 and column: effic
# row: 122 and error: 0.0 and column: enois
# row: 123 and error: 0.34 and column: eelen
# row: 123 and error: 0.03 and column: ethee
# row: 123 and error: 1.13 and column: ehadr
# row: 123 and error: 0.3 and column: radco
# row: 123 and error: 0.0 and column: egamp
# row: 123 and error: 0.5 and column: effic
# row: 123 and error: 0.0 and column: enois
# row: 124 and error: 0.47 and column: eelen
# row: 124 and error: 0.04 and column: ethee
# row: 124 and error: 1.78 and column: ehadr
# row: 124 and error: 0.3 and column: radco
# row: 124 and error: 0.0 and column: egamp
# row: 124 and error: 0.5 and column: effic
# row: 124 and error: 0.0 and column: enois
# row: 125 and error: 0.67 and column: eelen
# row: 125 and error: 0.06 and column: ethee
# row: 125 and error: 2.77 and column: ehadr
# row: 125 and error: 0.3 and column: radco
# row: 125 and error: 0.0 and column: egamp
# row: 125 and error: 0.5 and column: effic
# row: 125 and error: 0.0 and column: enois
# row: 126 and error: 0.99 and column: eelen
# row: 126 and error: 0.09 and column: ethee
# row: 126 and error: 4.38 and column: ehadr
# row: 126 and error: 0.3 and column: radco
# row: 126 and error: 0.0 and column: egamp
# row: 126 and error: 0.5 and column: effic
# row: 126 and error: 0.0 and column: enois
# row: 127 and error: 1.71 and column: eelen
# row: 127 and error: 0.15 and column: ethee
# row: 127 and error: 7.94 and column: ehadr
# row: 127 and error: 0.3 and column: radco
# row: 127 and error: 0.0 and column: egamp
# row: 127 and error: 0.5 and column: effic
# row: 127 and error: 0.0 and column: enois
# row: 128 and error: 0.15 and column: eelen
# row: 128 and error: 0.01 and column: ethee
# row: 128 and error: 0.06 and column: ehadr
# row: 128 and error: 0.3 and column: radco
# row: 128 and error: 1.0 and column: egamp
# row: 128 and error: 0.5 and column: effic
# row: 128 and error: 0.0 and column: enois
# row: 129 and error: 0.15 and column: eelen
# row: 129 and error: 0.01 and column: ethee
# row: 129 and error: 0.14 and column: ehadr
# row: 129 and error: 0.3 and column: radco
# row: 129 and error: 0.0 and column: egamp
# row: 129 and error: 0.5 and column: effic
# row: 129 and error: 0.0 and column: enois
# row: 130 and error: 0.18 and column: eelen
# row: 130 and error: 0.01 and column: ethee
# row: 130 and error: 0.33 and column: ehadr
# row: 130 and error: 0.3 and column: radco
# row: 130 and error: 0.0 and column: egamp
# row: 130 and error: 0.5 and column: effic
# row: 130 and error: 0.0 and column: enois
# row: 131 and error: 0.25 and column: eelen
# row: 131 and error: 0.01 and column: ethee
# row: 131 and error: 0.66 and column: ehadr
# row: 131 and error: 0.3 and column: radco
# row: 131 and error: 0.0 and column: egamp
# row: 131 and error: 0.5 and column: effic
# row: 131 and error: 0.0 and column: enois
# row: 132 and error: 0.34 and column: eelen
# row: 132 and error: 0.02 and column: ethee
# row: 132 and error: 1.14 and column: ehadr
# row: 132 and error: 0.3 and column: radco
# row: 132 and error: 0.0 and column: egamp
# row: 132 and error: 0.5 and column: effic
# row: 132 and error: 0.0 and column: enois
# row: 133 and error: 0.47 and column: eelen
# row: 133 and error: 0.03 and column: ethee
# row: 133 and error: 1.8 and column: ehadr
# row: 133 and error: 0.3 and column: radco
# row: 133 and error: 0.0 and column: egamp
# row: 133 and error: 0.5 and column: effic
# row: 133 and error: 0.0 and column: enois
# row: 134 and error: 0.67 and column: eelen
# row: 134 and error: 0.04 and column: ethee
# row: 134 and error: 2.8 and column: ehadr
# row: 134 and error: 0.3 and column: radco
# row: 134 and error: 0.0 and column: egamp
# row: 134 and error: 0.5 and column: effic
# row: 134 and error: 0.0 and column: enois
# row: 135 and error: 1.0 and column: eelen
# row: 135 and error: 0.06 and column: ethee
# row: 135 and error: 4.43 and column: ehadr
# row: 135 and error: 0.3 and column: radco
# row: 135 and error: 0.0 and column: egamp
# row: 135 and error: 0.5 and column: effic
# row: 135 and error: 0.0 and column: enois
# row: 136 and error: 1.73 and column: eelen
# row: 136 and error: 0.1 and column: ethee
# row: 136 and error: 8.02 and column: ehadr
# row: 136 and error: 0.3 and column: radco
# row: 136 and error: 0.0 and column: egamp
# row: 136 and error: 0.5 and column: effic
# row: 136 and error: 0.0 and column: enois
# row: 137 and error: 0.15 and column: eelen
# row: 137 and error: 0.0 and column: ethee
# row: 137 and error: 0.08 and column: ehadr
# row: 137 and error: 0.3 and column: radco
# row: 137 and error: 1.0 and column: egamp
# row: 137 and error: 0.5 and column: effic
# row: 137 and error: 0.0 and column: enois
# row: 138 and error: 0.19 and column: eelen
# row: 138 and error: 0.01 and column: ethee
# row: 138 and error: 0.28 and column: ehadr
# row: 138 and error: 0.3 and column: radco
# row: 138 and error: 0.0 and column: egamp
# row: 138 and error: 0.5 and column: effic
# row: 138 and error: 0.0 and column: enois
# row: 139 and error: 0.25 and column: eelen
# row: 139 and error: 0.01 and column: ethee
# row: 139 and error: 0.64 and column: ehadr
# row: 139 and error: 0.3 and column: radco
# row: 139 and error: 0.0 and column: egamp
# row: 139 and error: 0.5 and column: effic
# row: 139 and error: 0.0 and column: enois
# row: 140 and error: 0.34 and column: eelen
# row: 140 and error: 0.01 and column: ethee
# row: 140 and error: 1.13 and column: ehadr
# row: 140 and error: 0.3 and column: radco
# row: 140 and error: 0.0 and column: egamp
# row: 140 and error: 0.5 and column: effic
# row: 140 and error: 0.0 and column: enois
# row: 141 and error: 0.48 and column: eelen
# row: 141 and error: 0.02 and column: ethee
# row: 141 and error: 1.81 and column: ehadr
# row: 141 and error: 0.3 and column: radco
# row: 141 and error: 0.0 and column: egamp
# row: 141 and error: 0.5 and column: effic
# row: 141 and error: 0.0 and column: enois
# row: 142 and error: 0.68 and column: eelen
# row: 142 and error: 0.03 and column: ethee
# row: 142 and error: 2.82 and column: ehadr
# row: 142 and error: 0.3 and column: radco
# row: 142 and error: 0.0 and column: egamp
# row: 142 and error: 0.5 and column: effic
# row: 142 and error: 0.0 and column: enois
# row: 143 and error: 1.01 and column: eelen
# row: 143 and error: 0.04 and column: ethee
# row: 143 and error: 4.46 and column: ehadr
# row: 143 and error: 0.3 and column: radco
# row: 143 and error: 0.0 and column: egamp
# row: 143 and error: 0.5 and column: effic
# row: 143 and error: 0.0 and column: enois
# row: 144 and error: 1.74 and column: eelen
# row: 144 and error: 0.07 and column: ethee
# row: 144 and error: 8.09 and column: ehadr
# row: 144 and error: 0.3 and column: radco
# row: 144 and error: 0.0 and column: egamp
# row: 144 and error: 0.5 and column: effic
# row: 144 and error: 0.0 and column: enois
# row: 145 and error: 0.19 and column: eelen
# row: 145 and error: 0.0 and column: ethee
# row: 145 and error: 0.24 and column: ehadr
# row: 145 and error: 0.3 and column: radco
# row: 145 and error: 1.0 and column: egamp
# row: 145 and error: 0.5 and column: effic
# row: 145 and error: 0.0 and column: enois
# row: 146 and error: 0.25 and column: eelen
# row: 146 and error: 0.01 and column: ethee
# row: 146 and error: 0.58 and column: ehadr
# row: 146 and error: 0.3 and column: radco
# row: 146 and error: 0.0 and column: egamp
# row: 146 and error: 0.5 and column: effic
# row: 146 and error: 0.0 and column: enois
# row: 147 and error: 0.35 and column: eelen
# row: 147 and error: 0.01 and column: ethee
# row: 147 and error: 1.08 and column: ehadr
# row: 147 and error: 0.3 and column: radco
# row: 147 and error: 0.0 and column: egamp
# row: 147 and error: 0.5 and column: effic
# row: 147 and error: 0.0 and column: enois
# row: 148 and error: 0.48 and column: eelen
# row: 148 and error: 0.01 and column: ethee
# row: 148 and error: 1.78 and column: ehadr
# row: 148 and error: 0.3 and column: radco
# row: 148 and error: 0.0 and column: egamp
# row: 148 and error: 0.5 and column: effic
# row: 148 and error: 0.0 and column: enois
# row: 149 and error: 0.69 and column: eelen
# row: 149 and error: 0.02 and column: ethee
# row: 149 and error: 2.81 and column: ehadr
# row: 149 and error: 0.3 and column: radco
# row: 149 and error: 0.0 and column: egamp
# row: 149 and error: 0.5 and column: effic
# row: 149 and error: 0.0 and column: enois
# row: 150 and error: 1.02 and column: eelen
# row: 150 and error: 0.03 and column: ethee
# row: 150 and error: 4.47 and column: ehadr
# row: 150 and error: 0.3 and column: radco
# row: 150 and error: 0.0 and column: egamp
# row: 150 and error: 0.5 and column: effic
# row: 150 and error: 0.0 and column: enois
# row: 151 and error: 1.76 and column: eelen
# row: 151 and error: 0.05 and column: ethee
# row: 151 and error: 8.13 and column: ehadr
# row: 151 and error: 0.3 and column: radco
# row: 151 and error: 0.0 and column: egamp
# row: 151 and error: 0.5 and column: effic
# row: 151 and error: 0.0 and column: enois
# row: 152 and error: 0.35 and column: eelen
# row: 152 and error: 0.0 and column: ethee
# row: 152 and error: 1.06 and column: ehadr
# row: 152 and error: 0.3 and column: radco
# row: 152 and error: 1.0 and column: egamp
# row: 152 and error: 0.5 and column: effic
# row: 152 and error: 0.0 and column: enois
# row: 153 and error: 0.49 and column: eelen
# row: 153 and error: 0.01 and column: ethee
# row: 153 and error: 1.73 and column: ehadr
# row: 153 and error: 0.3 and column: radco
# row: 153 and error: 1.0 and column: egamp
# row: 153 and error: 0.5 and column: effic
# row: 153 and error: 0.0 and column: enois
# row: 154 and error: 0.7 and column: eelen
# row: 154 and error: 0.01 and column: ethee
# row: 154 and error: 2.76 and column: ehadr
# row: 154 and error: 0.3 and column: radco
# row: 154 and error: 0.0 and column: egamp
# row: 154 and error: 0.5 and column: effic
# row: 154 and error: 0.0 and column: enois
# row: 155 and error: 1.03 and column: eelen
# row: 155 and error: 0.02 and column: ethee
# row: 155 and error: 4.44 and column: ehadr
# row: 155 and error: 0.3 and column: radco
# row: 155 and error: 0.0 and column: egamp
# row: 155 and error: 0.5 and column: effic
# row: 155 and error: 0.0 and column: enois
# row: 156 and error: 1.78 and column: eelen
# row: 156 and error: 0.03 and column: ethee
# row: 156 and error: 8.14 and column: ehadr
# row: 156 and error: 0.3 and column: radco
# row: 156 and error: 0.0 and column: egamp
# row: 156 and error: 0.5 and column: effic
# row: 156 and error: 0.0 and column: enois
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D7_datanc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D7_datanc-thexp.dat
