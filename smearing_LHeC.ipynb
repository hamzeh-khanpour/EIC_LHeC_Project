# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC_Ee60/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for column in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , column))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std)

            sys_shift = 0.0
            print(f'df.at[i, column_to_modify] : {df.at[i, column_to_modify]}' )
            for col in find_corr_err(df):   
                sys_shift += sysErrDict[df.at[i, col]]**2
                # sys_shift += sysErrDict[df.at[i, col]]* sysErrDict[df.at[i, col]]/100.0
                # print(f'row: {i} and error: {df.at[i, col]} and column: {col}, sys_shift is:{sys_shift}')
                df.at[i, column_to_modify] += df.at[i, column_to_modify] * sysErrDict[df.at[i, col]]/100.0    # all errors are in percent

            
            sys_shift  = sys_shift**0.5
            # print(f'df.at[i, column_to_modify] shifted: {df.at[i, column_to_modify]}' )
            sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift 
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# df.at[i, column_to_modify] : 3.012635618979197
# row: 0 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.117967134907682
# df.at[i, column_to_modify] : 3.67601008001341
# row: 1 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.804535319460523
# df.at[i, column_to_modify] : 3.2760933042803266
# row: 2 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.3906361556922513
# df.at[i, column_to_modify] : 3.039670933151808
# row: 3 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.1459476913815734
# df.at[i, column_to_modify] : 2.6679243671796704
# row: 4 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.7612036593075375
# df.at[i, column_to_modify] : 2.0395784045264604
# row: 5 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.1108886830913027
# df.at[i, column_to_modify] : 1.6932051582267635
# row: 6 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.7524051042708146
# df.at[i, column_to_modify] : 1.2259749797901882
# row: 7 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.2688390428378957
# df.at[i, column_to_modify] : 1.0104857231244793
# row: 8 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.0458155825904765
# df.at[i, column_to_modify] : 3.1270103469751587
# row: 9 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.2363407744905035
# df.at[i, column_to_modify] : 3.5507532764106227
# row: 10 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.6748991316000708
# df.at[i, column_to_modify] : 3.2922718349911753
# row: 11 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.407380340329029
# df.at[i, column_to_modify] : 2.7178985427910898
# row: 12 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.8129250942427415
# df.at[i, column_to_modify] : 2.063491096479365
# row: 13 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.135637440341139
# df.at[i, column_to_modify] : 1.8850370923054363
# row: 14 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.9509441051758585
# df.at[i, column_to_modify] : 1.3548258128313475
# row: 15 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.4021949190669438
# df.at[i, column_to_modify] : 0.9668721761173201
# row: 16 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.000677164473004
# df.at[i, column_to_modify] : 0.8598016389906852
# row: 17 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.8898630939712153
# df.at[i, column_to_modify] : 2.730714885642082
# row: 18 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.826189538023249
# df.at[i, column_to_modify] : 3.050987667606744
# row: 19 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 3.1576600955909226
# df.at[i, column_to_modify] : 2.7617556983414517
# row: 20 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.8583156382484907
# df.at[i, column_to_modify] : 2.1688007868069468
# row: 21 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.2446290991266
# df.at[i, column_to_modify] : 1.8547282955161528
# row: 22 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.9195756145119918
# df.at[i, column_to_modify] : 1.3947970527778368
# row: 23 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.4435636832512073
# df.at[i, column_to_modify] : 0.9980644500692283
# row: 24 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.032960021527599
# df.at[i, column_to_modify] : 0.8380822010878445
# row: 25 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.8673842740491857
# df.at[i, column_to_modify] : 0.5513403519325774
# row: 26 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.5706169994951792
# df.at[i, column_to_modify] : 2.324553601064716
# row: 27 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.4058275371207896
# df.at[i, column_to_modify] : 2.5708456648501357
# row: 28 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.6607307705665026
# df.at[i, column_to_modify] : 2.184808651652333
# row: 29 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.2611966508655224
# df.at[i, column_to_modify] : 1.8762943812240933
# row: 30 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.9418957205488265
# df.at[i, column_to_modify] : 1.4262003894610376
# row: 31 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.4760649824749874
# df.at[i, column_to_modify] : 1.0078512711121037
# row: 32 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.0430890215881001
# df.at[i, column_to_modify] : 0.8174325749457186
# row: 33 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.8460126699780982
# df.at[i, column_to_modify] : 0.5560785067097065
# row: 34 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.575520815536563
# df.at[i, column_to_modify] : 0.36924092483244925
# row: 35 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.3821507855903912
# df.at[i, column_to_modify] : 0.24449819238024265
# row: 36 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.2354191211675517
# df.at[i, column_to_modify] : 0.1745873666786698
# row: 37 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.18375729141168518
# df.at[i, column_to_modify] : 2.0362237326715333
# row: 38 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.10741672102388
# df.at[i, column_to_modify] : 2.0562354605902105
# row: 39 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 2.1281281238799252
# df.at[i, column_to_modify] : 1.8323103442437725
# row: 40 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.8963738589266521
# df.at[i, column_to_modify] : 1.394724329143387
# row: 41 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.4434884169625406
# df.at[i, column_to_modify] : 1.004918420307048
# row: 42 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.0400536288030777
# df.at[i, column_to_modify] : 0.8130470441007726
# row: 43 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.8414738067456775
# df.at[i, column_to_modify] : 0.6080801563876084
# row: 44 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.629340611609883
# df.at[i, column_to_modify] : 0.4318153642623705
# row: 45 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.4469130304495538
# df.at[i, column_to_modify] : 0.2886263274947792
# row: 46 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.27790862461251314
# df.at[i, column_to_modify] : 0.0929427628946843
# row: 47 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.09782443421166669
# df.at[i, column_to_modify] : 0.08669772016158492
# row: 48 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.08637779449363311
# df.at[i, column_to_modify] : 0.0029146267303903507
# row: 49 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: 0.0028554613508888047
# df.at[i, column_to_modify] : 1.5716467856567125
# row: 50 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.626596656591799
# df.at[i, column_to_modify] : 1.617248881803604
# row: 51 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.6737931499789038
# df.at[i, column_to_modify] : 1.3373350049454298
# row: 52 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.3840925757872895
# df.at[i, column_to_modify] : 0.9804025615927736
# row: 53 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.0146806161248805
# df.at[i, column_to_modify] : 0.8490559354601405
# row: 54 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.8787416857801202
# df.at[i, column_to_modify] : 0.5457993922247285
# row: 55 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.5648823098579457
# df.at[i, column_to_modify] : 0.3634547692951444
# row: 56 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.37616232728195037
# df.at[i, column_to_modify] : 0.23993670389599825
# row: 57 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.231027016670899
# df.at[i, column_to_modify] : 0.13234862667078653
# row: 58 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.13930002852864695
# df.at[i, column_to_modify] : 0.04363300776617014
# row: 59 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.0434719963909192
# df.at[i, column_to_modify] : 0.015079611648667368
# row: 60 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: 0.014773503515976961
# df.at[i, column_to_modify] : 0.0038296175884808435
# row: 61 and error: 8.67 and column: ccsys, sys_shift is:0.039896266862767996
# df.at[i, column_to_modify] shifted: 0.003906110561216302
# df.at[i, column_to_modify] : 1.23792751205843
# row: 62 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.281209474414991
# df.at[i, column_to_modify] : 1.173506411173402
# row: 63 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.2145360028246397
# df.at[i, column_to_modify] : 0.9610515161443876
# row: 64 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.9946529953419141
# df.at[i, column_to_modify] : 0.7993230499298652
# row: 65 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.8272699772101784
# df.at[i, column_to_modify] : 0.519741793829492
# row: 66 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.5379136532772669
# df.at[i, column_to_modify] : 0.3942692066539094
# row: 67 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.4080541373501909
# df.at[i, column_to_modify] : 0.2251796018020277
# row: 68 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.21681789728183018
# df.at[i, column_to_modify] : 0.10297308728690653
# row: 69 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.10838158549562898
# df.at[i, column_to_modify] : 0.04618994780629672
# row: 70 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.04601950099550346
# df.at[i, column_to_modify] : 0.01797030335364279
# row: 71 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: 0.017605515709794555
# df.at[i, column_to_modify] : 0.0004001433381530964
# row: 72 and error: 8.67 and column: ccsys, sys_shift is:0.039896266862767996
# df.at[i, column_to_modify] shifted: 0.0004081358211487059
# df.at[i, column_to_modify] : 0.9720537033974911
# row: 73 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 1.0060398547586864
# df.at[i, column_to_modify] : 0.8891449981450732
# row: 74 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.9202323921680465
# df.at[i, column_to_modify] : 0.7390121271116583
# row: 75 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.7648503888475999
# df.at[i, column_to_modify] : 0.5105777774075654
# row: 76 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.5284292331079923
# df.at[i, column_to_modify] : 0.3721566705129794
# row: 77 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.385168475200236
# df.at[i, column_to_modify] : 0.24822517857005078
# row: 78 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.2390077113524791
# df.at[i, column_to_modify] : 0.1635629200746903
# row: 79 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.17215380322236748
# df.at[i, column_to_modify] : 0.04145585398852366
# row: 80 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.041302876588967224
# df.at[i, column_to_modify] : 0.005106030135815898
# row: 81 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: 0.0050023804274048934
# df.at[i, column_to_modify] : 0.003312193840257457
# row: 82 and error: 8.67 and column: ccsys, sys_shift is:0.039896266862767996
# df.at[i, column_to_modify] shifted: 0.00337835176523656
# df.at[i, column_to_modify] : 0.7686539862317951
# row: 83 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.7955286235374848
# df.at[i, column_to_modify] : 0.7442262503870273
# row: 84 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.7702468147902323
# df.at[i, column_to_modify] : 0.5285475895664393
# row: 85 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.5470273282041455
# df.at[i, column_to_modify] : 0.3477859648056165
# row: 86 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.35994569054903014
# df.at[i, column_to_modify] : 0.24866804887718041
# row: 87 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.23943413633943167
# df.at[i, column_to_modify] : 0.09639337133219478
# row: 88 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.10145628038852239
# df.at[i, column_to_modify] : 0.05353868513377835
# row: 89 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.05334112054302831
# df.at[i, column_to_modify] : -0.006689484424325086
# row: 90 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: -0.00655369143220432
# df.at[i, column_to_modify] : 0.0050875129001178
# row: 91 and error: 8.67 and column: ccsys, sys_shift is:0.039896266862767996
# df.at[i, column_to_modify] shifted: 0.005189131136552311
# df.at[i, column_to_modify] : 0.6395602973906418
# row: 92 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.6619214004817137
# df.at[i, column_to_modify] : 0.511487705914726
# row: 93 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.5293709756680846
# df.at[i, column_to_modify] : 0.38131635023376603
# row: 94 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.3946484070432281
# df.at[i, column_to_modify] : 0.2142170080719113
# row: 95 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.20626238291775154
# df.at[i, column_to_modify] : 0.06835552188991498
# row: 96 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.0719457873411957
# df.at[i, column_to_modify] : 0.044330802956648846
# row: 97 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.04416721662796209
# df.at[i, column_to_modify] : 0.011876052343901376
# row: 98 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: 0.011634974768999343
# df.at[i, column_to_modify] : 0.44519582915058403
# row: 99 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.4607613198040335
# df.at[i, column_to_modify] : 0.27634639425922
# row: 100 and error: 2.0 and column: ccsys, sys_shift is:0.12224284704396976
# df.at[i, column_to_modify] shifted: 0.2860083608260752
# df.at[i, column_to_modify] : 0.14849712166760065
# row: 101 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.14298290526634794
# df.at[i, column_to_modify] : 0.16870936322047342
# row: 102 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.17757055513783626
# df.at[i, column_to_modify] : 0.08192276298582812
# row: 103 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.08162045752012671
# df.at[i, column_to_modify] : 0.03205107674713152
# row: 104 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: 0.03140045685834623
# df.at[i, column_to_modify] : 0.3457697277946806
# row: 105 and error: 3.33 and column: ccsys, sys_shift is:0.1378896088972472
# df.at[i, column_to_modify] shifted: 0.33293009102158544
# df.at[i, column_to_modify] : 0.15234507490459132
# row: 106 and error: 4.67 and column: ccsys, sys_shift is:0.2758709134811252
# df.at[i, column_to_modify] shifted: 0.16034675851376032
# df.at[i, column_to_modify] : 0.17902202009748963
# row: 107 and error: 6.0 and column: ccsys, sys_shift is:0.0013617043230294823
# df.at[i, column_to_modify] shifted: 0.1783614059631038
# df.at[i, column_to_modify] : 0.008711681212502478
# row: 108 and error: 7.33 and column: ccsys, sys_shift is:0.04120685049410585
# df.at[i, column_to_modify] shifted: 0.008534838696217326
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D6_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D6_datacc-thexp.dat
# df.at[i, column_to_modify] : 5.252578636370235
# row: 0 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 5.200830976193194
# df.at[i, column_to_modify] : 6.5028523748414475
# row: 1 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 6.438787195018208
# df.at[i, column_to_modify] : 6.164592179935871
# row: 2 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 6.1038594916047515
# df.at[i, column_to_modify] : 5.580913165458334
# row: 3 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 5.525930800041851
# df.at[i, column_to_modify] : 4.622379267706608
# row: 4 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 4.576840242379425
# df.at[i, column_to_modify] : 3.4880464844013095
# row: 5 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.4536827448645595
# df.at[i, column_to_modify] : 3.0096856620992134
# row: 6 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 2.9800346655765506
# df.at[i, column_to_modify] : 1.998246632905894
# row: 7 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.9785601903282368
# df.at[i, column_to_modify] : 4.68423489427741
# row: 8 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 4.638086476085233
# df.at[i, column_to_modify] : 5.906017538560878
# row: 9 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 5.8478322909438525
# df.at[i, column_to_modify] : 5.857280160679814
# row: 10 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 5.799575066801192
# df.at[i, column_to_modify] : 5.110352165384436
# row: 11 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 5.060005700239067
# df.at[i, column_to_modify] : 3.884890065682249
# row: 12 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.8466166794349532
# df.at[i, column_to_modify] : 3.2269168746828893
# row: 13 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.195125747046189
# df.at[i, column_to_modify] : 2.1073800143597676
# row: 14 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 2.086618405177589
# df.at[i, column_to_modify] : 1.40651258643333
# row: 15 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.3926558238037312
# df.at[i, column_to_modify] : 4.178154147947905
# row: 16 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 4.136991565532058
# df.at[i, column_to_modify] : 4.636133411362766
# row: 17 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 4.59045888216192
# df.at[i, column_to_modify] : 3.9059935738098748
# row: 18 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.8675122787919096
# df.at[i, column_to_modify] : 3.3986000634011626
# row: 19 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.365117537325153
# df.at[i, column_to_modify] : 2.1801927273026287
# row: 20 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 2.158713777593676
# df.at[i, column_to_modify] : 1.3969346004439094
# row: 21 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.383172198774607
# df.at[i, column_to_modify] : 1.043204343591075
# row: 22 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.032926842271329
# df.at[i, column_to_modify] : 0.5186377718138863
# row: 23 and error: 3.33 and column: ccsys, sys_shift is:0.05562017406151419
# df.at[i, column_to_modify] shifted: 0.5064062550579387
# df.at[i, column_to_modify] : 3.0513693053712774
# row: 24 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.021307647503719
# df.at[i, column_to_modify] : 3.3537365524538747
# row: 25 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.320696015328354
# df.at[i, column_to_modify] : 3.1324251482082395
# row: 26 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 3.101564939666647
# df.at[i, column_to_modify] : 2.1621241151539405
# row: 27 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 2.1408231748506665
# df.at[i, column_to_modify] : 1.3709012914872951
# row: 28 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.3573953662876344
# df.at[i, column_to_modify] : 1.00782535067973
# row: 29 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 0.9978963981832047
# df.at[i, column_to_modify] : 0.46562321862043776
# row: 30 and error: 3.33 and column: ccsys, sys_shift is:0.05562017406151419
# df.at[i, column_to_modify] shifted: 0.45464199336066646
# df.at[i, column_to_modify] : 0.0950413987123528
# row: 31 and error: 6.0 and column: ccsys, sys_shift is:0.15286401132951613
# df.at[i, column_to_modify] shifted: 0.09132548650247772
# df.at[i, column_to_modify] : 0.0044444830908770576
# row: 32 and error: 8.67 and column: ccsys, sys_shift is:2.1364962459047168
# df.at[i, column_to_modify] shifted: 0.0037948437376861426
# df.at[i, column_to_modify] : 2.2127845148969625
# row: 33 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 2.1909844755164882
# df.at[i, column_to_modify] : 2.0279098198465557
# row: 34 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 2.00793113975589
# df.at[i, column_to_modify] : 1.3652288296680553
# row: 35 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.3517787887581711
# df.at[i, column_to_modify] : 0.9567501747598596
# row: 36 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 0.9473244076566351
# df.at[i, column_to_modify] : 0.4292463294893426
# row: 37 and error: 3.33 and column: ccsys, sys_shift is:0.05562017406151419
# df.at[i, column_to_modify] shifted: 0.4191230142259452
# df.at[i, column_to_modify] : 0.09088122106799452
# row: 38 and error: 6.0 and column: ccsys, sys_shift is:0.15286401132951613
# df.at[i, column_to_modify] shifted: 0.08732796276592553
# df.at[i, column_to_modify] : 0.00354221152652806
# row: 39 and error: 8.67 and column: ccsys, sys_shift is:2.1364962459047168
# df.at[i, column_to_modify] shifted: 0.003024455027536635
# df.at[i, column_to_modify] : 1.6086595833403738
# row: 40 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.5928112971514088
# df.at[i, column_to_modify] : 1.2912297341136822
# row: 41 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.278508721803892
# df.at[i, column_to_modify] : 0.9371384434234497
# row: 42 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 0.9279058883174054
# df.at[i, column_to_modify] : 0.38679733850954084
# row: 43 and error: 3.33 and column: ccsys, sys_shift is:0.05562017406151419
# df.at[i, column_to_modify] shifted: 0.37767513726571555
# df.at[i, column_to_modify] : 0.08165930349371861
# row: 44 and error: 6.0 and column: ccsys, sys_shift is:0.15286401132951613
# df.at[i, column_to_modify] shifted: 0.0784666021339609
# df.at[i, column_to_modify] : 0.0027532298017478867
# row: 45 and error: 8.67 and column: ccsys, sys_shift is:2.1364962459047168
# df.at[i, column_to_modify] shifted: 0.0023507968548738575
# df.at[i, column_to_modify] : 1.1680816124599265
# row: 46 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 1.1565738379885293
# df.at[i, column_to_modify] : 0.8973133957446738
# row: 47 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 0.8884731913631949
# df.at[i, column_to_modify] : 0.3519042338973938
# row: 48 and error: 3.33 and column: ccsys, sys_shift is:0.05562017406151419
# df.at[i, column_to_modify] shifted: 0.3436049491801413
# df.at[i, column_to_modify] : 0.06841078985517583
# row: 49 and error: 6.0 and column: ccsys, sys_shift is:0.15286401132951613
# df.at[i, column_to_modify] shifted: 0.06573607659596319
# df.at[i, column_to_modify] : 0.002491421677009466
# row: 50 and error: 8.67 and column: ccsys, sys_shift is:2.1364962459047168
# df.at[i, column_to_modify] shifted: 0.002127256591062686
# df.at[i, column_to_modify] : 0.802843998196925
# row: 51 and error: 2.0 and column: ccsys, sys_shift is:0.009705911099513912
# df.at[i, column_to_modify] shifted: 0.7949344929291311
# df.at[i, column_to_modify] : 0.34189403866840634
# row: 52 and error: 3.33 and column: ccsys, sys_shift is:0.05562017406151419
# df.at[i, column_to_modify] shifted: 0.33383083369182803
# df.at[i, column_to_modify] : 0.05852612022714099
# row: 53 and error: 6.0 and column: ccsys, sys_shift is:0.15286401132951613
# df.at[i, column_to_modify] shifted: 0.05623787607569645
# df.at[i, column_to_modify] : 0.0021534644870032787
# row: 54 and error: 8.67 and column: ccsys, sys_shift is:2.1364962459047168
# df.at[i, column_to_modify] shifted: 0.0018386977868378503
# df.at[i, column_to_modify] : 0.0022209470186505932
# row: 55 and error: 8.67 and column: ccsys, sys_shift is:2.1364962459047168
# df.at[i, column_to_modify] shifted: 0.0018963165599074725
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D1_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D1_datacc-thexp.dat
# df.at[i, column_to_modify] : 5.352660678935598
# row: 0 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 5.348129094171387
# df.at[i, column_to_modify] : 6.594418463471544
# row: 1 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 6.588835601409038
# df.at[i, column_to_modify] : 6.231002574473547
# row: 2 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 6.2257273818121925
# df.at[i, column_to_modify] : 5.637994188045653
# row: 3 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 5.633221038747435
# df.at[i, column_to_modify] : 4.575293115911316
# row: 4 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 4.5714196537549245
# df.at[i, column_to_modify] : 3.5389049250738998
# row: 5 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.5359088734647317
# df.at[i, column_to_modify] : 3.0081628931003928
# row: 6 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.005616169900044
# df.at[i, column_to_modify] : 2.0125572968827696
# row: 7 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 2.0108534575156405
# df.at[i, column_to_modify] : 4.648673477451788
# row: 8 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 4.644737891176515
# df.at[i, column_to_modify] : 5.916319340638769
# row: 9 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 5.911310560110284
# df.at[i, column_to_modify] : 5.850973488045431
# row: 10 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 5.846020029587179
# df.at[i, column_to_modify] : 5.022864035558268
# row: 11 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 5.0186116580022215
# df.at[i, column_to_modify] : 3.8501974420124356
# row: 12 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.8469378488654074
# df.at[i, column_to_modify] : 3.2303461893051018
# row: 13 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.2276113648033005
# df.at[i, column_to_modify] : 2.1078223405884433
# row: 14 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 2.106037849439609
# df.at[i, column_to_modify] : 1.4053168692023945
# row: 15 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.4041271221036429
# df.at[i, column_to_modify] : 4.210983241695819
# row: 16 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 4.207418205792177
# df.at[i, column_to_modify] : 4.602939477612273
# row: 17 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 4.599042609931231
# df.at[i, column_to_modify] : 3.9207544881257026
# row: 18 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.917435161090361
# df.at[i, column_to_modify] : 3.372131454228613
# row: 19 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.3692765937325917
# df.at[i, column_to_modify] : 2.1709048873886734
# row: 20 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 2.169066990293691
# df.at[i, column_to_modify] : 1.401646763007976
# row: 21 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.4004601230363731
# df.at[i, column_to_modify] : 1.0474079275879087
# row: 22 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.0465211876857794
# df.at[i, column_to_modify] : 0.5006995661393479
# row: 23 and error: 3.33 and column: ccsys, sys_shift is:0.365092566960603
# df.at[i, column_to_modify] shifted: 0.4704458511920242
# df.at[i, column_to_modify] : 3.0685822146951414
# row: 24 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.065984340246166
# df.at[i, column_to_modify] : 3.374895126434947
# row: 25 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.3720379262025566
# df.at[i, column_to_modify] : 3.140861999276219
# row: 26 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 3.138202932461388
# df.at[i, column_to_modify] : 2.168278788536793
# row: 27 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 2.1664431147080068
# df.at[i, column_to_modify] : 1.3743937724162427
# row: 28 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.3732302049396758
# df.at[i, column_to_modify] : 1.0132148043733369
# row: 29 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.0123570125113495
# df.at[i, column_to_modify] : 0.4636886972526115
# row: 30 and error: 3.33 and column: ccsys, sys_shift is:0.365092566960603
# df.at[i, column_to_modify] shifted: 0.4356712859751426
# df.at[i, column_to_modify] : 0.10385634366096325
# row: 31 and error: 6.0 and column: ccsys, sys_shift is:0.005002029219725198
# df.at[i, column_to_modify] shifted: 0.10312181940648686
# df.at[i, column_to_modify] : 0.004535002701137428
# row: 32 and error: 8.67 and column: ccsys, sys_shift is:0.016994698557610023
# df.at[i, column_to_modify] shifted: 0.0045941226817448
# df.at[i, column_to_modify] : 2.205568166735246
# row: 33 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 2.2037009235639875
# df.at[i, column_to_modify] : 1.9851667237105393
# row: 34 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.9834860733164301
# df.at[i, column_to_modify] : 1.3555808207329716
# row: 35 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.3544331803794434
# df.at[i, column_to_modify] : 0.973013952791433
# row: 36 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 0.9721901951373777
# df.at[i, column_to_modify] : 0.42309851916496805
# row: 37 and error: 3.33 and column: ccsys, sys_shift is:0.365092566960603
# df.at[i, column_to_modify] shifted: 0.397533683764473
# df.at[i, column_to_modify] : 0.08952562645262731
# row: 38 and error: 6.0 and column: ccsys, sys_shift is:0.005002029219725198
# df.at[i, column_to_modify] shifted: 0.0888924562320261
# df.at[i, column_to_modify] : 0.00357635026697694
# row: 39 and error: 8.67 and column: ccsys, sys_shift is:0.016994698557610023
# df.at[i, column_to_modify] shifted: 0.003622972898177538
# df.at[i, column_to_modify] : 1.5859211839100125
# row: 40 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.5845785364482505
# df.at[i, column_to_modify] : 1.2854649040485835
# row: 41 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.2843766241213619
# df.at[i, column_to_modify] : 0.9273459364087837
# row: 42 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 0.9265608414870898
# df.at[i, column_to_modify] : 0.3947140115129539
# row: 43 and error: 3.33 and column: ccsys, sys_shift is:0.365092566960603
# df.at[i, column_to_modify] shifted: 0.3708642501039254
# df.at[i, column_to_modify] : 0.07885143467349064
# row: 44 and error: 6.0 and column: ccsys, sys_shift is:0.005002029219725198
# df.at[i, column_to_modify] shifted: 0.07829375770137412
# df.at[i, column_to_modify] : 0.002914904837444409
# row: 45 and error: 8.67 and column: ccsys, sys_shift is:0.016994698557610023
# df.at[i, column_to_modify] shifted: 0.002952904620205029
# df.at[i, column_to_modify] : 1.1612886897596215
# row: 46 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 1.1603055379312095
# df.at[i, column_to_modify] : 0.8738903441698197
# row: 47 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 0.8731505049745546
# df.at[i, column_to_modify] : 0.3561748275663504
# row: 48 and error: 3.33 and column: ccsys, sys_shift is:0.365092566960603
# df.at[i, column_to_modify] shifted: 0.3346537150403499
# df.at[i, column_to_modify] : 0.06577411353653333
# row: 49 and error: 6.0 and column: ccsys, sys_shift is:0.005002029219725198
# df.at[i, column_to_modify] shifted: 0.06530892595139184
# df.at[i, column_to_modify] : 0.0024956579136720465
# row: 50 and error: 8.67 and column: ccsys, sys_shift is:0.016994698557610023
# df.at[i, column_to_modify] shifted: 0.002528192237724802
# df.at[i, column_to_modify] : 0.8307627547035682
# row: 51 and error: 2.0 and column: ccsys, sys_shift is:7.167385930865512e-05
# df.at[i, column_to_modify] shifted: 0.8300594275046849
# df.at[i, column_to_modify] : 0.3344249848216545
# row: 52 and error: 3.33 and column: ccsys, sys_shift is:0.365092566960603
# df.at[i, column_to_modify] shifted: 0.3142180606573911
# df.at[i, column_to_modify] : 0.06206350412595763
# row: 53 and error: 6.0 and column: ccsys, sys_shift is:0.005002029219725198
# df.at[i, column_to_modify] shifted: 0.06162455983530237
# df.at[i, column_to_modify] : 0.002113177876150825
# row: 54 and error: 8.67 and column: ccsys, sys_shift is:0.016994698557610023
# df.at[i, column_to_modify] shifted: 0.0021407260482889873
# df.at[i, column_to_modify] : 0.0018035084293264393
# row: 55 and error: 8.67 and column: ccsys, sys_shift is:0.016994698557610023
# df.at[i, column_to_modify] shifted: 0.0018270196354697717
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D2_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D2_datacc-thexp.dat
# df.at[i, column_to_modify] : 1.5167920084449402
# row: 0 and error: 0.05 and column: eelen, sys_shift is:7.339965960096678e-06
# row: 0 and error: 0.27 and column: ethee, sys_shift is:0.0003100836345779027
# row: 0 and error: 0.07 and column: ehadr, sys_shift is:0.00041622290927124993
# row: 0 and error: 0.3 and column: radco, sys_shift is:0.0005132372090856415
# row: 0 and error: 1.0 and column: egamp, sys_shift is:0.0043928066761613335
# row: 0 and error: 0.5 and column: effic, sys_shift is:0.004823338511390781
# row: 0 and error: 0.0 and column: enois, sys_shift is:0.004823338511390781
# df.at[i, column_to_modify] shifted: 1.5096434983517595
# df.at[i, column_to_modify] : 1.3024822253400117
# row: 1 and error: 0.06 and column: eelen, sys_shift is:5.975800465934852e-05
# row: 1 and error: 0.5 and column: ethee, sys_shift is:0.000490289839888796
# row: 1 and error: 0.07 and column: ehadr, sys_shift is:0.0005964291145821431
# row: 1 and error: 0.3 and column: radco, sys_shift is:0.0006934434143965346
# row: 1 and error: 0.0 and column: egamp, sys_shift is:0.0006934434143965346
# row: 1 and error: 0.5 and column: effic, sys_shift is:0.001123975249625982
# row: 1 and error: 0.0 and column: enois, sys_shift is:0.001123975249625982
# df.at[i, column_to_modify] shifted: 1.3042495982209954
# df.at[i, column_to_modify] : 1.185107299907892
# row: 2 and error: 0.07 and column: eelen, sys_shift is:0.00010613927469334719
# row: 2 and error: 0.6 and column: ethee, sys_shift is:0.00035814011699043693
# row: 2 and error: 0.1 and column: ehadr, sys_shift is:0.0004518770186843207
# row: 2 and error: 0.3 and column: radco, sys_shift is:0.0005488913184987122
# row: 2 and error: 0.0 and column: egamp, sys_shift is:0.0005488913184987122
# row: 2 and error: 0.5 and column: effic, sys_shift is:0.0009794231537281596
# row: 2 and error: 0.0 and column: enois, sys_shift is:0.0009794231537281596
# df.at[i, column_to_modify] shifted: 1.1844385636831067
# df.at[i, column_to_modify] : 0.9978056246304962
# row: 3 and error: 0.08 and column: eelen, sys_shift is:4.832565841928724e-05
# row: 3 and error: 0.68 and column: ethee, sys_shift is:0.0014235142158957096
# row: 3 and error: 0.1 and column: ehadr, sys_shift is:0.0015172511175895933
# row: 3 and error: 0.3 and column: radco, sys_shift is:0.0016142654174039848
# row: 3 and error: 0.0 and column: egamp, sys_shift is:0.0016142654174039848
# row: 3 and error: 0.5 and column: effic, sys_shift is:0.002044797252633432
# row: 3 and error: 0.0 and column: enois, sys_shift is:0.002044797252633432
# df.at[i, column_to_modify] shifted: 0.9954579475898779
# df.at[i, column_to_modify] : 0.8333333642955956
# row: 4 and error: 0.08 and column: eelen, sys_shift is:4.832565841928724e-05
# row: 4 and error: 0.74 and column: ethee, sys_shift is:0.013872308648015119
# row: 4 and error: 0.1 and column: ehadr, sys_shift is:0.013966045549709002
# row: 4 and error: 0.3 and column: radco, sys_shift is:0.014063059849523394
# row: 4 and error: 0.0 and column: egamp, sys_shift is:0.014063059849523394
# row: 4 and error: 0.5 and column: effic, sys_shift is:0.014493591684752841
# row: 4 and error: 0.0 and column: enois, sys_shift is:0.014493591684752841
# df.at[i, column_to_modify] shifted: 0.8246558793918505
# df.at[i, column_to_modify] : 0.7512061961541603
# row: 5 and error: 0.09 and column: eelen, sys_shift is:1.1727487191106888e-06
# row: 5 and error: 0.77 and column: ethee, sys_shift is:0.009211717271921232
# row: 5 and error: 0.09 and column: ehadr, sys_shift is:0.009212890020640341
# row: 5 and error: 0.3 and column: radco, sys_shift is:0.009309904320454733
# row: 5 and error: 0.0 and column: egamp, sys_shift is:0.009309904320454733
# row: 5 and error: 0.5 and column: effic, sys_shift is:0.00974043615568418
# row: 5 and error: 0.0 and column: enois, sys_shift is:0.00974043615568418
# df.at[i, column_to_modify] shifted: 0.7446448567626621
# df.at[i, column_to_modify] : 0.6386331992520236
# row: 6 and error: 0.09 and column: eelen, sys_shift is:1.1727487191106888e-06
# row: 6 and error: 0.79 and column: ethee, sys_shift is:0.0033933619699700436
# row: 6 and error: 0.09 and column: ehadr, sys_shift is:0.0033945347186891545
# row: 6 and error: 0.3 and column: radco, sys_shift is:0.003491549018503546
# row: 6 and error: 0.0 and column: egamp, sys_shift is:0.003491549018503546
# row: 6 and error: 0.5 and column: effic, sys_shift is:0.003922080853732994
# row: 6 and error: 1.71 and column: enois, sys_shift is:0.0039414125314000716
# df.at[i, column_to_modify] shifted: 0.6431949952089211
# df.at[i, column_to_modify] : 0.5474848607602831
# row: 7 and error: 0.09 and column: eelen, sys_shift is:1.1727487191106888e-06
# row: 7 and error: 0.8 and column: ethee, sys_shift is:0.00010671362241606695
# row: 7 and error: 0.08 and column: ehadr, sys_shift is:0.0001550392808353542
# row: 7 and error: 0.3 and column: radco, sys_shift is:0.00025205358064974575
# row: 7 and error: 0.0 and column: egamp, sys_shift is:0.00025205358064974575
# row: 7 and error: 0.5 and column: effic, sys_shift is:0.0006825854158791932
# row: 7 and error: 2.0 and column: enois, sys_shift is:0.0117894769962853
# df.at[i, column_to_modify] shifted: 0.5424253035429925
# df.at[i, column_to_modify] : 0.5017886569935885
# row: 8 and error: 0.09 and column: eelen, sys_shift is:1.1727487191106888e-06
# row: 8 and error: 0.78 and column: ethee, sys_shift is:0.02302708625863997
# row: 8 and error: 0.08 and column: ehadr, sys_shift is:0.023075411917059255
# row: 8 and error: 0.3 and column: radco, sys_shift is:0.023172426216873647
# row: 8 and error: 0.0 and column: egamp, sys_shift is:0.023172426216873647
# row: 8 and error: 0.5 and column: effic, sys_shift is:0.023602958052103093
# row: 8 and error: 2.17 and column: enois, sys_shift is:0.04250096788337316
# df.at[i, column_to_modify] shifted: 0.4875192057709214
# df.at[i, column_to_modify] : 1.760273894975232
# row: 9 and error: 0.08 and column: eelen, sys_shift is:4.832565841928724e-05
# row: 9 and error: 0.32 and column: ethee, sys_shift is:0.0001843992103799941
# row: 9 and error: 0.06 and column: ehadr, sys_shift is:0.0002441572150393426
# row: 9 and error: 0.3 and column: radco, sys_shift is:0.00034117151485373417
# row: 9 and error: 1.0 and column: egamp, sys_shift is:0.0042207409819294255
# row: 9 and error: 0.5 and column: effic, sys_shift is:0.004651272817158873
# row: 9 and error: 0.0 and column: enois, sys_shift is:0.004651272817158873
# df.at[i, column_to_modify] shifted: 1.7466029449400537
# df.at[i, column_to_modify] : 1.6741872203035402
# row: 10 and error: 0.08 and column: eelen, sys_shift is:4.832565841928724e-05
# row: 10 and error: 0.37 and column: ethee, sys_shift is:4.8821306961939346e-05
# row: 10 and error: 0.06 and column: ehadr, sys_shift is:0.00010857931162128786
# row: 10 and error: 0.3 and column: radco, sys_shift is:0.0002055936114356794
# row: 10 and error: 0.0 and column: egamp, sys_shift is:0.0002055936114356794
# row: 10 and error: 0.5 and column: effic, sys_shift is:0.0006361254466651268
# row: 10 and error: 0.0 and column: enois, sys_shift is:0.0006361254466651268
# df.at[i, column_to_modify] shifted: 1.6736666159813414
# df.at[i, column_to_modify] : 1.47733858352245
# row: 11 and error: 0.07 and column: eelen, sys_shift is:0.00010613927469334719
# row: 11 and error: 0.39 and column: ethee, sys_shift is:0.0007118937625499375
# row: 11 and error: 0.09 and column: ehadr, sys_shift is:0.0007130665112690482
# row: 11 and error: 0.3 and column: radco, sys_shift is:0.0008100808110834397
# row: 11 and error: 0.0 and column: egamp, sys_shift is:0.0008100808110834397
# row: 11 and error: 0.5 and column: effic, sys_shift is:0.0012406126463128872
# row: 11 and error: 0.0 and column: enois, sys_shift is:0.0012406126463128872
# df.at[i, column_to_modify] shifted: 1.4808980019367568
# df.at[i, column_to_modify] : 1.2784980632740777
# row: 12 and error: 0.07 and column: eelen, sys_shift is:0.00010613927469334719
# row: 12 and error: 0.4 and column: ethee, sys_shift is:0.0014133135715799893
# row: 12 and error: 0.11 and column: ehadr, sys_shift is:0.0018669766738614894
# row: 12 and error: 0.3 and column: radco, sys_shift is:0.001963990973675881
# ...
# row: 132 and error: 0.3 and column: radco, sys_shift is:0.018715498778810187
# row: 132 and error: 0.0 and column: egamp, sys_shift is:0.018715498778810187
# row: 132 and error: 0.5 and column: effic, sys_shift is:0.03861480358920699
# row: 132 and error: 0.0 and column: enois, sys_shift is:0.03861480358920699
# df.at[i, column_to_modify] shifted: 0.14357270508557748
# df.at[i, column_to_modify] : 0.06851831174046596
# row: 133 and error: 0.47 and column: eelen, sys_shift is:0.003965196235882842
# row: 133 and error: 0.03 and column: ethee, sys_shift is:0.003968154242894554
# row: 133 and error: 1.8 and column: ehadr, sys_shift is:0.03064021621324609
# row: 133 and error: 0.3 and column: radco, sys_shift is:0.030661659571491306
# row: 133 and error: 0.0 and column: egamp, sys_shift is:0.030661659571491306
# row: 133 and error: 0.5 and column: effic, sys_shift is:0.05056096438188811
# row: 133 and error: 0.0 and column: enois, sys_shift is:0.05056096438188811
# df.at[i, column_to_modify] shifted: 0.06607204482338892
# df.at[i, column_to_modify] : 0.025288324552975822
# row: 134 and error: 0.67 and column: eelen, sys_shift is:0.004751817135508617
# row: 134 and error: 0.04 and column: ethee, sys_shift is:0.004759814268110782
# row: 134 and error: 2.8 and column: ehadr, sys_shift is:0.21050938658189872
# row: 134 and error: 0.3 and column: radco, sys_shift is:0.21053082994014394
# row: 134 and error: 0.0 and column: egamp, sys_shift is:0.21053082994014394
# row: 134 and error: 0.5 and column: effic, sys_shift is:0.23043013475054075
# row: 134 and error: 0.0 and column: enois, sys_shift is:0.23043013475054075
# df.at[i, column_to_modify] shifted: 0.025902133685355388
# df.at[i, column_to_modify] : 0.006830168151762191
# row: 135 and error: 1.0 and column: eelen, sys_shift is:0.02025237830276354
# row: 135 and error: 0.06 and column: ethee, sys_shift is:0.020257175402451096
# row: 135 and error: 4.43 and column: ehadr, sys_shift is:0.020430137146068107
# row: 135 and error: 0.3 and column: radco, sys_shift is:0.020451580504313324
# row: 135 and error: 0.0 and column: egamp, sys_shift is:0.020451580504313324
# row: 135 and error: 0.5 and column: effic, sys_shift is:0.04035088531471013
# row: 135 and error: 0.0 and column: enois, sys_shift is:0.04035088531471013
# df.at[i, column_to_modify] shifted: 0.006822329863988533
# df.at[i, column_to_modify] : 0.0012813424766823325
# row: 136 and error: 1.73 and column: eelen, sys_shift is:0.010300731101854683
# row: 136 and error: 0.1 and column: ethee, sys_shift is:0.010301135208995758
# row: 136 and error: 8.02 and column: ehadr, sys_shift is:0.2336490611281366
# row: 136 and error: 0.3 and column: radco, sys_shift is:0.23367050448638182
# row: 136 and error: 0.0 and column: egamp, sys_shift is:0.23367050448638182
# row: 136 and error: 0.5 and column: effic, sys_shift is:0.25356980929677864
# row: 136 and error: 0.0 and column: enois, sys_shift is:0.25356980929677864
# df.at[i, column_to_modify] shifted: 0.0013100648427566963
# df.at[i, column_to_modify] : 0.8910195112731841
# row: 137 and error: 0.15 and column: eelen, sys_shift is:0.00015196356659064273
# row: 137 and error: 0.0 and column: ethee, sys_shift is:0.00015196356659064273
# row: 137 and error: 0.08 and column: ehadr, sys_shift is:0.00015801163471162118
# row: 137 and error: 0.3 and column: radco, sys_shift is:0.00017945499295683986
# row: 137 and error: 1.0 and column: egamp, sys_shift is:0.020431833295720382
# row: 137 and error: 0.5 and column: effic, sys_shift is:0.04033113810611719
# row: 137 and error: 0.0 and column: enois, sys_shift is:0.04033113810611719
# df.at[i, column_to_modify] shifted: 0.8926825260614899
# df.at[i, column_to_modify] : 0.44953466704484846
# row: 138 and error: 0.19 and column: eelen, sys_shift is:0.00017177554626261228
# row: 138 and error: 0.01 and column: ethee, sys_shift is:0.00017217012738675617
# row: 138 and error: 0.28 and column: ehadr, sys_shift is:0.0004553021332285385
# row: 138 and error: 0.3 and column: radco, sys_shift is:0.0004767454914737572
# row: 138 and error: 0.0 and column: egamp, sys_shift is:0.0004767454914737572
# row: 138 and error: 0.5 and column: effic, sys_shift is:0.020376050301870563
# row: 138 and error: 0.0 and column: enois, sys_shift is:0.020376050301870563
# df.at[i, column_to_modify] shifted: 0.44353465339128606
# df.at[i, column_to_modify] : 0.2640711866341575
# row: 139 and error: 0.25 and column: eelen, sys_shift is:0.0019922670693984655
# row: 139 and error: 0.01 and column: ethee, sys_shift is:0.0019926616505226095
# row: 139 and error: 0.64 and column: ehadr, sys_shift is:0.005981054766275293
# row: 139 and error: 0.3 and column: radco, sys_shift is:0.006002498124520511
# row: 139 and error: 0.0 and column: egamp, sys_shift is:0.006002498124520511
# row: 139 and error: 0.5 and column: effic, sys_shift is:0.025901802934917315
# row: 139 and error: 0.0 and column: enois, sys_shift is:0.025901802934917315
# df.at[i, column_to_modify] shifted: 0.26092524989864957
# df.at[i, column_to_modify] : 0.15333570451292008
# row: 140 and error: 0.34 and column: eelen, sys_shift is:3.7797304751248064e-07
# row: 140 and error: 0.01 and column: ethee, sys_shift is:7.72554171656371e-07
# row: 140 and error: 1.13 and column: ehadr, sys_shift is:0.003389270300712091
# row: 140 and error: 0.3 and column: radco, sys_shift is:0.0034107136589573094
# row: 140 and error: 0.0 and column: egamp, sys_shift is:0.0034107136589573094
# row: 140 and error: 0.5 and column: effic, sys_shift is:0.023310018469354113
# row: 140 and error: 0.0 and column: enois, sys_shift is:0.023310018469354113
# df.at[i, column_to_modify] shifted: 0.1521041677089321
# df.at[i, column_to_modify] : 0.07072966597263962
# row: 141 and error: 0.48 and column: eelen, sys_shift is:0.00371473137619397
# row: 141 and error: 0.02 and column: ethee, sys_shift is:0.0037181936331244165
# row: 141 and error: 1.81 and column: ehadr, sys_shift is:0.04209277995224961
# row: 141 and error: 0.3 and column: radco, sys_shift is:0.04211422331049483
# row: 141 and error: 0.0 and column: egamp, sys_shift is:0.04211422331049483
# row: 141 and error: 0.5 and column: effic, sys_shift is:0.062013528120891635
# row: 141 and error: 0.0 and column: enois, sys_shift is:0.062013528120891635
# df.at[i, column_to_modify] shifted: 0.0707104728854241
# df.at[i, column_to_modify] : 0.022069512629411814
# row: 142 and error: 0.68 and column: eelen, sys_shift is:5.828527791133462e-05
# row: 142 and error: 0.03 and column: ethee, sys_shift is:6.124328492304732e-05
# row: 142 and error: 2.82 and column: ehadr, sys_shift is:0.3582169112804986
# row: 142 and error: 0.3 and column: radco, sys_shift is:0.3582383546387438
# row: 142 and error: 0.0 and column: egamp, sys_shift is:0.3582383546387438
# row: 142 and error: 0.5 and column: effic, sys_shift is:0.37813765944914063
# row: 142 and error: 0.0 and column: enois, sys_shift is:0.37813765944914063
# df.at[i, column_to_modify] shifted: 0.023092595269469406
# df.at[i, column_to_modify] : 0.00553507504353646
# row: 143 and error: 1.01 and column: eelen, sys_shift is:0.011784725525433278
# row: 143 and error: 0.04 and column: ethee, sys_shift is:0.011792722658035442
# row: 143 and error: 4.46 and column: ehadr, sys_shift is:0.7780307710551752
# row: 143 and error: 0.3 and column: radco, sys_shift is:0.7780522144134203
# row: 143 and error: 0.0 and column: egamp, sys_shift is:0.7780522144134203
# row: 143 and error: 0.5 and column: effic, sys_shift is:0.7979515192238171
# row: 143 and error: 0.0 and column: enois, sys_shift is:0.7979515192238171
# df.at[i, column_to_modify] shifted: 0.005037125472954312
# df.at[i, column_to_modify] : 0.0015135087967299108
# row: 144 and error: 1.74 and column: eelen, sys_shift is:0.0065306217339587405
# row: 144 and error: 0.07 and column: ethee, sys_shift is:0.006626314941645344
# row: 144 and error: 8.09 and column: ehadr, sys_shift is:2.041785527880324
# row: 144 and error: 0.3 and column: radco, sys_shift is:2.041806971238569
# row: 144 and error: 0.0 and column: egamp, sys_shift is:2.041806971238569
# row: 144 and error: 0.5 and column: effic, sys_shift is:2.0617062760489655
# row: 144 and error: 0.0 and column: enois, sys_shift is:2.0617062760489655
# df.at[i, column_to_modify] shifted: 0.001693687992223351
# df.at[i, column_to_modify] : 0.5283969195291359
# row: 145 and error: 0.19 and column: eelen, sys_shift is:0.00017177554626261228
# row: 145 and error: 0.0 and column: ethee, sys_shift is:0.00017177554626261228
# row: 145 and error: 0.24 and column: ehadr, sys_shift is:0.0008636982142250037
# row: 145 and error: 0.3 and column: radco, sys_shift is:0.0008851415724702224
# row: 145 and error: 1.0 and column: egamp, sys_shift is:0.021137519875233764
# row: 145 and error: 0.5 and column: effic, sys_shift is:0.041036824685630566
# row: 145 and error: 0.0 and column: enois, sys_shift is:0.041036824685630566
# df.at[i, column_to_modify] shifted: 0.5292971766623416
# df.at[i, column_to_modify] : 0.32789056423871527
# row: 146 and error: 0.25 and column: eelen, sys_shift is:0.0019922670693984655
# row: 146 and error: 0.01 and column: ethee, sys_shift is:0.0019926616505226095
# row: 146 and error: 0.58 and column: ehadr, sys_shift is:0.0020505561857736415
# row: 146 and error: 0.3 and column: radco, sys_shift is:0.00207199954401886
# row: 146 and error: 0.0 and column: egamp, sys_shift is:0.00207199954401886
# row: 146 and error: 0.5 and column: effic, sys_shift is:0.021971304354415664
# row: 146 and error: 0.0 and column: enois, sys_shift is:0.021971304354415664
# df.at[i, column_to_modify] shifted: 0.32219606007116314
# df.at[i, column_to_modify] : 0.16856149790520858
# row: 147 and error: 0.35 and column: eelen, sys_shift is:7.311732179091347e-05
# row: 147 and error: 0.01 and column: ethee, sys_shift is:7.351190291505736e-05
# row: 147 and error: 1.08 and column: ehadr, sys_shift is:0.04545396424528234
# row: 147 and error: 0.3 and column: radco, sys_shift is:0.045475407603527564
# row: 147 and error: 0.0 and column: egamp, sys_shift is:0.045475407603527564
# row: 147 and error: 0.5 and column: effic, sys_shift is:0.06537471241392437
# row: 147 and error: 0.0 and column: enois, sys_shift is:0.06537471241392437
# df.at[i, column_to_modify] shifted: 0.16993696055593183
# df.at[i, column_to_modify] : 0.07822646874868283
# row: 148 and error: 0.48 and column: eelen, sys_shift is:0.00371473137619397
# row: 148 and error: 0.01 and column: ethee, sys_shift is:0.0037151259573181138
# row: 148 and error: 1.78 and column: ehadr, sys_shift is:0.12642848843857254
# row: 148 and error: 0.3 and column: radco, sys_shift is:0.12644993179681777
# row: 148 and error: 0.0 and column: egamp, sys_shift is:0.12644993179681777
# row: 148 and error: 0.5 and column: effic, sys_shift is:0.14634923660721458
# row: 148 and error: 0.0 and column: enois, sys_shift is:0.14634923660721458
# df.at[i, column_to_modify] shifted: 0.07399733056138821
# df.at[i, column_to_modify] : 0.021687458825705327
# row: 149 and error: 0.69 and column: eelen, sys_shift is:0.0027360678560318825
# row: 149 and error: 0.02 and column: ethee, sys_shift is:0.002739530112962329
# row: 149 and error: 2.81 and column: ehadr, sys_shift is:0.024947157958089446
# row: 149 and error: 0.3 and column: radco, sys_shift is:0.024968601316334663
# row: 149 and error: 0.0 and column: egamp, sys_shift is:0.024968601316334663
# row: 149 and error: 0.5 and column: effic, sys_shift is:0.04486790612673147
# row: 149 and error: 0.0 and column: enois, sys_shift is:0.04486790612673147
# df.at[i, column_to_modify] shifted: 0.021186813365676394
# df.at[i, column_to_modify] : 0.004524080155361205
# row: 150 and error: 1.02 and column: eelen, sys_shift is:0.04447885476654605
# row: 150 and error: 0.03 and column: ethee, sys_shift is:0.04448181277355776
# row: 150 and error: 4.47 and column: ehadr, sys_shift is:0.289695037887963
# row: 150 and error: 0.3 and column: radco, sys_shift is:0.28971648124620825
# row: 150 and error: 0.0 and column: egamp, sys_shift is:0.28971648124620825
# row: 150 and error: 0.5 and column: effic, sys_shift is:0.30961578605660506
# row: 150 and error: 0.0 and column: enois, sys_shift is:0.30961578605660506
# df.at[i, column_to_modify] shifted: 0.0043315517897422025
# df.at[i, column_to_modify] : 0.0010476514577580536
# row: 151 and error: 1.76 and column: eelen, sys_shift is:0.00014789989025151845
# row: 151 and error: 0.05 and column: ethee, sys_shift is:0.00016546381833192688
# row: 151 and error: 8.13 and column: ehadr, sys_shift is:0.4157219593282659
# row: 151 and error: 0.3 and column: radco, sys_shift is:0.4157434026865111
# row: 151 and error: 0.0 and column: egamp, sys_shift is:0.4157434026865111
# row: 151 and error: 0.5 and column: effic, sys_shift is:0.4356427074969079
# row: 151 and error: 0.0 and column: enois, sys_shift is:0.4356427074969079
# df.at[i, column_to_modify] shifted: 0.0009683187968586216
# df.at[i, column_to_modify] : 0.23773111433122882
# row: 152 and error: 0.35 and column: eelen, sys_shift is:7.311732179091347e-05
# row: 152 and error: 0.0 and column: ethee, sys_shift is:7.311732179091347e-05
# row: 152 and error: 1.06 and column: ehadr, sys_shift is:7.497657838118291e-05
# row: 152 and error: 0.3 and column: radco, sys_shift is:9.64199366264016e-05
# row: 152 and error: 1.0 and column: egamp, sys_shift is:0.020348798239389943
# row: 152 and error: 0.5 and column: effic, sys_shift is:0.04024810304978675
# row: 152 and error: 0.0 and column: enois, sys_shift is:0.04024810304978675
# df.at[i, column_to_modify] shifted: 0.23799399094967366
# df.at[i, column_to_modify] : 0.07050866184402463
# row: 153 and error: 0.49 and column: eelen, sys_shift is:0.0001772396526735546
# row: 153 and error: 0.01 and column: ethee, sys_shift is:0.0001776342337976985
# row: 153 and error: 1.73 and column: ehadr, sys_shift is:0.01047836533565238
# row: 153 and error: 0.3 and column: radco, sys_shift is:0.0104998086938976
# row: 153 and error: 1.0 and column: egamp, sys_shift is:0.030752186996661143
# row: 153 and error: 0.5 and column: effic, sys_shift is:0.05065149180705795
# row: 153 and error: 0.0 and column: enois, sys_shift is:0.05065149180705795
# df.at[i, column_to_modify] shifted: 0.06990861394343008
# df.at[i, column_to_modify] : 0.018792986310266477
# row: 154 and error: 0.7 and column: eelen, sys_shift is:0.015623514829829006
# row: 154 and error: 0.01 and column: ethee, sys_shift is:0.01562390941095315
# row: 154 and error: 2.76 and column: ehadr, sys_shift is:0.016297152165636573
# row: 154 and error: 0.3 and column: radco, sys_shift is:0.01631859552388179
# row: 154 and error: 0.0 and column: egamp, sys_shift is:0.01631859552388179
# row: 154 and error: 0.5 and column: effic, sys_shift is:0.036217900334278595
# row: 154 and error: 0.0 and column: enois, sys_shift is:0.036217900334278595
# df.at[i, column_to_modify] shifted: 0.018351110601034355
# df.at[i, column_to_modify] : 0.01018114809790991
# row: 155 and error: 1.03 and column: eelen, sys_shift is:0.004287257086462718
# row: 155 and error: 0.02 and column: ethee, sys_shift is:0.004290719343393165
# row: 155 and error: 4.44 and column: ehadr, sys_shift is:0.0722238461586607
# row: 155 and error: 0.3 and column: radco, sys_shift is:0.07224528951690593
# row: 155 and error: 0.0 and column: egamp, sys_shift is:0.07224528951690593
# row: 155 and error: 0.5 and column: effic, sys_shift is:0.09214459432730274
# row: 155 and error: 0.0 and column: enois, sys_shift is:0.09214459432730274
# df.at[i, column_to_modify] shifted: 0.009718205231897325
# df.at[i, column_to_modify] : -0.0010437765616404084
# row: 156 and error: 1.78 and column: eelen, sys_shift is:0.12271336248125442
# row: 156 and error: 0.03 and column: ethee, sys_shift is:0.12271632048826613
# row: 156 and error: 8.14 and column: ehadr, sys_shift is:0.29601734751934977
# row: 156 and error: 0.3 and column: radco, sys_shift is:0.296038790877595
# row: 156 and error: 0.0 and column: egamp, sys_shift is:0.296038790877595
# row: 156 and error: 0.5 and column: effic, sys_shift is:0.3159380956879918
# row: 156 and error: 0.0 and column: enois, sys_shift is:0.3159380956879918
# df.at[i, column_to_modify] shifted: -0.00103499951243704
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D7_datanc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D7_datanc-thexp.dat
