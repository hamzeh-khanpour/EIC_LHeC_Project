# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC_Ee60/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for column in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , column))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std)

            sys_shift = 0.0
            for col in find_corr_err(df):
                print(f'row: {i} and error: {df.at[i, col]} and column: {col}, sysErrDict[df.at[i, col]] is:{sysErrDict[df.at[i, col]]}')
                sys_shift += sysErrDict[df.at[i, col]]**2
            
            sys_shift  = sys_shift**0.5
            sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift 
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 23 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 30 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 31 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 32 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 36 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 37 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 38 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 39 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 43 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 44 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 45 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 46 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 47 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 48 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 49 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# row: 50 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 52 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 53 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 54 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 55 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 56 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 57 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 58 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 59 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 60 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# row: 61 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:7.266542842345248
# row: 62 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 63 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 64 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 65 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 66 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 67 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 68 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 69 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 70 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 71 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# row: 72 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:7.266542842345248
# row: 73 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 74 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 75 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 76 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 77 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 78 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 79 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 80 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 81 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# row: 82 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:7.266542842345248
# row: 83 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 84 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 85 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 86 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 87 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 88 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 89 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 90 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# row: 91 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:7.266542842345248
# row: 92 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 93 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 94 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 95 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 96 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 97 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 98 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# row: 99 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 100 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:0.0788123180825387
# row: 101 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 102 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 103 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 104 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# row: 105 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.47430264695266
# row: 106 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:3.8160951539309846
# row: 107 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-11.154302556273322
# row: 108 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.035296030925938
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D6_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D6_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.8315233254715158
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.8315233254715158
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.5757594320566852
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.864422521785773
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.8315233254715158
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.5757594320566852
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.864422521785773
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.8315233254715158
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.5757594320566852
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.864422521785773
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.8315233254715158
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.5757594320566852
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.864422521785773
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.2246455258705033
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:2.8315233254715158
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.5757594320566852
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.864422521785773
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.864422521785773
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D1_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D1_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:6.307582247616494
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:6.307582247616494
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.382188660443316
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.6059098991599613
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:6.307582247616494
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.382188660443316
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.6059098991599613
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:6.307582247616494
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.382188660443316
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.6059098991599613
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:6.307582247616494
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.382188660443316
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.6059098991599613
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-1.5797963360497755
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:6.307582247616494
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-6.382188660443316
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.6059098991599613
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.6059098991599613
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D2_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D2_datacc-thexp.dat
# row: 0 and error: 0.05 and column: eelen, sysErrDict[df.at[i, col]] is:-0.13123414014513782
# row: 0 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.4498490563367793
# row: 0 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03185225773233255
# row: 0 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 0 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5860447407148909
# row: 0 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 0 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.06 and column: eelen, sysErrDict[df.at[i, col]] is:0.0351976345505804
# row: 1 and error: 0.5 and column: ethee, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 1 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03185225773233255
# row: 1 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 1 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 1 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.03185225773233255
# row: 2 and error: 0.6 and column: ethee, sysErrDict[df.at[i, col]] is:-0.10554976237736757
# row: 2 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 2 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 2 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 2 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 3 and error: 0.68 and column: ethee, sysErrDict[df.at[i, col]] is:0.26654010648255483
# row: 3 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 3 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 3 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 3 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 4 and error: 0.74 and column: ethee, sysErrDict[df.at[i, col]] is:0.14528258805264013
# row: 4 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 4 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 4 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 4 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 5 and error: 0.77 and column: ethee, sysErrDict[df.at[i, col]] is:0.7427644952219246
# row: 5 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 5 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 5 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 5 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 6 and error: 0.79 and column: ethee, sysErrDict[df.at[i, col]] is:0.5205155785253046
# row: 6 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 6 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 6 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 6 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.7626597413516796
# row: 7 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 7 and error: 0.8 and column: ethee, sysErrDict[df.at[i, col]] is:-1.2145145807361926
# row: 7 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 7 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 7 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 7 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 7 and error: 2.0 and column: enois, sysErrDict[df.at[i, col]] is:0.8700989864583532
# row: 8 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 8 and error: 0.78 and column: ethee, sysErrDict[df.at[i, col]] is:0.09126897709350412
# row: 8 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 8 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 8 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 8 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 8 and error: 2.17 and column: enois, sysErrDict[df.at[i, col]] is:1.8692578568068934
# row: 9 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 9 and error: 0.32 and column: ethee, sysErrDict[df.at[i, col]] is:0.24310739052276578
# row: 9 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0351976345505804
# row: 9 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 9 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5860447407148909
# row: 9 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 9 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 10 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:0.04247685008661137
# row: 10 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0351976345505804
# row: 10 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 10 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 10 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.03185225773233255
# row: 11 and error: 0.39 and column: ethee, sysErrDict[df.at[i, col]] is:0.19576217649982858
# row: 11 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 11 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 11 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 11 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.03185225773233255
# row: 12 and error: 0.4 and column: ethee, sysErrDict[df.at[i, col]] is:-0.2718863137749587
# row: 12 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 12 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 12 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 12 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.03185225773233255
# row: 13 and error: 0.41 and column: ethee, sysErrDict[df.at[i, col]] is:0.39660043231469966
# row: 13 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 13 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 13 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 13 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.03185225773233255
# row: 14 and error: 0.42 and column: ethee, sysErrDict[df.at[i, col]] is:0.7730573889781277
# row: 14 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 14 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 14 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 14 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 15 and error: 0.44 and column: ethee, sysErrDict[df.at[i, col]] is:-0.012342122476866248
# row: 15 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 15 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 15 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 15 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.7626597413516796
# row: 16 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 16 and error: 0.46 and column: ethee, sysErrDict[df.at[i, col]] is:-0.08037363938518126
# row: 16 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 16 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 16 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 16 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 16 and error: 1.88 and column: enois, sysErrDict[df.at[i, col]] is:1.948037063078319
# row: 17 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 17 and error: 0.47 and column: ethee, sysErrDict[df.at[i, col]] is:0.5936280372536125
# row: 17 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 17 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 17 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 17 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 17 and error: 2.15 and column: enois, sysErrDict[df.at[i, col]] is:-2.2317202353780488
# row: 18 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 18 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:0.10788995928672256
# row: 18 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:0.01155483815932236
# row: 18 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 18 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5860447407148909
# row: 18 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 18 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 19 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.4498490563367793
# row: 19 and error: 0.03 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.03714568117256724
# row: 19 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 19 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 19 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 20 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.10622194499592903
# row: 20 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 20 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 20 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 20 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 21 and error: 0.3 and column: ethee, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 21 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 21 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 21 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 21 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:-0.01618599316428424
# row: 22 and error: 0.31 and column: ethee, sysErrDict[df.at[i, col]] is:-0.28190102442226905
# row: 22 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 22 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 22 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 22 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 23 and error: 0.33 and column: ethee, sysErrDict[df.at[i, col]] is:0.43201475043906773
# row: 23 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.16011024567907997
# row: 23 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 23 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 23 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 24 and error: 0.34 and column: ethee, sysErrDict[df.at[i, col]] is:0.028365832598170146
# row: 24 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.16011024567907997
# row: 24 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 24 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 24 and error: 1.66 and column: enois, sysErrDict[df.at[i, col]] is:0.6100158596465406
# row: 25 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 25 and error: 0.36 and column: ethee, sysErrDict[df.at[i, col]] is:0.19255853168508977
# row: 25 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.16011024567907997
# row: 25 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 25 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 25 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 25 and error: 1.93 and column: enois, sysErrDict[df.at[i, col]] is:-1.9743690793737145
# row: 26 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 26 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:0.04247685008661137
# row: 26 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 26 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 26 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 26 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 26 and error: 2.22 and column: enois, sysErrDict[df.at[i, col]] is:-3.414878769626859
# row: 27 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 27 and error: 0.16 and column: ethee, sysErrDict[df.at[i, col]] is:-0.301803479779771
# row: 27 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.009167502142227536
# row: 27 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 27 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5860447407148909
# row: 27 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 27 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 28 and error: 0.22 and column: ethee, sysErrDict[df.at[i, col]] is:-0.32760467552210576
# row: 28 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:0.01155483815932236
# row: 28 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 28 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 28 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 29 and error: 0.23 and column: ethee, sysErrDict[df.at[i, col]] is:0.07725918816648178
# row: 29 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 29 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 29 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 29 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 30 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 30 and error: 0.24 and column: ethee, sysErrDict[df.at[i, col]] is:-0.13484274060012313
# row: 30 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 30 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 30 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 30 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 30 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 31 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 31 and error: 0.26 and column: ethee, sysErrDict[df.at[i, col]] is:0.3058945163107447
# row: 31 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.02742933291004205
# row: 31 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 31 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 31 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 31 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 32 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 32 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:-0.4498490563367793
# row: 32 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.02742933291004205
# row: 32 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 32 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 32 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 32 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 33 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 33 and error: 0.28 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1627293685614495
# row: 33 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.02742933291004205
# row: 33 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 33 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 33 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 33 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.7626597413516796
# row: 34 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 34 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.10622194499592903
# row: 34 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.02742933291004205
# row: 34 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 34 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 34 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 34 and error: 2.0 and column: enois, sysErrDict[df.at[i, col]] is:0.8700989864583532
# row: 35 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 35 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.10622194499592903
# row: 35 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.16011024567907997
# row: 35 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 35 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 35 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 35 and error: 2.17 and column: enois, sysErrDict[df.at[i, col]] is:1.8692578568068934
# row: 36 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 36 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:-0.16011024567907997
# row: 36 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.009167502142227536
# row: 36 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 36 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.5860447407148909
# row: 36 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 36 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 37 and error: 0.15 and column: ethee, sysErrDict[df.at[i, col]] is:0.05848392757622881
# row: 37 and error: 0.02 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.02288897529653569
# row: 37 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 37 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 37 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 38 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 38 and error: 0.17 and column: ethee, sysErrDict[df.at[i, col]] is:0.16800757731021163
# row: 38 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.005815362469060002
# row: 38 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 38 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 38 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 38 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 39 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 39 and error: 0.18 and column: ethee, sysErrDict[df.at[i, col]] is:-0.02168691638515366
# row: 39 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.02742933291004205
# row: 39 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 39 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 39 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 39 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 40 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.05996328343433613
# row: 40 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:0.10788995928672256
# row: 40 and error: 0.14 and column: ehadr, sysErrDict[df.at[i, col]] is:0.18115740909363395
# row: 40 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 40 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 40 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 40 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 41 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 41 and error: 0.2 and column: ethee, sysErrDict[df.at[i, col]] is:-0.13363473698219383
# row: 41 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05848392757622881
# row: 41 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 41 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 41 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 41 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 42 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 42 and error: 0.2 and column: ethee, sysErrDict[df.at[i, col]] is:-0.13363473698219383
# row: 42 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05848392757622881
# row: 42 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 42 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 42 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 42 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.7626597413516796
# row: 43 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.08147788673506137
# row: 43 and error: 0.21 and column: ethee, sysErrDict[df.at[i, col]] is:-0.33526439801631697
# row: 43 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05848392757622881
# row: 43 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 43 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 43 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# row: 43 and error: 1.88 and column: enois, sysErrDict[df.at[i, col]] is:1.948037063078319
# row: 44 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:-0.16011024567907997
# row: 44 and error: 0.21 and column: ethee, sysErrDict[df.at[i, col]] is:-0.33526439801631697
# row: 44 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.02742933291004205
# row: 44 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.19580133666398783
# row: 44 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 44 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.2607563540643994
# ...
# row: 131 and error: 0.66 and column: ehadr, sysErrDict[df.at[i, col]] is:6.978620778370048e-05
# row: 131 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 131 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 131 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 131 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 132 and error: 0.34 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19729504844739265
# row: 132 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.019411181992269804
# row: 132 and error: 1.14 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.9719498465929814
# row: 132 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 132 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 132 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 132 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 133 and error: 0.47 and column: eelen, sysErrDict[df.at[i, col]] is:-0.12104603528460414
# row: 133 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.02551146145880529
# row: 133 and error: 1.8 and column: ehadr, sysErrDict[df.at[i, col]] is:-3.091478852507529
# row: 133 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 133 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 133 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 133 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 134 and error: 0.67 and column: eelen, sysErrDict[df.at[i, col]] is:0.22302409809363105
# row: 134 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:-0.030787388297260094
# row: 134 and error: 2.8 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.7158977124746537
# row: 134 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 134 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 134 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 134 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 135 and error: 1.0 and column: eelen, sysErrDict[df.at[i, col]] is:2.5774421778176086
# row: 135 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:0.007453235333295127
# row: 135 and error: 4.43 and column: ehadr, sysErrDict[df.at[i, col]] is:2.46629234543541
# row: 135 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 135 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 135 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 135 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 136 and error: 1.73 and column: eelen, sysErrDict[df.at[i, col]] is:-0.9042775315830877
# row: 136 and error: 0.1 and column: ethee, sysErrDict[df.at[i, col]] is:0.22524023501719564
# row: 136 and error: 8.02 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.9414989900342797
# row: 136 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 136 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 136 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 136 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 137 and error: 0.15 and column: eelen, sysErrDict[df.at[i, col]] is:-0.009237943719136756
# row: 137 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 137 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.07852558297391005
# row: 137 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 137 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:2.5774421778176086
# row: 137 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 137 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 138 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.27850819948326183
# row: 138 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 138 and error: 0.28 and column: ehadr, sysErrDict[df.at[i, col]] is:0.10916866890447506
# row: 138 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 138 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 138 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 138 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 139 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.28137622029835285
# row: 139 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 139 and error: 0.64 and column: ehadr, sysErrDict[df.at[i, col]] is:0.4167568159818106
# row: 139 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 139 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 139 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 139 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 140 and error: 0.34 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19729504844739265
# row: 140 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 140 and error: 1.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.3704365663551484
# row: 140 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 140 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 140 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 140 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 141 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.3162888025088444
# row: 141 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.019411181992269804
# row: 141 and error: 1.81 and column: ehadr, sysErrDict[df.at[i, col]] is:-2.021104099462934
# row: 141 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 141 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 141 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 141 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 142 and error: 0.68 and column: eelen, sysErrDict[df.at[i, col]] is:0.02707162099720964
# row: 142 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.02551146145880529
# row: 142 and error: 2.82 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.9321349737108855
# row: 142 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 142 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 142 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 142 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 143 and error: 1.01 and column: eelen, sysErrDict[df.at[i, col]] is:-0.7503116998775126
# row: 143 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:-0.030787388297260094
# row: 143 and error: 4.46 and column: ehadr, sysErrDict[df.at[i, col]] is:7.011570875539674
# row: 143 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 143 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 143 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 143 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 144 and error: 1.74 and column: eelen, sysErrDict[df.at[i, col]] is:3.125324779382997
# row: 144 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:0.04106311366209648
# row: 144 and error: 8.09 and column: ehadr, sysErrDict[df.at[i, col]] is:-4.894233919773069
# row: 144 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 144 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 144 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 144 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 145 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.27850819948326183
# row: 145 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 145 and error: 0.24 and column: ehadr, sysErrDict[df.at[i, col]] is:0.10135660188839053
# row: 145 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 145 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:2.5774421778176086
# row: 145 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 145 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 146 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.28137622029835285
# row: 146 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 146 and error: 0.58 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.01289655987849857
# row: 146 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 146 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 146 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 146 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 147 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:0.24036940278742222
# row: 147 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 147 and error: 1.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.49764150512896604
# row: 147 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 147 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 147 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 147 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 148 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.3162888025088444
# row: 148 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 148 and error: 1.78 and column: ehadr, sysErrDict[df.at[i, col]] is:1.2526529425289932
# row: 148 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 148 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 148 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 148 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 149 and error: 0.69 and column: eelen, sysErrDict[df.at[i, col]] is:-0.549631238370846
# row: 149 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.019411181992269804
# row: 149 and error: 2.81 and column: ehadr, sysErrDict[df.at[i, col]] is:-1.6093625531553983
# row: 149 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 149 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 149 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 149 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 150 and error: 1.02 and column: eelen, sysErrDict[df.at[i, col]] is:0.235776082212078
# row: 150 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.02551146145880529
# row: 150 and error: 4.47 and column: ehadr, sysErrDict[df.at[i, col]] is:-6.0547720912962655
# row: 150 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 150 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 150 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 150 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 151 and error: 1.76 and column: eelen, sysErrDict[df.at[i, col]] is:1.6245972725361446
# row: 151 and error: 0.05 and column: ethee, sysErrDict[df.at[i, col]] is:0.01018367921290238
# row: 151 and error: 8.13 and column: ehadr, sysErrDict[df.at[i, col]] is:1.0379852312214881
# row: 151 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 151 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 151 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 151 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 152 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:0.24036940278742222
# row: 152 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 152 and error: 1.06 and column: ehadr, sysErrDict[df.at[i, col]] is:0.19094241560193134
# row: 152 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 152 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:2.5774421778176086
# row: 152 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 152 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 153 and error: 0.49 and column: eelen, sysErrDict[df.at[i, col]] is:1.0119542923876794
# row: 153 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 153 and error: 1.73 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.9042775315830877
# row: 153 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 153 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:2.5774421778176086
# row: 153 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 153 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 154 and error: 0.7 and column: eelen, sysErrDict[df.at[i, col]] is:-0.43715257854472395
# row: 154 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:0.006065052903430626
# row: 154 and error: 2.76 and column: ehadr, sysErrDict[df.at[i, col]] is:-2.9892569770666095
# row: 154 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 154 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 154 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 154 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 155 and error: 1.03 and column: eelen, sysErrDict[df.at[i, col]] is:-0.06037247142742213
# row: 155 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:0.019411181992269804
# row: 155 and error: 4.44 and column: ehadr, sysErrDict[df.at[i, col]] is:-5.008050072549282
# row: 155 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 155 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 155 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 155 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 156 and error: 1.78 and column: eelen, sysErrDict[df.at[i, col]] is:1.2526529425289932
# row: 156 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:0.02551146145880529
# row: 156 and error: 8.14 and column: ehadr, sysErrDict[df.at[i, col]] is:-2.3526595670088803
# row: 156 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.4631976226126324
# row: 156 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 156 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.48836245876984963
# row: 156 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D7_datanc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D7_datanc-thexp.dat
