# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC_Ee60/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for column in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , column))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std)

            sys_shift = 0.0
            for col in find_corr_err(df):
                print(f'row: {i} and error: {df.at[i, col]} and column: {col}, sysErrDict[df.at[i, col]] is:{sysErrDict[df.at[i, col]]}')
                sys_shift += sysErrDict[df.at[i, col]]**2
            
            sys_shift  = sys_shift**0.5
            sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift * 000.0
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 23 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 30 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 31 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 32 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 36 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 37 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 38 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 39 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 43 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 44 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 45 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 46 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 47 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 48 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 49 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# row: 50 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 52 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 53 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 54 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 55 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 56 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 57 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 58 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 59 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 60 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# row: 61 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.335207117484577
# row: 62 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 63 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 64 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 65 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 66 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 67 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 68 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 69 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 70 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 71 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# row: 72 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.335207117484577
# row: 73 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 74 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 75 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 76 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 77 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 78 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 79 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 80 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 81 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# row: 82 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.335207117484577
# row: 83 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 84 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 85 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 86 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 87 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 88 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 89 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 90 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# row: 91 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-14.335207117484577
# row: 92 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 93 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 94 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 95 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 96 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 97 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 98 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# row: 99 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 100 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-2.8500431562316093
# row: 101 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 102 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 103 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 104 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# row: 105 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-4.649170143141727
# row: 106 and error: 4.67 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.673392343839394
# row: 107 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:16.564362277753535
# row: 108 and error: 7.33 and column: ccsys, sysErrDict[df.at[i, col]] is:4.965737239681173
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D6_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D6_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.9599795852174198
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.9599795852174198
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-8.922340726291146
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:4.443498958046598
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.9599795852174198
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-8.922340726291146
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:4.443498958046598
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.9599795852174198
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-8.922340726291146
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:4.443498958046598
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.9599795852174198
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-8.922340726291146
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:4.443498958046598
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:3.9588266144953757
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:1.9599795852174198
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-8.922340726291146
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:4.443498958046598
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:4.443498958046598
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D1_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D1_datacc-thexp.dat
# row: 0 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 1 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 2 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 3 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 4 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 5 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 6 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 7 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 8 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 9 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 10 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 11 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 12 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 13 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 14 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 15 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 16 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 17 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 18 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 19 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 20 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 21 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 22 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 23 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.5062223260706419
# row: 24 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 25 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 26 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 27 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 28 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 29 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 30 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.5062223260706419
# row: 31 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-7.293407476437521
# row: 32 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.246154508927456
# row: 33 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 34 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 35 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 36 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 37 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.5062223260706419
# row: 38 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-7.293407476437521
# row: 39 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.246154508927456
# row: 40 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 41 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 42 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 43 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.5062223260706419
# row: 44 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-7.293407476437521
# row: 45 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.246154508927456
# row: 46 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 47 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 48 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.5062223260706419
# row: 49 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-7.293407476437521
# row: 50 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.246154508927456
# row: 51 and error: 2.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-5.0284698217746575
# row: 52 and error: 3.33 and column: ccsys, sysErrDict[df.at[i, col]] is:-0.5062223260706419
# row: 53 and error: 6.0 and column: ccsys, sysErrDict[df.at[i, col]] is:-7.293407476437521
# row: 54 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.246154508927456
# row: 55 and error: 8.67 and column: ccsys, sysErrDict[df.at[i, col]] is:2.246154508927456
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D2_datacc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D2_datacc-thexp.dat
# row: 0 and error: 0.05 and column: eelen, sysErrDict[df.at[i, col]] is:0.006589843918983586
# row: 0 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:0.03875516870918897
# row: 0 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04939803402664745
# row: 0 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 0 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.168751013805723
# row: 0 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 0 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.06 and column: eelen, sysErrDict[df.at[i, col]] is:-0.04441011504413038
# row: 1 and error: 0.5 and column: ethee, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 1 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04939803402664745
# row: 1 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 1 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 1 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.04939803402664745
# row: 2 and error: 0.6 and column: ethee, sysErrDict[df.at[i, col]] is:1.7842936466579007
# row: 2 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 2 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 2 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 2 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 3 and error: 0.68 and column: ethee, sysErrDict[df.at[i, col]] is:-0.30203441831915223
# row: 3 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 3 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 3 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 3 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 4 and error: 0.74 and column: ethee, sysErrDict[df.at[i, col]] is:0.08532208628966939
# row: 4 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 4 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 4 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 4 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 5 and error: 0.77 and column: ethee, sysErrDict[df.at[i, col]] is:-0.8977229401924335
# row: 5 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 5 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 5 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 5 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 6 and error: 0.79 and column: ethee, sysErrDict[df.at[i, col]] is:0.2780254389611069
# row: 6 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 6 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 6 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 6 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.1301610135400841
# row: 7 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 7 and error: 0.8 and column: ethee, sysErrDict[df.at[i, col]] is:-0.11681546642025815
# row: 7 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 7 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 7 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 7 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 7 and error: 2.0 and column: enois, sysErrDict[df.at[i, col]] is:-4.741441595122368
# row: 8 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 8 and error: 0.78 and column: ethee, sysErrDict[df.at[i, col]] is:1.129175670020265
# row: 8 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 8 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 8 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 8 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 8 and error: 2.17 and column: enois, sysErrDict[df.at[i, col]] is:-0.5462034277627816
# row: 9 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 9 and error: 0.32 and column: ethee, sysErrDict[df.at[i, col]] is:-0.17261293258173652
# row: 9 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04441011504413038
# row: 9 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 9 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.168751013805723
# row: 9 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 9 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 10 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:0.046328720892091585
# row: 10 and error: 0.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04441011504413038
# row: 10 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 10 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 10 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.04939803402664745
# row: 11 and error: 0.39 and column: ethee, sysErrDict[df.at[i, col]] is:0.15447925251407377
# row: 11 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 11 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 11 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 11 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.04939803402664745
# row: 12 and error: 0.4 and column: ethee, sysErrDict[df.at[i, col]] is:-0.24723405144673102
# row: 12 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 12 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 12 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 12 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.04939803402664745
# row: 13 and error: 0.41 and column: ethee, sysErrDict[df.at[i, col]] is:0.6337093667708649
# row: 13 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 13 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 13 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 13 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:0.04939803402664745
# row: 14 and error: 0.42 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1082983855925483
# row: 14 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 14 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 14 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 14 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 15 and error: 0.44 and column: ethee, sysErrDict[df.at[i, col]] is:-0.05033739976729401
# row: 15 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 15 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 15 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 15 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.1301610135400841
# row: 16 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 16 and error: 0.46 and column: ethee, sysErrDict[df.at[i, col]] is:0.07538806378470239
# row: 16 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 16 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 16 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 16 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 16 and error: 1.88 and column: enois, sysErrDict[df.at[i, col]] is:-0.9362204817140302
# row: 17 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 17 and error: 0.47 and column: ethee, sysErrDict[df.at[i, col]] is:0.1740605903822374
# row: 17 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 17 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 17 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 17 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 17 and error: 2.15 and column: enois, sysErrDict[df.at[i, col]] is:0.49442261790740505
# row: 18 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 18 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:0.20944875279310948
# row: 18 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04549005814871809
# row: 18 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 18 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.168751013805723
# row: 18 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 18 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 19 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:0.03875516870918897
# row: 19 and error: 0.03 and column: ehadr, sysErrDict[df.at[i, col]] is:0.048985828590031893
# row: 19 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 19 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 19 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 20 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.6741479529745575
# row: 20 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 20 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 20 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 20 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 21 and error: 0.3 and column: ethee, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 21 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 21 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 21 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 21 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.11266214528651194
# row: 22 and error: 0.31 and column: ethee, sysErrDict[df.at[i, col]] is:-0.17003289214383835
# row: 22 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 22 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 22 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 22 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 23 and error: 0.33 and column: ethee, sysErrDict[df.at[i, col]] is:-0.22295931138822767
# row: 23 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.02562687093245324
# row: 23 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 23 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 23 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 24 and error: 0.34 and column: ethee, sysErrDict[df.at[i, col]] is:-0.4779368170745399
# row: 24 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.02562687093245324
# row: 24 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 24 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 24 and error: 1.66 and column: enois, sysErrDict[df.at[i, col]] is:-0.4986616345285154
# row: 25 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 25 and error: 0.36 and column: ethee, sysErrDict[df.at[i, col]] is:-0.20775357870058128
# row: 25 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.02562687093245324
# row: 25 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 25 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 25 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 25 and error: 1.93 and column: enois, sysErrDict[df.at[i, col]] is:0.4691503120246547
# row: 26 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 26 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:0.046328720892091585
# row: 26 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 26 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 26 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 26 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 26 and error: 2.22 and column: enois, sysErrDict[df.at[i, col]] is:-3.607442285549975
# row: 27 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 27 and error: 0.16 and column: ethee, sysErrDict[df.at[i, col]] is:0.027598170847252725
# row: 27 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.010605750507982004
# row: 27 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 27 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.168751013805723
# row: 27 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 27 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 28 and error: 0.22 and column: ethee, sysErrDict[df.at[i, col]] is:0.27333928879474595
# row: 28 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04549005814871809
# row: 28 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 28 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 28 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 29 and error: 0.23 and column: ethee, sysErrDict[df.at[i, col]] is:0.2626750473209705
# row: 29 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 29 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 29 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 29 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 30 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 30 and error: 0.24 and column: ethee, sysErrDict[df.at[i, col]] is:0.11334482943013813
# row: 30 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 30 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 30 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 30 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 30 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 31 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 31 and error: 0.26 and column: ethee, sysErrDict[df.at[i, col]] is:-0.3478849900123254
# row: 31 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1216486082779577
# row: 31 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 31 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 31 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 31 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 32 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 32 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:0.03875516870918897
# row: 32 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1216486082779577
# row: 32 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 32 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 32 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 32 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 33 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 33 and error: 0.28 and column: ethee, sysErrDict[df.at[i, col]] is:-0.24970335116920986
# row: 33 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1216486082779577
# row: 33 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 33 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 33 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 33 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.1301610135400841
# row: 34 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 34 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.6741479529745575
# row: 34 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1216486082779577
# row: 34 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 34 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 34 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 34 and error: 2.0 and column: enois, sysErrDict[df.at[i, col]] is:-4.741441595122368
# row: 35 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 35 and error: 0.29 and column: ethee, sysErrDict[df.at[i, col]] is:0.6741479529745575
# row: 35 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.02562687093245324
# row: 35 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 35 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 35 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 35 and error: 2.17 and column: enois, sysErrDict[df.at[i, col]] is:-0.5462034277627816
# row: 36 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 36 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:-0.02562687093245324
# row: 36 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.010605750507982004
# row: 36 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 36 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-0.168751013805723
# row: 36 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 36 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 37 and error: 0.15 and column: ethee, sysErrDict[df.at[i, col]] is:-0.18682650525157304
# row: 37 and error: 0.02 and column: ehadr, sysErrDict[df.at[i, col]] is:0.016164795683787002
# row: 37 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 37 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 37 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 38 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 38 and error: 0.17 and column: ethee, sysErrDict[df.at[i, col]] is:0.023918222537449876
# row: 38 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.03640000085560962
# row: 38 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 38 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 38 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 38 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 39 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 39 and error: 0.18 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1347922477162248
# row: 39 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1216486082779577
# row: 39 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 39 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 39 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 39 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 40 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:-0.1296216642502523
# row: 40 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:0.20944875279310948
# row: 40 and error: 0.14 and column: ehadr, sysErrDict[df.at[i, col]] is:0.11895826206633331
# row: 40 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 40 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 40 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 40 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 41 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 41 and error: 0.2 and column: ethee, sysErrDict[df.at[i, col]] is:-0.2903676265758889
# row: 41 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.18682650525157304
# row: 41 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 41 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 41 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 41 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 42 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 42 and error: 0.2 and column: ethee, sysErrDict[df.at[i, col]] is:-0.2903676265758889
# row: 42 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.18682650525157304
# row: 42 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 42 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 42 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 42 and error: 1.71 and column: enois, sysErrDict[df.at[i, col]] is:-1.1301610135400841
# row: 43 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:0.17994979166447184
# row: 43 and error: 0.21 and column: ethee, sysErrDict[df.at[i, col]] is:0.04309440020022289
# row: 43 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.18682650525157304
# row: 43 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 43 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 43 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# row: 43 and error: 1.88 and column: enois, sysErrDict[df.at[i, col]] is:-0.9362204817140302
# row: 44 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:-0.02562687093245324
# row: 44 and error: 0.21 and column: ethee, sysErrDict[df.at[i, col]] is:0.04309440020022289
# row: 44 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.1216486082779577
# row: 44 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:0.06947314381170505
# row: 44 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 44 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3911426155507393
# ...
# row: 131 and error: 0.66 and column: ehadr, sysErrDict[df.at[i, col]] is:0.5934078327380699
# row: 131 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 131 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 131 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 131 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 132 and error: 0.34 and column: eelen, sysErrDict[df.at[i, col]] is:0.4028125421469899
# row: 132 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.028089912679284495
# row: 132 and error: 1.14 and column: ehadr, sysErrDict[df.at[i, col]] is:0.02126509812403054
# row: 132 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 132 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 132 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 132 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 133 and error: 0.47 and column: eelen, sysErrDict[df.at[i, col]] is:-0.3461805033877517
# row: 133 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:-0.023869445885376553
# row: 133 and error: 1.8 and column: ehadr, sysErrDict[df.at[i, col]] is:-1.3044530191153525
# row: 133 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 133 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 133 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 133 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 134 and error: 0.67 and column: eelen, sysErrDict[df.at[i, col]] is:0.7282655612857605
# row: 134 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:0.014384371331998791
# row: 134 and error: 2.8 and column: ehadr, sysErrDict[df.at[i, col]] is:2.2913676396496463
# row: 134 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 134 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 134 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 134 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 135 and error: 1.0 and column: eelen, sysErrDict[df.at[i, col]] is:-1.2070243842807848
# row: 135 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:-0.032782991594094944
# row: 135 and error: 4.43 and column: ehadr, sysErrDict[df.at[i, col]] is:-10.085673023524665
# row: 135 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 135 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 135 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 135 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 136 and error: 1.73 and column: eelen, sysErrDict[df.at[i, col]] is:3.5064252924167394
# row: 136 and error: 0.1 and column: ethee, sysErrDict[df.at[i, col]] is:0.0037037752140946945
# row: 136 and error: 8.02 and column: ehadr, sysErrDict[df.at[i, col]] is:9.359910318435313
# row: 136 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 136 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 136 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 136 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 137 and error: 0.15 and column: eelen, sysErrDict[df.at[i, col]] is:0.20172613355540286
# row: 137 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 137 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.013870841580905374
# row: 137 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 137 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-1.2070243842807848
# row: 137 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 137 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 138 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.13003621311507235
# row: 138 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 138 and error: 0.28 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.0858437688093372
# row: 138 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 138 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 138 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 138 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 139 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.2416923115081046
# row: 139 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 139 and error: 0.64 and column: ehadr, sysErrDict[df.at[i, col]] is:0.4186817367676761
# row: 139 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 139 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 139 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 139 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 140 and error: 0.34 and column: eelen, sysErrDict[df.at[i, col]] is:0.4028125421469899
# row: 140 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 140 and error: 1.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-1.430397636504338
# row: 140 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 140 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 140 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 140 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 141 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.48132702685958284
# row: 141 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.028089912679284495
# row: 141 and error: 1.81 and column: ehadr, sysErrDict[df.at[i, col]] is:1.7940157583856258
# row: 141 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 141 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 141 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 141 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 142 and error: 0.68 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19795623052112796
# row: 142 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:-0.023869445885376553
# row: 142 and error: 2.82 and column: ehadr, sysErrDict[df.at[i, col]] is:0.15163830401709685
# row: 142 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 142 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 142 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 142 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 143 and error: 1.01 and column: eelen, sysErrDict[df.at[i, col]] is:-1.0774216834000567
# row: 143 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:0.014384371331998791
# row: 143 and error: 4.46 and column: ehadr, sysErrDict[df.at[i, col]] is:-4.655996288297778
# row: 143 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 143 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 143 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 143 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 144 and error: 1.74 and column: eelen, sysErrDict[df.at[i, col]] is:0.6280001148930874
# row: 144 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:-0.08432517554813823
# row: 144 and error: 8.09 and column: ehadr, sysErrDict[df.at[i, col]] is:2.872692594099844
# row: 144 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 144 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 144 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 144 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 145 and error: 0.19 and column: eelen, sysErrDict[df.at[i, col]] is:0.13003621311507235
# row: 145 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 145 and error: 0.24 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06989975789784768
# row: 145 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 145 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-1.2070243842807848
# row: 145 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 145 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 146 and error: 0.25 and column: eelen, sysErrDict[df.at[i, col]] is:0.2416923115081046
# row: 146 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 146 and error: 0.58 and column: ehadr, sysErrDict[df.at[i, col]] is:0.9179952023515237
# row: 146 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 146 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 146 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 146 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 147 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:0.27441873131983585
# row: 147 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 147 and error: 1.08 and column: ehadr, sysErrDict[df.at[i, col]] is:1.2997220723281009
# row: 147 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 147 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 147 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 147 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 148 and error: 0.48 and column: eelen, sysErrDict[df.at[i, col]] is:0.48132702685958284
# row: 148 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 148 and error: 1.78 and column: ehadr, sysErrDict[df.at[i, col]] is:0.24601919443157852
# row: 148 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 148 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 148 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 148 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 149 and error: 0.69 and column: eelen, sysErrDict[df.at[i, col]] is:-0.005694900483444543
# row: 149 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.028089912679284495
# row: 149 and error: 2.81 and column: ehadr, sysErrDict[df.at[i, col]] is:-1.240350988126155
# row: 149 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 149 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 149 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 149 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 150 and error: 1.02 and column: eelen, sysErrDict[df.at[i, col]] is:0.1696112103322773
# row: 150 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:-0.023869445885376553
# row: 150 and error: 4.47 and column: ehadr, sysErrDict[df.at[i, col]] is:0.364888586891897
# row: 150 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 150 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 150 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 150 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 151 and error: 1.76 and column: eelen, sysErrDict[df.at[i, col]] is:1.3485222348291361
# row: 151 and error: 0.05 and column: ethee, sysErrDict[df.at[i, col]] is:0.009781577040845172
# row: 151 and error: 8.13 and column: ehadr, sysErrDict[df.at[i, col]] is:-13.344401884891512
# row: 151 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 151 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 151 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 151 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 152 and error: 0.35 and column: eelen, sysErrDict[df.at[i, col]] is:0.27441873131983585
# row: 152 and error: 0.0 and column: ethee, sysErrDict[df.at[i, col]] is:0.0
# row: 152 and error: 1.06 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.31067495127997563
# row: 152 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 152 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-1.2070243842807848
# row: 152 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 152 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 153 and error: 0.49 and column: eelen, sysErrDict[df.at[i, col]] is:0.6551287361669524
# row: 153 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 153 and error: 1.73 and column: ehadr, sysErrDict[df.at[i, col]] is:3.5064252924167394
# row: 153 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 153 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:-1.2070243842807848
# row: 153 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 153 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 154 and error: 0.7 and column: eelen, sysErrDict[df.at[i, col]] is:0.11249843802604476
# row: 154 and error: 0.01 and column: ethee, sysErrDict[df.at[i, col]] is:-0.018976149319791767
# row: 154 and error: 2.76 and column: ehadr, sysErrDict[df.at[i, col]] is:1.6695468002387839
# row: 154 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 154 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 154 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 154 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 155 and error: 1.03 and column: eelen, sysErrDict[df.at[i, col]] is:0.5955611629231442
# row: 155 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.028089912679284495
# row: 155 and error: 4.44 and column: ehadr, sysErrDict[df.at[i, col]] is:-11.62170795878179
# row: 155 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 155 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 155 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 155 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# row: 156 and error: 1.78 and column: eelen, sysErrDict[df.at[i, col]] is:0.24601919443157852
# row: 156 and error: 0.03 and column: ethee, sysErrDict[df.at[i, col]] is:-0.023869445885376553
# row: 156 and error: 8.14 and column: ehadr, sysErrDict[df.at[i, col]] is:8.13466634525831
# row: 156 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.06309683608121586
# row: 156 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 156 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:0.30784320003570115
# row: 156 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# DataFrame has been written to ./LHeC_Ee60/smeared/lhec_D7_datanc-thexp_smeared.dat with preamble from ./LHeC_Ee60/lhec_D7_datanc-thexp.dat
