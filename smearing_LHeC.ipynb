# %%
import os
import glob
import numpy as np
import pandas as pd
import re


# Specify the directory containing the .dat files
directory_path = './LHeC/'

# Construct the full pattern for .dat files
file_pattern = os.path.join(directory_path, '*.dat')

# Use glob to get a list of all .dat files in the directory
dat_files = glob.glob(file_pattern)

# %%
##################################################################################################################
# Function to check if a line starts with a digit
def starts_with_digit(line):
    return line.strip() and (line.strip()[0].isdigit() or line.strip()[0] == '-' or line.strip()[0] == '.')

##################################################################################################################
# Function to read the file, skip lines starting with any string, and return a DataFrame

def expand_column_names(column_names_raw):
    column_names = []
    parts = column_names_raw.split(',')
    for part in parts:
        part = part.strip().replace("'", "")
        match = re.match(r"(\d+)\*(.+)", part)
        if match:
            count = int(match.group(1))
            string = match.group(2)
            column_names.extend([string] * count)
        else:
            column_names.append(part)
    return column_names
##################################################################################################################

def read_dat_file(file_path):
    from io import StringIO
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Find the line with column names
    column_names = None
    data_lines = []
    for line in lines:
        if line.startswith("  ColumnName = "):
            column_names_raw = line[len("  ColumnName = "):].strip()
            # Expand column names to handle patterns like 3*'string'
            column_names = expand_column_names(column_names_raw)
        elif starts_with_digit(line):
            data_lines.append(line)
    
    # Convert the filtered lines to a DataFrame
    filtered_content = '\n'.join(data_lines)
    data = pd.read_csv(StringIO(filtered_content), delim_whitespace=True, header=None)
    
    # Assign column names if found
    if column_names and len(column_names) == data.shape[1]:
        data.columns = column_names
    
    return data

##################################################################################################################
# function to generate Gaussian random number
def generate_random_number(mean, std_dev):
    return np.random.normal(mean, std_dev)

##################################################################################################################
# function to Get unique values in the 'column' column and produce corrsponding shifts
def generate_corr_err_shift(df , column):
    sysErrDict = {key: value for key, value in []}
    unique_values = df[column].unique()
    for elem in unique_values:
        sysErrDict[elem] = generate_random_number(0,elem)
    return sysErrDict

##################################################################################################################
#  function Find column names that start with 'esyst'
def find_corr_err(df):
    norm_columns = [col for col in df.columns if (col.startswith('e') or col.startswith('radco') or col.startswith('ccsys'))]
    return norm_columns
##################################################################################################################
# Function to write the filefrom a DataFrame
def write_dataframe_with_preamble(df, preamble_file, output_file):
    """
    Write lines from a preamble file and a Pandas DataFrame to a TSV file.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to write to file.
    preamble_file (str): The name of the file to read the preamble lines from.
    output_file (str): The name of the output file to write to.
    """
    # Read lines from the preamble file
    preamble_lines = []
    with open(preamble_file, 'r') as file:
        lines = file.readlines()
    
    # Find the line which start with a string : preamble
    for line in lines:
        if starts_with_digit(line):
            continue
        else:
            preamble_lines.append(line)
    ###########################################################################
    # Open the output file in write mode
    with open(output_file, 'w') as file:
        # Write the preamble lines to the output file
        file.writelines(preamble_lines)
    
    # Write the DataFrame to the output file in TSV format, appending mode, w/o header
    df.to_csv(output_file, sep='\t', index=False, mode='a', header=False)

    print(f"DataFrame has been written to {output_file} with preamble from {preamble_file}")

# %%
# Iterate through the list of .dat files and process each one
for file_path in dat_files:
    try:
        df = read_dat_file(file_path)
        # Get the file name from the file path
        file_name = os.path.basename(file_path)
        file_name = file_name.replace(".dat","")
        
        # Loop through the column and update the column that needs changing
        sysErrDict = {key: value for key, value in []} 
        for column in find_corr_err(df):
            sysErrDict.update(generate_corr_err_shift(df , column))
     
        column_to_modify = 'reduced x-section'

        for i in range(len(df)):
            std  = np.sqrt(df.at[i, 'stat']**2 + df.at[i, 'uncor']**2) 
            std *= df.at[i, column_to_modify]/100.0 
            df.at[i, column_to_modify] += generate_random_number(0,std)

            sys_shift = 0.0
            for col in find_corr_err(df):
                print(f'row: {i} and error: {df.at[i, col]} and column: {col}, sysErrDict[df.at[i, col]] is:{sysErrDict[df.at[i, col]]}')
                sys_shift += sysErrDict[df.at[i, col]]**2
            
            sys_shift  = sys_shift**0.5
            print(f'total sys shift: {sys_shift}' )
            sys_shift *= df.at[i, column_to_modify]/100.0    # all errors are in percent
            df.at[i, column_to_modify] += sys_shift 
        
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

    preamble_file  = directory_path + file_name + ".dat"
    outputFileName = directory_path + "smeared/" + file_name + "_smeared.dat"
    write_dataframe_with_preamble(df, preamble_file, outputFileName)
# Out:
# row: 0 and error: 0.05 and column: eelen, sysErrDict[df.at[i, col]] is:-0.006217620177265868
# row: 0 and error: 0.23 and column: ethee, sysErrDict[df.at[i, col]] is:0.059239282443177756
# row: 0 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 0 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 0 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 0 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 0 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.3706945066682539
# row: 1 and error: 0.06 and column: eelen, sysErrDict[df.at[i, col]] is:-0.011509443209264275
# row: 1 and error: 0.41 and column: ethee, sysErrDict[df.at[i, col]] is:0.5119672985723644
# row: 1 and error: 0.05 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.006217620177265868
# row: 1 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 1 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 1 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 1 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.6270602135751427
# row: 2 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 2 and error: 0.49 and column: ethee, sysErrDict[df.at[i, col]] is:0.1589592998881215
# row: 2 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 2 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 2 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 2 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 2 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.399550476978474
# row: 3 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 3 and error: 0.56 and column: ethee, sysErrDict[df.at[i, col]] is:0.4357305628185908
# row: 3 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 3 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 3 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 3 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 3 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.5857674467076075
# row: 4 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 4 and error: 0.62 and column: ethee, sysErrDict[df.at[i, col]] is:-0.20917449002542146
# row: 4 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 4 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 4 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 4 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 4 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4438652335174935
# row: 5 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 5 and error: 0.64 and column: ethee, sysErrDict[df.at[i, col]] is:-0.21596418615801827
# row: 5 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 5 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 5 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 5 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 5 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.46429058167418563
# row: 6 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 6 and error: 0.66 and column: ethee, sysErrDict[df.at[i, col]] is:-0.6707394172984048
# row: 6 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 6 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 6 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 6 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 6 and error: 0.85 and column: enois, sysErrDict[df.at[i, col]] is:-0.6838933367530432
# total sys shift: 1.0423659033666985
# row: 7 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 7 and error: 0.67 and column: ethee, sysErrDict[df.at[i, col]] is:-1.4341476560249362
# row: 7 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 7 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 7 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 7 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 7 and error: 0.99 and column: enois, sysErrDict[df.at[i, col]] is:1.069316882150998
# total sys shift: 1.8312510674353457
# row: 8 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 8 and error: 0.67 and column: ethee, sysErrDict[df.at[i, col]] is:-1.4341476560249362
# row: 8 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 8 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 8 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 8 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 8 and error: 1.07 and column: enois, sysErrDict[df.at[i, col]] is:0.2067294338510417
# total sys shift: 1.500926026275224
# row: 9 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 9 and error: 0.24 and column: ethee, sysErrDict[df.at[i, col]] is:0.09225354600351988
# row: 9 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04946040546216578
# row: 9 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 9 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 9 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 9 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.3733945273242434
# row: 10 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 10 and error: 0.3 and column: ethee, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 10 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04946040546216578
# row: 10 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 10 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 10 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 10 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3940976141103683
# row: 11 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 11 and error: 0.32 and column: ethee, sysErrDict[df.at[i, col]] is:0.4404685105064741
# row: 11 and error: 0.08 and column: ehadr, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 11 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 11 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 11 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 11 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.5730488926615217
# row: 12 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 12 and error: 0.33 and column: ethee, sysErrDict[df.at[i, col]] is:0.6334614206055119
# row: 12 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 12 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 12 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 12 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 12 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.7346392713810381
# row: 13 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 13 and error: 0.34 and column: ethee, sysErrDict[df.at[i, col]] is:0.5284283080448205
# row: 13 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 13 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 13 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 13 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 13 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.6462646241307202
# row: 14 and error: 0.07 and column: eelen, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 14 and error: 0.35 and column: ethee, sysErrDict[df.at[i, col]] is:0.2763596123056369
# row: 14 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 14 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 14 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 14 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 14 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.46346102638024606
# row: 15 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 15 and error: 0.37 and column: ethee, sysErrDict[df.at[i, col]] is:0.2292356738422481
# row: 15 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 15 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 15 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 15 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 15 and error: 0.85 and column: enois, sysErrDict[df.at[i, col]] is:-0.6838933367530432
# total sys shift: 0.8135770370480322
# row: 16 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 16 and error: 0.38 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1964388953889929
# row: 16 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 16 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 16 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 16 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 16 and error: 0.93 and column: enois, sysErrDict[df.at[i, col]] is:-1.0775938444806243
# total sys shift: 1.1582077699095763
# row: 17 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 17 and error: 0.39 and column: ethee, sysErrDict[df.at[i, col]] is:0.011537738383379544
# row: 17 and error: 0.09 and column: ehadr, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 17 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 17 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 17 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 17 and error: 1.06 and column: enois, sysErrDict[df.at[i, col]] is:0.2310904315286325
# total sys shift: 0.4547507946108911
# row: 18 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 18 and error: 0.15 and column: ethee, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 18 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04946040546216578
# row: 18 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 18 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 18 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 18 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.3770198038478154
# row: 19 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 19 and error: 0.21 and column: ethee, sysErrDict[df.at[i, col]] is:-0.0195310829123547
# row: 19 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:0.020599197843645327
# row: 19 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 19 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 19 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 19 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.36751462068103785
# row: 20 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 20 and error: 0.24 and column: ethee, sysErrDict[df.at[i, col]] is:0.09225354600351988
# row: 20 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 20 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 20 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 20 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 20 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.37799899653706476
# row: 21 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 21 and error: 0.25 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1246829419995225
# row: 21 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 21 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 21 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 21 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 21 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.39647741552374777
# row: 22 and error: 0.08 and column: eelen, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 22 and error: 0.26 and column: ethee, sysErrDict[df.at[i, col]] is:0.031139284928833496
# row: 22 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 22 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 22 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 22 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 22 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.41831430451400664
# row: 23 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 23 and error: 0.27 and column: ethee, sysErrDict[df.at[i, col]] is:0.23858474844862035
# row: 23 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 23 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 23 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 23 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 23 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4655702938760646
# row: 24 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 24 and error: 0.28 and column: ethee, sysErrDict[df.at[i, col]] is:0.09122932583241163
# row: 24 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 24 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 24 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 24 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 24 and error: 0.83 and column: enois, sysErrDict[df.at[i, col]] is:1.050016936204559
# total sys shift: 1.127249472191404
# row: 25 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 25 and error: 0.3 and column: ethee, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 25 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 25 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 25 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 25 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 25 and error: 0.96 and column: enois, sysErrDict[df.at[i, col]] is:-1.6788032562365334
# total sys shift: 1.7311322251561687
# row: 26 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 26 and error: 0.31 and column: ethee, sysErrDict[df.at[i, col]] is:0.33303238582463524
# row: 26 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 26 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 26 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 26 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 26 and error: 1.1 and column: enois, sysErrDict[df.at[i, col]] is:0.23770414353619884
# total sys shift: 0.5877754632377822
# row: 27 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 27 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 27 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:0.020599197843645327
# row: 27 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 27 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 27 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 27 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.3788588094007432
# row: 28 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 28 and error: 0.17 and column: ethee, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 28 and error: 0.02 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.006830825754109044
# row: 28 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 28 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 28 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 28 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3920169976641312
# row: 29 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 29 and error: 0.19 and column: ethee, sysErrDict[df.at[i, col]] is:0.08235272191065858
# row: 29 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 29 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 29 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 29 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 29 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.39600168146008313
# row: 30 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 30 and error: 0.2 and column: ethee, sysErrDict[df.at[i, col]] is:0.006885231174484046
# row: 30 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 30 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 30 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 30 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 30 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4355771401070064
# row: 31 and error: 0.09 and column: eelen, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 31 and error: 0.22 and column: ethee, sysErrDict[df.at[i, col]] is:0.29218375711591493
# row: 31 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 31 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 31 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 31 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 31 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.48708456761229846
# row: 32 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 32 and error: 0.22 and column: ethee, sysErrDict[df.at[i, col]] is:0.29218375711591493
# row: 32 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 32 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 32 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 32 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 32 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4750131606099457
# row: 33 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 33 and error: 0.23 and column: ethee, sysErrDict[df.at[i, col]] is:0.059239282443177756
# row: 33 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 33 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 33 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 33 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 33 and error: 0.85 and column: enois, sysErrDict[df.at[i, col]] is:-0.6838933367530432
# total sys shift: 0.7819754110391657
# row: 34 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 34 and error: 0.24 and column: ethee, sysErrDict[df.at[i, col]] is:0.09225354600351988
# row: 34 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 34 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 34 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 34 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 34 and error: 0.99 and column: enois, sysErrDict[df.at[i, col]] is:1.069316882150998
# total sys shift: 1.1367565553070864
# row: 35 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 35 and error: 0.25 and column: ethee, sysErrDict[df.at[i, col]] is:-0.1246829419995225
# row: 35 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 35 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 35 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 35 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 35 and error: 1.07 and column: enois, sysErrDict[df.at[i, col]] is:0.2067294338510417
# total sys shift: 0.48874403857294896
# row: 36 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 36 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 36 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:0.020599197843645327
# row: 36 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 36 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 36 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 36 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.3779440994429095
# row: 37 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 37 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 37 and error: 0.0 and column: ehadr, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 37 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 37 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 37 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.38499239355361814
# row: 38 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 38 and error: 0.14 and column: ethee, sysErrDict[df.at[i, col]] is:0.06794038612796283
# row: 38 and error: 0.07 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 38 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 38 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 38 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 38 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3782028341074746
# row: 39 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 39 and error: 0.15 and column: ethee, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 39 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 39 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 39 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 39 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 39 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3782658427681266
# row: 40 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 40 and error: 0.16 and column: ethee, sysErrDict[df.at[i, col]] is:0.18286433267452876
# row: 40 and error: 0.14 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06794038612796283
# row: 40 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 40 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 40 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 40 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.41995884265177524
# row: 41 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 41 and error: 0.16 and column: ethee, sysErrDict[df.at[i, col]] is:0.18286433267452876
# row: 41 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 41 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 41 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 41 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 41 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.45490342241999954
# row: 42 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 42 and error: 0.17 and column: ethee, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 42 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 42 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 42 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 42 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 42 and error: 0.85 and column: enois, sysErrDict[df.at[i, col]] is:-0.6838933367530432
# total sys shift: 0.8030656756169727
# row: 43 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 43 and error: 0.17 and column: ethee, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 43 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 43 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 43 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 43 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 43 and error: 0.93 and column: enois, sysErrDict[df.at[i, col]] is:-1.0775938444806243
# total sys shift: 1.156897954428767
# row: 44 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 44 and error: 0.17 and column: ethee, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 44 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 44 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 44 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 44 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 44 and error: 1.06 and column: enois, sysErrDict[df.at[i, col]] is:0.2310904315286325
# total sys shift: 0.44709869288656856
# row: 45 and error: 0.1 and column: eelen, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 45 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:-0.011509443209264275
# row: 45 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:0.020599197843645327
# row: 45 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 45 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 45 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 45 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.371080317299891
# row: 46 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 46 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 46 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:0.020599197843645327
# row: 46 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 46 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 46 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 46 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.43600959338903794
# row: 47 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 47 and error: 0.1 and column: ethee, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 47 and error: 0.1 and column: ehadr, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 47 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 47 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 47 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 47 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4306430819762474
# row: 48 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 48 and error: 0.11 and column: ethee, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 48 and error: 0.14 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06794038612796283
# row: 48 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 48 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 48 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 48 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4637356560473901
# row: 49 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 49 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 49 and error: 0.16 and column: ehadr, sysErrDict[df.at[i, col]] is:0.18286433267452876
# row: 49 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 49 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 49 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 49 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.429162186511288
# row: 50 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 50 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 50 and error: 0.17 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 50 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 50 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 50 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 50 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.39299801768031156
# row: 51 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 51 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 51 and error: 0.16 and column: ehadr, sysErrDict[df.at[i, col]] is:0.18286433267452876
# row: 51 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 51 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 51 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 51 and error: 0.83 and column: enois, sysErrDict[df.at[i, col]] is:1.050016936204559
# total sys shift: 1.1343349367129438
# row: 52 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 52 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 52 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 52 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 52 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 52 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 52 and error: 0.96 and column: enois, sysErrDict[df.at[i, col]] is:-1.6788032562365334
# total sys shift: 1.7239315776131718
# row: 53 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 53 and error: 0.12 and column: ethee, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 53 and error: 0.13 and column: ehadr, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 53 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 53 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 53 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 53 and error: 1.1 and column: enois, sysErrDict[df.at[i, col]] is:0.23770414353619884
# total sys shift: 0.45738393452492804
# row: 54 and error: 0.11 and column: eelen, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 54 and error: 0.05 and column: ethee, sysErrDict[df.at[i, col]] is:-0.006217620177265868
# row: 54 and error: 0.01 and column: ehadr, sysErrDict[df.at[i, col]] is:0.020599197843645327
# row: 54 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 54 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 54 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 54 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.3828001031621582
# row: 55 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 55 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 55 and error: 0.05 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.006217620177265868
# row: 55 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 55 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 55 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 55 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3754754606267669
# row: 56 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 56 and error: 0.08 and column: ethee, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 56 and error: 0.11 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.19938905695238587
# row: 56 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 56 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 56 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 56 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4288661517298852
# row: 57 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 57 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 57 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 57 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 57 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 57 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 57 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4033012637252165
# row: 58 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 58 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 58 and error: 0.17 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 58 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 58 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 58 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 58 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4044003462925808
# row: 59 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 59 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 59 and error: 0.18 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.28079079711734195
# row: 59 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 59 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 59 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 59 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4803368607857199
# row: 60 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 60 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 60 and error: 0.17 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 60 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 60 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 60 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 60 and error: 0.85 and column: enois, sysErrDict[df.at[i, col]] is:-0.6838933367530432
# total sys shift: 0.7894914488915664
# row: 61 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 61 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 61 and error: 0.15 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.05309324792102051
# row: 61 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 61 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 61 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 61 and error: 0.99 and column: enois, sysErrDict[df.at[i, col]] is:1.069316882150998
# total sys shift: 1.139358378874541
# row: 62 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 62 and error: 0.09 and column: ethee, sysErrDict[df.at[i, col]] is:0.13784473869302272
# row: 62 and error: 0.16 and column: ehadr, sysErrDict[df.at[i, col]] is:0.18286433267452876
# row: 62 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 62 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 62 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 62 and error: 1.07 and column: enois, sysErrDict[df.at[i, col]] is:0.2067294338510417
# total sys shift: 0.47755256367080756
# row: 63 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 63 and error: 0.04 and column: ethee, sysErrDict[df.at[i, col]] is:-0.04946040546216578
# row: 63 and error: 0.02 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.006830825754109044
# row: 63 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 63 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 63 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 63 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 1.372705033579265
# row: 64 and error: 0.12 and column: eelen, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 64 and error: 0.05 and column: ethee, sysErrDict[df.at[i, col]] is:-0.006217620177265868
# row: 64 and error: 0.05 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.006217620177265868
# row: 64 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 64 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 64 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 64 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3753786914084808
# row: 65 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 65 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:-0.011509443209264275
# row: 65 and error: 0.12 and column: ehadr, sysErrDict[df.at[i, col]] is:0.09954382856030242
# row: 65 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 65 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 65 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 65 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.3780480091017148
# row: 66 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 66 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:-0.011509443209264275
# row: 66 and error: 0.17 and column: ehadr, sysErrDict[df.at[i, col]] is:0.06088204771527985
# row: 66 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 66 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 66 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 66 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.36975390074390424
# row: 67 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 67 and error: 0.06 and column: ethee, sysErrDict[df.at[i, col]] is:-0.011509443209264275
# row: 67 and error: 0.18 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.28079079711734195
# row: 67 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 67 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 67 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 67 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.46027686790356914
# row: 68 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 68 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 68 and error: 0.18 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.28079079711734195
# row: 68 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 68 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 68 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 68 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 0.4602538932091074
# row: 69 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 69 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 69 and error: 0.16 and column: ehadr, sysErrDict[df.at[i, col]] is:0.18286433267452876
# row: 69 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 69 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 69 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 69 and error: 0.85 and column: enois, sysErrDict[df.at[i, col]] is:-0.6838933367530432
# total sys shift: 0.7963288483334384
# row: 70 and error: 0.14 and column: eelen, sysErrDict[df.at[i, col]] is:0.06794038612796283
# row: 70 and error: 0.07 and column: ethee, sysErrDict[df.at[i, col]] is:-0.010550752106277528
# row: 70 and error: 0.18 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.28079079711734195
# row: 70 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 70 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 70 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 70 and error: 0.93 and column: enois, sysErrDict[df.at[i, col]] is:-1.0775938444806243
# total sys shift: 1.1729032570520521
# row: 71 and error: 0.16 and column: eelen, sysErrDict[df.at[i, col]] is:0.18286433267452876
# row: 71 and error: 0.08 and column: ethee, sysErrDict[df.at[i, col]] is:0.05777833248747448
# row: 71 and error: 0.29 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.23952735118963422
# row: 71 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 71 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 71 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 71 and error: 1.06 and column: enois, sysErrDict[df.at[i, col]] is:0.2310904315286325
# total sys shift: 0.5277089253928807
# row: 72 and error: 0.22 and column: eelen, sysErrDict[df.at[i, col]] is:0.29218375711591493
# row: 72 and error: 0.1 and column: ethee, sysErrDict[df.at[i, col]] is:0.08594939634423295
# row: 72 and error: 0.55 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.9754685216263457
# row: 72 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# row: 72 and error: 0.0 and column: egamp, sysErrDict[df.at[i, col]] is:0.0
# row: 72 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 72 and error: 1.12 and column: enois, sysErrDict[df.at[i, col]] is:-0.7602647003699277
# total sys shift: 1.3240931872510098
# row: 73 and error: 0.13 and column: eelen, sysErrDict[df.at[i, col]] is:0.04422652530526217
# row: 73 and error: 0.02 and column: ethee, sysErrDict[df.at[i, col]] is:-0.006830825754109044
# row: 73 and error: 0.04 and column: ehadr, sysErrDict[df.at[i, col]] is:-0.04946040546216578
# row: 73 and error: 0.3 and column: radco, sysErrDict[df.at[i, col]] is:-0.13640158164847901
# ...
# row: 154 and error: 1.0 and column: egamp, sysErrDict[df.at[i, col]] is:1.319467420197513
# row: 154 and error: 0.5 and column: effic, sysErrDict[df.at[i, col]] is:-0.3351380000560312
# row: 154 and error: 0.0 and column: enois, sysErrDict[df.at[i, col]] is:0.0
# total sys shift: 3.3552416022760636
# DataFrame has been written to ./LHeC/smeared/lhec_D4_dataempn1000nc-thexp_smeared.dat with preamble from ./LHeC/lhec_D4_dataempn1000nc-thexp.dat
# row: 0 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 1 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 2 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 3 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 4 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 5 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 6 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 7 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 8 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 9 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 10 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 11 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 12 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 13 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 14 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 15 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 16 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 17 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 18 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 19 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 20 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 21 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 22 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 23 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 24 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 25 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 26 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 27 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 28 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 29 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 30 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 31 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 32 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 33 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 34 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 35 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 36 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 37 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 38 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 39 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 40 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 41 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 42 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 43 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 44 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 45 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 46 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 47 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 48 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 49 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 50 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 51 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 52 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 53 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 54 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 55 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 56 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 57 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 58 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 59 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 60 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 61 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 62 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 63 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 64 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 65 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 66 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 67 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 68 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 69 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 70 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 71 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# row: 72 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 73 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 74 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 75 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 76 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 77 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 78 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 79 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 80 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 81 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 82 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# row: 83 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 84 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 85 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 86 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 87 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 88 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 89 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 90 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 91 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 92 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# row: 93 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 94 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 95 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 96 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 97 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 98 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 99 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 100 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 101 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# row: 102 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 103 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 104 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 105 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 106 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 107 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 108 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 109 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# row: 110 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 111 and error: 1.5 and column: ccsys, sysErrDict[df.at[i, col]] is:-3.315827924074421
# total sys shift: 3.315827924074421
# row: 112 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 113 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 114 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 115 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 116 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# row: 117 and error: 2.92 and column: ccsys, sysErrDict[df.at[i, col]] is:1.824018659054584
# total sys shift: 1.824018659054584
# row: 118 and error: 4.33 and column: ccsys, sysErrDict[df.at[i, col]] is:8.59244911005269
# total sys shift: 8.59244911005269
# row: 119 and error: 5.75 and column: ccsys, sysErrDict[df.at[i, col]] is:6.224165370675535
# total sys shift: 6.224165370675535
# row: 120 and error: 7.17 and column: ccsys, sysErrDict[df.at[i, col]] is:7.339655365295119
# total sys shift: 7.339655365295119
# row: 121 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# row: 122 and error: 8.58 and column: ccsys, sysErrDict[df.at[i, col]] is:-13.761979563700256
# total sys shift: 13.761979563700256
# DataFrame has been written to ./LHeC/smeared/lhec_D4_dataempn1000cc-thexp_smeared.dat with preamble from ./LHeC/lhec_D4_dataempn1000cc-thexp.dat
